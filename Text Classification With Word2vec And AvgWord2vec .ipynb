# %% [markdown]
# ### Text Classification With Word2vec And AvgWord2vec

# %%
import pandas as pd
df = pd.read_csv("spam.csv",encoding="latin1")
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
# Rename 'v1' to 'label' and 'v2' to 'Message'
df.rename(columns={'v1': 'label', 'v2': 'Message'}, inplace=True)

# Drop the unwanted columns
df.drop(columns=['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'], inplace=True)

# Display the updated DataFrame
print(df.head())
# Out:
#   label                                            Message
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %% [markdown]
# ### Data Preprocessing and Cleaning

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
lz = WordNetLemmatizer()
from nltk.stem import SnowballStemmer
sb = SnowballStemmer('english')
from nltk.stem import PorterStemmer
pt = PorterStemmer()

# %%
corpus = []
for i in range(0,len(df)):
    review = re.sub('[^a-zA-Z]',' ',df['Message'][i])
    review = review.lower()
    review =review.split()
    review = [lz.lemmatize(word)for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    corpus.append(review)

# %%
corpus
# Out:
# ['go jurong point crazy available bugis n great world la e buffet cine got amore wat',
#  'ok lar joking wif u oni',
#  'free entry wkly comp win fa cup final tkts st may text fa receive entry question std txt rate c apply',
#  'u dun say early hor u c already say',
#  'nah think go usf life around though',
#  'freemsg hey darling week word back like fun still tb ok xxx std chgs send rcv',
#  'even brother like speak treat like aid patent',
#  'per request melle melle oru minnaminunginte nurungu vettam set callertune caller press copy friend callertune',
#  'winner valued network customer selected receivea prize reward claim call claim code kl valid hour',
#  'mobile month u r entitled update latest colour mobile camera free call mobile update co free',
#  'gonna home soon want talk stuff anymore tonight k cried enough today',
#  'six chance win cash pound txt csh send cost p day day tsandcs apply reply hl info',
#  'urgent week free membership prize jackpot txt word claim c www dbuk net lccltd pobox ldnw rw',
#  'searching right word thank breather promise wont take help granted fulfil promise wonderful blessing time',
#  'date sunday',
#  'xxxmobilemovieclub use credit click wap link next txt message click http wap xxxmobilemovieclub com n qjkgighjjgcbl',
#  'oh k watching',
#  'eh u remember spell name yes v naughty make v wet',
#  'fine way u feel way gota b',
#  'england v macedonia dont miss goal team news txt ur national team eg england try wale scotland txt poboxox w wq',
#  'seriously spell name',
#  'going try month ha ha joking',
#  'pay first lar da stock comin',
#  'aft finish lunch go str lor ard smth lor u finish ur lunch already',
#  'ffffffffff alright way meet sooner',
#  'forced eat slice really hungry tho suck mark getting worried know sick turn pizza lol',
#  'lol always convincing',
#  'catch bus frying egg make tea eating mom left dinner feel love',
#  'back amp packing car let know room',
#  'ahhh work vaguely remember feel like lol',
#  'wait still clear sure sarcastic x want live u',
#  'yeah got v apologetic n fallen actin like spoilt child got caught till go badly cheer',
#  'k tell anything',
#  'fear fainting housework quick cuppa',
#  'thanks subscription ringtone uk mobile charged month please confirm replying yes reply charged',
#  'yup ok go home look timing msg xuhui going learn nd may lesson',
#  'oops let know roommate done',
#  'see letter b car',
#  'anything lor u decide',
#  'hello saturday go texting see decided anything tomo trying invite anything',
#  'pls go ahead watt wanted sure great weekend abiola',
#  'forget tell want need crave love sweet arabian steed mmmmmm yummy',
#  'rodger burn msg tried call reply sm free nokia mobile free camcorder please call delivery tomorrow',
#  'seeing',
#  'great hope like man well endowed lt gt inch',
#  'call message missed call',
#  'get hep b immunisation nigeria',
#  'fair enough anything going',
#  'yeah hopefully tyler could maybe ask around bit',
#  'u know stubborn even want go hospital kept telling mark weak sucker hospital weak sucker',
#  'thinked first time saw class',
#  'gram usually run like lt gt half eighth smarter though get almost whole second gram lt gt',
#  'k fyi x ride early tomorrow morning crashing place tonight',
#  'wow never realized embarassed accomodations thought liked since best could always seemed happy cave sorry give sorry offered sorry room embarassing',
#  'sm ac sptv new jersey devil detroit red wing play ice hockey correct incorrect end reply end sptv',
#  'know mallika sherawat yesterday find lt url gt',
#  'congrats year special cinema pas call c suprman v matrix starwars etc free bx ip pm dont miss',
#  'sorry call later meeting',
#  'tell reached',
#  'yes gauti sehwag odi series',
#  'gonna pick burger way home even move pain killing',
#  'ha ha ha good joke girl situation seeker',
#  'part checking iq',
#  'sorry roommate took forever ok come',
#  'ok lar double check wif da hair dresser already said wun cut v short said cut look nice',
#  'valued customer pleased advise following recent review mob awarded bonus prize call',
#  'today song dedicated day song u dedicate send ur valuable frnds first rply',
#  'urgent ur awarded complimentary trip eurodisinc trav aco entry claim txt dis morefrmmob shracomorsglsuplt l aj',
#  'hear new divorce barbie come ken stuff',
#  'plane give month end',
#  'wah lucky man save money hee',
#  'finished class',
#  'hi babe im home wanna something xx',
#  'k k performed',
#  'u call',
#  'waiting machan call free',
#  'thats cool gentleman treat dignity respect',
#  'like people much shy pa',
#  'operate lt gt',
#  'still looking job much ta earn',
#  'sorry call later',
#  'k call ah',
#  'ok way home hi hi',
#  'place man',
#  'yup next stop',
#  'call later network urgnt sm',
#  'real u getting yo need ticket one jacket done already used multis',
#  'yes started send request make pain came back back bed double coin factory gotta cash nitros',
#  'really still tonight babe',
#  'ela kano il download come wen ur free',
#  'yeah stand close tho catch something',
#  'sorry pain ok meet another night spent late afternoon casualty mean done stuff moro includes time sheet sorry',
#  'smile pleasure smile pain smile trouble pours like rain smile sum hurt u smile becoz someone still love see u smiling',
#  'please call customer service representative pm guaranteed cash prize',
#  'havent planning buy later check already lido got show e afternoon u finish work already',
#  'free ringtone waiting collected simply text password mix verify get usher britney fml',
#  'watching telugu movie wat abt u',
#  'see finish load loan pay',
#  'hi wk ok hols yes bit run forgot hairdresser appointment four need get home n shower beforehand cause prob u ham',
#  'please text anymore nothing else say',
#  'okay name ur price long legal wen pick u ave x am xx',
#  'still looking car buy gone driving test yet',
#  'per request melle melle oru minnaminunginte nurungu vettam set callertune caller press copy friend callertune',
#  'wow right mean guess gave boston men changed search location nyc something changed cuz signin page still say boston',
#  'umma life vava umma love lot dear',
#  'thanks lot wish birthday thanks making birthday truly memorable',
#  'aight hit get cash',
#  'would ip address test considering computer minecraft server',
#  'know grumpy old people mom like better lying always one play joke',
#  'dont worry guess busy',
#  'plural noun research',
#  'going dinner msg',
#  'ok wif co like try new thing scared u dun like mah co u said loud',
#  'gent trying contact last weekend draw show prize guaranteed call claim code k valid hr ppm',
#  'wa ur openin sentence formal anyway fine juz tt eatin much n puttin weight haha anythin special happened',
#  'entered cabin pa said happy b day bos felt special askd lunch lunch invited apartment went',
#  'winner u specially selected receive holiday flight inc speak live operator claim p min',
#  'goodo yes must speak friday egg potato ratio tortilla needed',
#  'hmm uncle informed paying school directly pls buy food',
#  'private account statement show unredeemed bonus point claim call identifier code expires',
#  'urgent mobile awarded bonus caller prize final try contact u call landline box wr c ppm',
#  'new address apple pair malarky',
#  'today voda number ending selected receive award match please call quoting claim code standard rate app',
#  'going sao mu today done',
#  'predict wat time finish buying',
#  'good stuff',
#  'know yetunde sent money yet sent text bother sending dont involve anything imposed anything first place apologise',
#  'room',
#  'hey girl r u hope u r well del r bak long time c give call sum time lucyxx',
#  'k k much cost',
#  'home',
#  'dear call tmorrow pls accomodate',
#  'first answer question',
#  'sunshine quiz wkly q win top sony dvd player u know country algarve txt ansr sp tyrone',
#  'want get laid tonight want real dogging location sent direct ur mob join uk largest dogging network bt txting gravel nt ec p msg p',
#  'haf msn yijue hotmail com',
#  'call meet',
#  'check room befor activity',
#  'rcv msg chat svc free hardcore service text go u get nothing u must age verify yr network try',
#  'got c lazy type forgot lect saw pouch like v nice',
#  'k text way',
#  'sir waiting mail',
#  'swt thought nver get tired little thing lovable person coz somtimes little thing occupy biggest part heart gud ni',
#  'know pls open back',
#  'yes see ya dot',
#  'whats staff name taking class u',
#  'freemsg replied text randy sexy female live local luv hear u netcollex ltd p per msg reply stop end',
#  'ummma call check life begin qatar pls pray hard',
#  'k deleted contact',
#  'sindu got job birla soft',
#  'wine flowing nevering',
#  'yup thk cine better co need go plaza mah',
#  'ok ur typical reply',
#  'per request melle melle oru minnaminunginte nurungu vettam set callertune caller press copy friend callertune',
#  'everywhere dirt floor window even shirt sometimes open mouth come flowing dream world without half chore time joy lot tv show see guess like thing must exist like rain hail mist time done become one',
#  'aaooooright work',
#  'leaving house',
#  'hello love get interview today happy good boy think missing',
#  'customer service annoncement new year delivery waiting please call arrange delivery',
#  'winner u specially selected receive cash holiday flight inc speak live operator claim',
#  'keep safe need miss already envy everyone see real life',
#  'new car house parent new job hand',
#  'love excited day spend make happy',
#  'pls stop bootydelious f inviting friend reply yes see www sm ac u bootydelious stop send stop frnd',
#  'bangbabes ur order way u receive service msg download ur content u goto wap bangb tv ur mobile internet service menu',
#  'place ur point e culture module already',
#  'urgent trying contact last weekend draw show prize guaranteed call claim code valid hr',
#  'hi frnd best way avoid missunderstding wit beloved one',
#  'great escape fancy bridge need lager see tomo',
#  'yes completely form clark also utter waste',
#  'sir need axis bank account bank address',
#  'hmmm thk sure got time hop ard ya go free abt muz call u discus liao',
#  'time coming later',
#  'bloody hell cant believe forgot surname mr ill give u clue spanish begin',
#  'well gonna finish bath good fine night',
#  'let know got money carlos make call',
#  'u still going mall',
#  'turn friend staying whole show back til lt gt feel free go ahead smoke lt gt worth',
#  'text doesnt reply let know log',
#  'hi spoke maneesha v like know satisfied experience reply toll free yes',
#  'lifted hope offer money need especially end month approach hurt studying anyways gr weekend',
#  'lol u trust',
#  'ok gentleman treat dignity respect',
#  'guy close',
#  'going nothing great bye',
#  'hello handsome finding job lazy working towards getting back net mummy boytoy miss',
#  'haha awesome minute',
#  'please call customer service representative freephone pm guaranteed cash prize',
#  'got xmas radio time get',
#  'jus reached home go bathe first si using net tell u finish k',
#  'unique enough find th august www areyouunique co uk',
#  'sorry joined league people dont keep touch mean great deal friend time even great personal cost great week',
#  'hi finally completed course',
#  'stop however suggest stay someone able give or every stool',
#  'hope settled new school year wishin gr day',
#  'gud mrng dear hav nice day',
#  'u got person story',
#  'hamster dead hey tmr meet pm orchard mrt',
#  'hi kate evening hope see tomorrow bit bloody babyjontet txt back u xxx',
#  'found enc lt gt',
#  'sent lt gt buck',
#  'hello darlin ive finished college txt u finish u love kate xxx',
#  'account refilled successfully inr lt decimal gt keralacircle prepaid account balance r lt decimal gt transaction id kr lt gt',
#  'goodmorning sleeping ga',
#  'u call alter ok',
#  'say like dat dun buy ericsson oso cannot oredi lar',
#  'entered cabin pa said happy b day bos felt special askd lunch lunch invited apartment went',
#  'aight yo dat straight dogg',
#  'please give u connection today lt decimal gt refund bill',
#  'shoot big load get ready',
#  'bruv hope great break rewarding semester',
#  'home always chat',
#  'k k good study well',
#  'yup noe leh',
#  'sound great home',
#  'finally match heading towards draw prediction',
#  'tired slept well past night',
#  'easy ah sen got selected mean good',
#  'take exam march',
#  'yeah think use gt atm register sure anyway help let know sure ready',
#  'ok prob take ur time',
#  'o called ubandu run without installing hard disk use o copy important file system give repair shop',
#  'sorry call later',
#  'u say leh course nothing happen lar say v romantic jus bit lor thk e nite scenery nice leh',
#  'new mobile must go txt nokia collect today www tc biz optout gbp mtmsg',
#  'would really appreciate call need someone talk',
#  'u meet ur dream partner soon ur career flyng start find free txt horo followed ur star sign e g horo aries',
#  'hey company elama po mudyadhu',
#  'life strict teacher bcoz teacher teach lesson amp conduct exam life first conduct exam amp teach lesson happy morning',
#  'dear good morning',
#  'get gandhipuram walk cross cut road right side lt gt street road turn first right',
#  'dear going rubber place',
#  'sorry battery died yeah',
#  'yes tv always available work place',
#  'text meet someone sexy today u find date even flirt u join p reply name age eg sam msg recd thirtyeight penny',
#  'printed oh lt gt come upstairs',
#  'ill little closer like bus stop street',
#  'wil reach',
#  'new theory argument win situation loses person dont argue ur friend kick amp say always correct',
#  'u secret admirer looking make contact u find r reveal think ur special call',
#  'tomarrow final hearing laptop case cant',
#  'pleassssssseeeeee tel v avent done sportsx',
#  'okay shining meant signing sound better',
#  'although told u dat baig face watch really like e watch u gave co fr u thanx everything dat u done today touched',
#  'u remember old commercial',
#  'late said website dont slipper',
#  'asked call ok',
#  'kallis wont bat nd inning',
#  'didnt work oh ok goodnight fix ready time wake dearly missed good night sleep',
#  'congratulation ur awarded cd voucher gift guaranteed free entry wkly draw txt music tncs www ldew com win ppmx age',
#  'ranjith cal drpd deeraj deepak min hold',
#  'wen ur lovable bcums angry wid u dnt take seriously coz angry childish n true way showing deep affection care n luv kettoda manda nice day da',
#  '',
#  'ups day also shipping company take wks way usps take week get lag may bribe nipost get stuff',
#  'back lemme know ready',
#  'necessarily expect done get back though headin',
#  'mmm yummy babe nice jolt suzy',
#  'lover need',
#  'tried contact reply offer video handset anytime network min unlimited text camcorder reply call',
#  'parked next mini coming today think',
#  'yup',
#  'anyway going shopping co si done yet dun disturb u liao',
#  'luton ring ur around h',
#  'hey really horny want chat see naked text hot text charged pm unsubscribe text stop',
#  'dint come u',
#  'wana plan trip sometme',
#  'sure yet still trying get hold',
#  'ur ringtone service changed free credit go club mobile com choose content stop txt club stop p wk club po box mk wt',
#  'evo download flash jealous',
#  'ringtone club get uk single chart mobile week choose top quality ringtone message free charge',
#  'come mu sorting narcotic situation',
#  'night ended another day morning come special way may smile like sunny ray leaf worry blue blue bay',
#  'hmv bonus special pound genuine hmv voucher answer easy question play send hmv info www percent real com',
#  'usf guess might well take car',
#  'objection bf coming',
#  'thanx',
#  'tell rob mack gf theater',
#  'awesome see bit',
#  'sent type food like',
#  'done handed celebration full swing yet',
#  'got called tool',
#  'wen u miss someone',
#  'ok asked money far',
#  'okie',
#  'yeah think usual guy still passed last night get ahold anybody let know throw',
#  'k might come tonight class let early',
#  'ok',
#  'hi baby im cruisin girl friend r u give call hour home thats alright fone fone love jenny xxx',
#  'life mean lot love life love people life world call friend call world ge',
#  'dear shall mail tonite busy street shall update tonite thing looking ok varunnathu edukkukayee raksha ollu good one real sense',
#  'hey told name gautham ah',
#  'haf u found feel stupid da v cam working',
#  'oops got bit',
#  'much buzy',
#  'accidentally deleted message resend please',
#  'mobile customer may claim free camera phone upgrade pay go sim card loyalty call offer end thfeb c apply',
#  'unless situation go gurl would appropriate',
#  'hurt tease make cry end life die plz keep one rose grave say stupid miss u nice day bslvyl',
#  'cant pick phone right pls send message',
#  'need coffee run tomo believe time week already',
#  'awesome remember last time got somebody high first time diesel v',
#  'shit really shocking scary cant imagine second def night u think somewhere could crash night save taxi',
#  'oh way food fridge want go meal tonight',
#  'womdarfull actor',
#  'sm ac blind date u rodds aberdeen united kingdom check http img sm ac w icmb cktz r blind date send hide',
#  'yup remb think book',
#  'jos ask u wana meet',
#  'lol yes friendship hanging thread cause u buy stuff',
#  'themob check newest selection content game tone gossip babe sport keep mobile fit funky text wap',
#  'garage key bookshelf',
#  'today accept day u accept brother sister lover dear best clos lvblefrnd jstfrnd cutefrnd lifpartnr belovd swtheart bstfrnd rply mean enemy',
#  'think ur smart win week weekly quiz text play c winnersclub po box uz gbp week',
#  'say give call friend got money definitely buying end week',
#  'hi way u day normal way real ur unique hope know u rest mylife hope u find wot lost',
#  'made day great day',
#  'k k advance happy pongal',
#  'hmmm guess go kb n power yoga haha dunno tahan power yoga anot thk got lo oso forgot liao',
#  'really dude friend afraid',
#  'december mobile mths entitled update latest colour camera mobile free call mobile update co free',
#  'coffee cake guess',
#  'merry christmas babe love ya kiss',
#  'hey dont go watch x men lunch haha',
#  'cud u tell ppl im gona b bit l co bus hav gon past co full im still waitin pete x',
#  'would great guild could meet bristol road somewhere get touch weekend plan take flight good week',
#  'problem',
#  'call message missed call',
#  'hi da today class',
#  'say good sign well know track record reading woman',
#  'cool text parked',
#  'reading text sent meant joke read light',
#  'k k apo k good movie',
#  'maybe could get book tomo return immediately something',
#  'call germany penny per minute call fixed line via access number prepayment direct access',
#  'chance might evaporated soon violated privacy stealing phone number employer paperwork cool please contact report supervisor',
#  'valentine day special win quiz take partner trip lifetime send go p msg rcvd custcare',
#  'ta daaaaa home babe still',
#  'cool come havent wined dined',
#  'sleeping surfing',
#  'sorry call later',
#  'u calling right call hand phone',
#  'ok great thanx lot',
#  'take post come must text happy reading one wiv hello caroline end favourite bless',
#  'u hiding stranger',
#  'interested like',
#  'sister cleared two round birla soft yesterday',
#  'gudnite tc practice going',
#  'dis yijue jus saw ur mail case huiming havent sent u num dis num',
#  'one small prestige problem',
#  'fancy shag interested sextextuk com txt xxuk suzy txts cost per msg tncs website x',
#  'checking really miss seeing jeremiah great month',
#  'nah help never iphone',
#  'car hour half going apeshit',
#  'today sorry day ever angry ever misbehaved hurt plz plz slap urself bcoz ur fault basically good',
#  'yo guy ever figure much need alcohol jay trying figure much safely spend weed',
#  'lt gt ish minute minute ago wtf',
#  'thank calling forgot say happy onam sirji fine remembered met insurance person meet qatar insha allah rakhesh ex tata aig joined tissco tayseer',
#  'congratulation ur awarded cd voucher gift guaranteed free entry wkly draw txt music tncs www ldew com win ppmx age',
#  'ur cash balance currently pound maximize ur cash send cash p msg cc hg suite land row w j hl',
#  'actor work work evening sleep late since unemployed moment always sleep late unemployed every day saturday',
#  'hello got st andrew boy long way cold keep posted',
#  'ha ha cool cool chikku chikku db',
#  'oh ok prob',
#  'check audrey status right',
#  'busy trying finish new year looking forward finally meeting',
#  'good afternoon sunshine dawn day refreshed happy alive breathe air smile think love always',
#  'well know z take care worry',
#  'update xmas offer latest motorola sonyericsson nokia free bluetooth double min txt orange call mobileupd call optout f q',
#  'discount code rp stop message reply stop www regalportfolio co uk customer service',
#  'wat uniform get',
#  'cool text ready',
#  'hello boytoy geeee miss already woke wish bed cuddling love',
#  'spoil bed well',
#  'going bath msg next lt gt min',
#  'cant keep talking people sure pay agree price pls tell want really buy much willing pay',
#  'thanks ringtone order reference charged gbp per week unsubscribe anytime calling customer service',
#  'say happen',
#  'could seen recognise face',
#  'well lot thing happening lindsay new year sigh bar ptbo blue heron something going',
#  'keep payasam rinu brings',
#  'taught ranjith sir called sm like becaus he verifying project prabu told today pa dont mistake',
#  'guess worried must know way body repair quite sure worry take slow first test guide ovulation relax nothing said reason worry keep followin',
#  'yeah sure give couple minute track wallet',
#  'hey leave big deal take care',
#  'hey late ah meet',
#  'double min txts month free bluetooth orange available sony nokia motorola phone call mobileupd call optout n dx',
#  'took mr owl lick',
#  'customer place call',
#  'mm time dont like fun',
#  'mths half price orange line rental latest camera phone free phone mths call mobilesdirect free update stoptxt',
#  'yup lunch buffet u eat already',
#  'huh late fr dinner',
#  'hey sat going intro pilate kickboxing',
#  'morning ok',
#  'yes think office lap room think thats last day didnt shut',
#  'pick bout ish time going',
#  'performance award calculated every two month current one month period',
#  'actually sleeping still might u call back text gr rock si send u text wen wake',
#  'always putting business put picture as facebook one open people ever met would think picture room would hurt make feel violated',
#  'good evening sir al salam wahleykkum sharing happy news grace god got offer tayseer tissco joined hope fine inshah allah meet sometime rakhesh visitor india',
#  'hmmm k want change field quickly da wanna get system administrator network administrator',
#  'free ringtone text first poly text get true tone help st free tone x pw e nd txt stop',
#  'dear chechi talk',
#  'hair cream shipped',
#  'none happening til get though',
#  'yep great loxahatchee xmas tree burning lt gt start hour',
#  'haha get used driving usf man know lot stoner',
#  'well slightly disastrous class pm fav darling hope day ok coffee wld good stay late tomorrow time place always',
#  'hello good week fancy drink something later',
#  'headin towards busetop',
#  'message text missing sender name missing number missing sent date missing missing u lot thats everything missing sent via fullonsms com',
#  'come room point iron plan weekend',
#  'co want thing',
#  'okies go yan jiu skip ard oso go cine den go mrt one blah blah blah',
#  'bring home wendy',
#  'dating service cal l box sk ch',
#  'whatsup dont u want sleep',
#  'alright new goal',
#  'free entry weekly competition text word win c www txttowin co uk',
#  'alright head minute text meet',
#  'send logo ur lover name joined heart txt love name name mobno eg love adam eve yahoo pobox w wq txtno ad p',
#  'yes last week taking live call',
#  'someone contacted dating service entered phone fancy find call landline pobox n tf p',
#  'siva hostel aha',
#  'urgent mobile number awarded prize guaranteed call land line claim valid hr',
#  'send ur friend receive something ur voice speaking expression childish naughty sentiment rowdy ful attitude romantic shy attractive funny lt gt irritating lt gt lovable reply',
#  'ok ok guess',
#  'aathi dear',
#  'pain urination thing else',
#  'esplanade mind giving lift co got car today',
#  'wnt buy bmw car urgently vry urgent hv shortage lt gt lac source arng dis amt lt gt lac thats prob',
#  'home watching tv lor',
#  'usually take fifteen fucking minute respond yes question',
#  'congrats nokia video camera phone call call cost ppm ave call min vary mobile close post bcm ldn wc n xx',
#  'booked ticket pongal',
#  'available like right around hillsborough amp lt gt th',
#  'message sent askin lt gt dollar shoul pay lt gt lt gt',
#  'ask g iouri told story like ten time already',
#  'long applebees fucking take',
#  'hi hope u get txt journey hasnt gd min late think',
#  'like love arrange',
#  'yes really great bhaji told kallis best cricketer sachin world tough get',
#  'supposed wake gt',
#  'oic saw tot din c found group liao',
#  'sorry call later',
#  'hey hey werethe monkeespeople say monkeyaround howdy gorgeous',
#  'sorry battery died come getting gram place',
#  'well done blimey exercise yeah kinda remember wot hmm',
#  'wont get concentration dear know mind everything',
#  'lol made plan new year',
#  'min later k',
#  'hank lotsly',
#  'thanks hope good day today',
#  'k k detail want transfer acc enough',
#  'ok tell stay yeah tough optimistic thing improve month',
#  'loan purpose homeowner tenant welcome previously refused still help call free text back help',
#  'si si think ill go make oreo truffle',
#  'look amy ure beautiful intelligent woman like u lot know u like like worry',
#  'hope result consistently intelligent kind start asking practicum link keep ear open best ttyl',
#  'call cost guess isnt bad miss ya need ya want ya love ya',
#  'going thru different feeling wavering decision coping individual time heal everything believe',
#  'u go phone gonna die stay',
#  'great never better day give even reason thank god',
#  'upgrdcentre orange customer may claim free camera phone upgrade loyalty call offer end th july c apply opt available',
#  'sorry call later ok bye',
#  'ok way railway',
#  'great princess love giving receiving oral doggy style fave position enjoy making love lt gt time per night',
#  'put stuff road keep getting slippery',
#  'going ride bike',
#  'yup need jus wait e rain stop',
#  'many company tell language',
#  'okmail dear dave final notice collect tenerife holiday cash award call landline tc sae box cw wx ppm',
#  'long since screamed princess',
#  'nothing meant money enters account bank remove flat rate someone transfered lt gt account lt gt dollar got removed bank differ charge also differ sure trust ja person sending account detail co',
#  'want get laid tonight want real dogging location sent direct ur mob join uk largest dogging network txting moan nyt ec p msg p',
#  'nice line said broken heart plz cum time infront wise trust u good',
#  'ok gonna head usf like fifteen minute',
#  'love aathi love u lot',
#  'tension ah machi problem',
#  'k pick another th done',
#  'guy getting back g said thinking staying mcr',
#  'almost see u sec',
#  'yo carlos friend already asking working weekend',
#  'watching tv lor',
#  'thank baby cant wait taste real thing',
#  'change fb jaykwon thuglyfe falconerf',
#  'win really side long time',
#  'free message activate free text message replying message word free term condition visit www com',
#  'dear reached railway happen',
#  'depends quality want type sent boye faded glory want ralphs maybe',
#  'think fixed send test message',
#  'sorry man account dry would want could trade back half could buy shit credit card',
#  'congrats year special cinema pas call c suprman v matrix starwars etc free bx ip pm dont miss',
#  'sorry meeting call later',
#  'class lt gt reunion',
#  'free call',
#  'got meh',
#  'nope think go monday sorry replied late',
#  'told accenture confirm true',
#  'kate jackson rec center ish right',
#  'dear reache room',
#  'fighting world easy u either win lose bt fightng close u dificult u lose u lose u win u still lose',
#  'come',
#  'check nuerologist',
#  'lolnice went fish water',
#  'congratulation week competition draw u prize claim call b c stop sm ppm',
#  'waiting e car dat bored wat co wait outside got nothing home stuff watch tv wat',
#  'maybe westshore hyde park village place near house',
#  'know anthony bringing money school fee pay rent stuff like thats need help friend need',
#  'significance',
#  'opinion jada kusruthi lovable silent spl character matured stylish simple pls reply',
#  'latest g still scrounge ammo want give new ak try',
#  'prabha soryda realy frm heart sory',
#  'lol ok forgiven',
#  'jst change tat',
#  'guaranteed latest nokia phone gb ipod mp player prize txt word collect ibhltd ldnw h p mtmsgrcvd',
#  'competition',
#  'boltblue tone p reply poly mono eg poly cha cha slide yeah slow jamz toxic come stop tone txt',
#  'credit topped http www bubbletext com renewal pin tgxxrz',
#  'way transport le problematic sat night way u want ask n join bday feel free need know definite no booking fri',
#  'usually person unconscious child adult may behave abnormally call',
#  'ebay might le elsewhere',
#  'shall come get pickle',
#  'gonna go get taco',
#  'rude campus',
#  'urgent mobile awarded bonus caller prize nd attempt contact call box qu',
#  'hi b ard christmas enjoy n merry x ma',
#  'today offer claim ur worth discount voucher text yes savamob member offer mobile c sub unsub reply x',
#  'yes pretty lady like single',
#  'recieve tone within next hr term condition please see channel u teletext pg',
#  'jay say double faggot',
#  'private account statement show un redeemed point call identifier code expires',
#  'today sunday sunday holiday work',
#  'gudnite tc practice going',
#  'late',
#  'called hoping l r malaria know miss guy miss ban big pls give love especially great day',
#  'good afternoon love go day hope maybe got lead job think boytoy send passionate kiss across sea',
#  'probably gonna see later tonight lt',
#  'maybe fat finger press button know',
#  'ummmmmaah many many happy return day dear sweet heart happy birthday dear',
#  'tirupur da started office call',
#  'www applausestore com monthlysubscription p msg max month csc web age stop txt stop',
#  'famous quote develop ability listen anything unconditionally without losing temper self confidence mean married',
#  'going college pa else ill come self pa',
#  'oclock mine bash flat plan',
#  'girl stay bed girl need recovery time id rather pas fun cooped bed',
#  'special',
#  'know need get hotel got invitation apologise cali sweet come english bloke weddin',
#  'sorry took long omw',
#  'wait lt gt min',
#  'ok give minute think see btw alibi cutting hair whole time',
#  'imagine finally get sink bath put pace maybe even eat left also imagine feel cage cock surrounded bath water reminding always owns enjoy cuck',
#  'hurry weed deficient like three day',
#  'sure get acknowledgement astoundingly tactless generally faggy demand blood oath fo',
#  'ok every night take warm bath drink cup milk see work magic still need loose weight know',
#  'look frying pan case cheap book perhaps silly frying pan likely book',
#  'well uv cause mutation sunscreen like essential thesedays',
#  'lunch online',
#  'know friend already told',
#  'hi princess thank pic pretty',
#  'aiyo u always c ex one dunno abt mei reply first time u reply fast lucky workin huh got bao ur sugardad ah gee',
#  'hi msg office',
#  'thanx e brownie v nice',
#  'geeeee love much barely stand',
#  'gent trying contact last weekend draw show prize guaranteed call claim code k valid hr ppm',
#  'fuck babe miss already know let send money towards net need want crave',
#  'ill call u mrw ninish address icky american freek wont stop callin bad jen k eh',
#  'oooh bed ridden ey thinking',
#  'anyways go gym whatever love smile hope ok good day babe miss much already',
#  'love daddy make scream pleasure going slap as dick',
#  'wot u wanna missy',
#  'yar lor wait mum finish sch lunch lor whole morning stay home clean room room quite clean hee',
#  'know lab goggles went',
#  'open door',
#  'waiting call',
#  'nope waiting sch daddy',
#  'cash prize claim call',
#  'tired arguing week week want',
#  'wait sch finish ard',
#  'mobile number claim call u back ring claim hot line',
#  'arngd marriage u r walkin unfortuntly snake bite u bt love marriage dancing frnt snake amp sayin bite bite',
#  'huh early dinner outside izzit',
#  'ok anyway need change said',
#  'tried contact reply offer min textand new video phone call reply free delivery tomorrow',
#  'ex wife able kid want kid one day',
#  'scotland hope showing jjc tendency take care live dream',
#  'tell u headache want use hour sick time',
#  'dun thk quit yet hmmm go jazz yogasana oso go meet em lesson den',
#  'pete please ring meive hardly gotany credit',
#  'ya srsly better yi tho',
#  'meeting call later',
#  'ur chance win wkly shopping spree txt shop c www txt shop com custcare x p wk',
#  'specially selected receive pound award call line close cost ppm c apply ag promo',
#  'private account statement show un redeemed point call identifier code expires',
#  'still grand prix',
#  'met stranger choose friend long world stand friendship never end let friend forever gud nitz',
#  'great',
#  'gud mrng dear nice day',
#  'important customer service announcement call freephone',
#  'exhausted train morning much wine pie sleep well',
#  'going buy mum present ar',
#  'mind blastin tsunami occur rajnikant stopped swimming indian ocean',
#  'u sending home first ok lor ready yet',
#  'speaking cash yet',
#  'happy come noon',
#  'meet lunch la',
#  'take care n get well soon',
#  'xclusive clubsaisai morow soiree speciale zouk nichols paris free rose lady info',
#  'meant say cant wait see u getting bored bridgwater banter',
#  'neva mind ok',
#  'fine imma get drink somethin want come find',
#  'day kick euro u kept date latest news result daily removed send get txt stop',
#  'valentine game send dis msg ur friend answer r someone really love u ques colour suit best rply',
#  'many dependent',
#  'thanx today cer nice catch ave find time often oh well take care c u soon c',
#  'called said choose future',
#  'happy valentine day know early hundred handsomes beauty wish thought finish aunty uncle st',
#  'like v shock leh co telling shuhui like telling leona also like dat almost know liao got ask abt ur reaction lor',
#  'family happiness',
#  'come n pick come immediately aft ur lesson',
#  'let snow let snow kind weather brings ppl together friendship grow',
#  'dear got lt gt dollar hi hi',
#  'good word word may leave u dismay many time',
#  'make sure alex know birthday fifteen minute far concerned',
#  'sorry got thing may pub later',
#  'nah straight bring bud drink something actually little useful straight cash',
#  'haha good hear officially paid market th',
#  'many lick take get center tootsie pop',
#  'yup thk r e teacher said make face look longer darren ask cut short',
#  'new textbuddy chat horny guy ur area p free receive search postcode gaytextbuddy com txt one name',
#  'today vodafone number ending selected receive award number match call receive award',
#  'please dont say like hi hi hi',
#  'thank u',
#  'oh forwarded message thought send',
#  'got seventeen pound seven hundred ml hope ok',
#  'dear voucher holder claim week offer pc go http www e tlp co uk expressoffer t c apply stop text txt stop',
#  'n funny',
#  'sweetheart hope kind day one load reason smile biola',
#  'login dat time dad fetching home',
#  'shower baby',
#  'askd u question hour answer',
#  'well imma definitely need restock thanksgiving let know',
#  'said kiss kiss sound effect gorgeous man kind person need smile brighten day',
#  'probably gonna swing wee bit',
#  'ya nice ready thursday',
#  'allo braved bus taken train triumphed mean b ham jolly good rest week',
#  'watching cartoon listening music amp eve go temple amp church u',
#  'mind ask happened dont say uncomfortable',
#  'private account statement show un redeemed point call identifier code expires',
#  'prob send email',
#  'cash prize claim call c rstm sw s ppm',
#  'thats cool sometimes slow gentle sonetimes rough hard',
#  'gonna say sorry would normal starting panic time sorry seeing tuesday',
#  'wait know wesley town bet hella drug',
#  'fine miss much',
#  'u got person story',
#  'tell drug dealer getting impatient',
#  'sun cant come earth send luv ray cloud cant come river send luv rain cant come meet u send care msg u gud evng',
#  'place man',
#  'doesnt make sense take unless free need know wikipedia com',
#  'premium phone service call',
#  'sea lay rock rock envelope envelope paper paper word',
#  'mum repent',
#  'sorry going home first daddy come fetch later',
#  'leave de start prepare next',
#  'yes baby study position kama sutra',
#  'en chikku nange bakra msg kalstiya tea coffee',
#  'carlos minute still need buy',
#  'pay lt decimal gt lakh',
#  'good evening ttyl',
#  'u receive msg',
#  'ho ho big belly laugh see ya tomo',
#  'sm ac sun post hello seem cool',
#  'get ur st ringtone free reply msg tone gr top tone phone every week per wk opt send stop',
#  'ditto worry saying anything anymore like said last night whatever want peace',
#  'got lt gt way could pick',
#  'dont knw pa drink milk',
#  'maybe say hi find got card great escape wetherspoons',
#  'piggy r u awake bet u still sleeping going lunch',
#  'cause freaky lol',
#  'missed call cause yelling scrappy miss u wait u come home lonely today',
#  'hex place talk explain',
#  'log wat sdryb',
#  'xy going e lunch',
#  'hi sue year old work lapdancer love sex text live bedroom text sue textoperator g da ppmsg',
#  'wanted ask wait finish lect co lect finish hour anyway',
#  'finished work yet',
#  'every king cry baby every great building map imprtant u r today u wil reach tomorw gud ni',
#  'dear cherthala case u r coming cochin pls call bfore u start shall also reach accordingly tell day u r coming tmorow engaged an holiday',
#  'thanks love torch bold',
#  'forwarded please call immediately urgent message waiting',
#  'farm open',
#  'sorry trouble u buy dad big small sat n sun thanx',
#  'sister law hope great month saying hey abiola',
#  'purchase stuff today mail po box number',
#  'ah poop look like ill prob send laptop get fixed cuz gpu problem',
#  'good good job like entrepreneur',
#  'aight close still around alex place',
#  'meet corporation st outside gap see mind working',
#  'mum ask buy food home',
#  'k u also dont msg reply msg',
#  'much r willing pay',
#  'sorry call later',
#  'important prevent dehydration giving enough fluid',
#  'thats bit weird even supposed happening good idea sure pub',
#  'true dear sat pray evening felt sm time',
#  'think get away trek long family town sorry',
#  'wanna gym harri',
#  'quite late lar ard anyway wun b drivin',
#  'review keep fantastic nokia n gage game deck club nokia go www cnupdates com newsletter unsubscribe alert reply word',
#  'mths half price orange line rental latest camera phone free phone mths call mobilesdirect free update stoptxt c',
#  'height confidence aeronautics professor wer calld amp wer askd sit aeroplane aftr sat wer told dat plane w made student dey hurried plane bt didnt move said made student',
#  'seems like weird timing night g want come smoke day shitstorm attributed always coming making everyone smoke',
#  'pm cost p',
#  'save stress person dorm account send account detail money sent',
#  'also know lunch menu da know',
#  'stuff sell tell',
#  'urgent nd attempt contact u u call b csbcm wc n xx callcost ppm mobilesvary max',
#  'book lesson msg call work sth going get spec membership px',
#  'guaranteed cash prize claim yr prize call customer service representative pm',
#  'macha dont feel upset assume mindset believe one evening wonderful plan u let life begin call anytime',
#  'oh send address',
#  'fine anytime best',
#  'wondar full flim',
#  'ya even cooky jelly',
#  'world running still maybe feeling admit mad correction let call life keep running world may u r also running let run',
#  'got look scrumptious daddy want eat night long',
#  'co lar ba dao ok pm lor u never ask go ah said u would ask fri said u ask today',
#  'alright omw gotta change order half th',
#  'exactly anyways far jide study visiting',
#  'dunno u ask',
#  'email alertfrom jeri stewartsize kbsubject low cost prescripiton drvgsto listen email call',
#  'spring coming early yay',
#  'lol feel bad use money take steak dinner',
#  'even u dont get trouble convincing tel twice tel neglect msg dont c read dont reply',
#  'leaving qatar tonite search opportunity went fast pls add ur prayer dear rakhesh',
#  'one talking',
#  'thanks looking really appreciate',
#  'hi customer loyalty offer new nokia mobile txtauction txt word start get ctxt tc p mtmsg',
#  'wish',
#  'haha mayb u rite u know well da feeling liked someone gd lor u faster go find one gal group attached liao',
#  'yes glad made',
#  'well little time thing good time ahead',
#  'got room soon put clock back til shouted everyone get realised wahay another hour bed',
#  'ok may free gym',
#  'men like shorter lady gaze eye',
#  'dunno jus say go lido time',
#  'promise take good care princess run please send pic get chance ttyl',
#  'u subscribed best mobile content service uk per day send stop helpline',
#  'reason spoken year anyways great week best exam',
#  'monday next week give full gist',
#  'realize year thousand old lady running around tattoo',
#  'important customer service announcement premier',
#  'dont gimme lip caveboy',
#  'get library',
#  'realy sorry recognise number confused r u please',
#  'didnt holla',
#  'cant think anyone spare room top head',
#  'faith make thing possible hope make thing work love make thing beautiful may three christmas merry christmas',
#  'u made appointment',
#  'call carlos phone vibrate acting might hear text',
#  'romantic paris night flight book next year call t c apply',
#  'grandma oh dear u still ill felt shit morning think hungover another night leave sat',
#  'urgent ur guaranteed award still unclaimed call closingdate claimcode pmmorefrommobile bremoved mobypobox l yf',
#  'nothing jus tot u would ask co u ba gua went mt faber yest yest jus went already mah today going jus call lor',
#  'wishing family merry x ma happy new year advance',
#  'ur awarded city break could win summer shopping spree every wk txt store skilgme tscs winawk age perwksub',
#  'nt goin got somethin unless meetin dinner lor haha wonder go ti time',
#  'sorry call later',
#  'cant pick phone right pls send message',
#  'lol know dramatic school already closed tomorrow apparently drive inch snow supposed get',
#  'getting anywhere damn job hunting',
#  'lol u drunkard hair moment yeah still tonight wats plan',
#  'idc get weaseling way shit twice row',
#  'wil lt gt minute got space',
#  'sleeping surfing',
#  'thanks picking trash',
#  'go tell friend sure want live smoke much spend hour begging come smoke',
#  'hi kate lovely see tonight ill phone tomorrow got sing guy gave card xxx',
#  'happy new year dear brother really miss got number decided send text wishing happiness abiola',
#  'mean get door',
#  'opinion jada kusruthi lovable silent spl character matured stylish simple pls reply',
#  'hmmm thought said hour slave late punish',
#  'beerage',
#  'important customer service announcement premier call freephone',
#  'dont think turn like randomlly within min opening',
#  'supposed make still town though',
#  'time fix spelling sometimes get completely diff word go figure',
#  'ever thought living good life perfect partner txt back name age join mobile community p sm',
#  'free top polyphonic tone call national rate get toppoly tune sent every week text subpoly per pole unsub',
#  'gud mrng dear hav nice day',
#  'hoping enjoyed game yesterday sorry touch pls know fondly bein thot great week abiola',
#  'e best ur driving tmr',
#  'u dogbreath sounding like jan c al',
#  'omg want scream weighed lost weight woohoo',
#  'generally one uncountable noun u dictionary piece research',
#  'really getting hanging around',
#  'orange customer may claim free camera phone upgrade loyalty call offer end thmarch c apply opt availa',
#  'petey boy whereare friendsare thekingshead come canlove nic',
#  'ok msg u b leave house',
#  'gimme lt gt minute ago',
#  'last chance claim ur worth discount voucher today text shop savamob offer mobile c savamob pobox uz sub',
#  'appt lt time gt fault u listen told u twice',
#  'free st week nokia tone ur mobile every week txt nokia get txting tell ur mate www getzed co uk pobox w wq norm p tone',
#  'guaranteed award even cashto claim ur award call free stop getstop php rg jx',
#  'k',
#  'dled imp',
#  'sure make sure know smokin yet',
#  'boooo always work quit',
#  'taking half day leave bec well',
#  'ugh wanna get bed warm',
#  'nervous lt gt',
#  'ring come guy costume gift future yowifes hint hint',
#  'congratulation ur awarded either cd gift voucher free entry weekly draw txt music tncs www ldew com win ppmx age',
#  'borrow ur bag ok',
#  'u outbid simonwatson shinco dvd plyr bid visit sm ac smsrewards end bid notification reply end',
#  'boytoy miss happened',
#  'lot used one babe model help youi bring match',
#  'also bringing galileo dobby',
#  'responding',
#  'boo babe u enjoyin yourjob u seemed b gettin well hunny hope ure ok take care llspeak u soonlots loveme xxxx',
#  'good afternoon starshine boytoy crave yet ache fuck sip cappuccino miss babe teasing kiss',
#  'road cant txt',
#  'smsservices yourinclusive text credit pls goto www comuk net login qxj unsubscribe stop extra charge help comuk cm ae',
#  'p alfie moon child need song ur mob tell ur txt tone charity nokias poly charity polys zed profit charity',
#  'good evening ttyl',
#  'hmm bit piece lol sigh',
#  'hahaha use brain dear',
#  'hey got mail',
#  'sorry light turned green meant another friend wanted lt gt worth may around',
#  'thanks yesterday sir wonderful hope enjoyed burial mojibiola',
#  'u secret admirer reveal think u r special call opt reply reveal stop per msg recd cust care',
#  'hi mate rv u hav nice hol message say hello coz sent u age started driving stay road rvx',
#  'dear voucher holder claim week offer pc please go http www e tlp co uk expressoffer t c apply stop text txt stop',
#  'thank much skyped wit kz sura didnt get pleasure company hope good given ultimatum oh countin aburo enjoy message sent day ago',
#  'surely result offer',
#  'good morning dear great amp successful day',
#  'want anytime network min text new video phone five pound per week call reply delivery tomorrow',
#  'sir late paying rent past month pay lt gt charge felt would inconsiderate nag something give great cost didnt speak however recession wont able pay charge month hence askin well ahead month end please help thanks',
#  'tried contact offer new video phone anytime network min half price rental camcorder call reply delivery wed',
#  'last chance claim ur worth discount voucher text yes savamob member offer mobile c sub remove txt x stop',
#  'luv u soo much u understand special u r ring u morrow luv u xxx',
#  'pls send comprehensive mail paying much',
#  'prashanthettan mother passed away last night pray family',
#  'urgent call landline complimentary ibiza holiday cash await collection sae c po box sk wp ppm',
#  'k k going',
#  'meanwhile shit suite xavier decided give u lt gt second warning samantha coming playing jay guitar impress shit also think doug realizes live anymore',
#  'stomach thru much trauma swear eat better lose weight',
#  'office whats matter msg call break',
#  'yeah barely enough room two u x many fucking shoe sorry man see later',
#  'today offer claim ur worth discount voucher text yes savamob member offer mobile c sub unsub reply x',
#  'u reach orchard already u wan go buy ticket first',
#  'real baby want bring inner tigress',
#  'da run activate full version da',
#  'ah poor baby hope urfeeling bettersn luv probthat overdose work hey go careful spk u sn lot lovejen xxx',
#  'stop story told returned saying order',
#  'talk sexy make new friend fall love world discreet text dating service text vip see could meet',
#  'going take babe',
#  'hai ana tomarrow coming morning lt decimal gt ill sathy go rto office reply came home',
#  'spoon okay',
#  'say somebody named tampa',
#  'work going min',
#  'brother genius',
#  'sorry guess whenever get hold connection maybe hour two text',
#  'u find time bus coz need sort stuff',
#  'dude ive seeing lotta corvette lately',
#  'congratulation ur awarded either yr supply cd virgin record mystery gift guaranteed call t c www smsco net pm approx min',
#  'consider wall bunker shit important never play peaceful guess place high enough matter',
#  'private account statement xxxxxx show un redeemed point call identifier code expires',
#  'hello need posh bird chap user trial prod champneys put need address dob asap ta r',
#  'u want xmas free text message new video phone half price line rental call free find',
#  'well officially philosophical hole u wanna call home ready saved',
#  'going good problem still need little experience understand american customer voice',
#  'text drop x',
#  'ugh long day exhausted want cuddle take nap',
#  'talk atleast day otherwise miss best friend world shakespeare shesil lt gt',
#  'shop till u drop either k k cash travel voucher call ntt po box cr bt fixedline cost ppm mobile vary',
#  'castor need see something',
#  'sunshine quiz wkly q win top sony dvd player u know country liverpool played mid week txt ansr sp tyrone',
#  'u secret admirer looking make contact u find r reveal think ur special call',
#  'u secret admirer looking make contact u find r reveal think ur special call stopsms',
#  'reminder downloaded content already paid goto http doit mymoby tv collect content',
#  'see knew giving break time woul lead always wanting miss curfew gonna gibe til one midnight movie gonna get til need come home need getsleep anything need b studdying ear training',
#  'love give massage use lot baby oil fave position',
#  'dude go sup',
#  'yoyyooo u know change permission drive mac usb flash drive',
#  'gibbs unsold mike hussey',
#  'like talk pa able dont know',
#  'dun cut short leh u dun like ah failed quite sad',
#  'unbelievable faglord',
#  'wife knew time murder exactly',
#  'ask princess',
#  'great princess thinking',
#  'nutter cutter ctter cttergg cttargg ctargg ctagg ie',
#  'ok noe u busy really bored msg u oso dunno wat colour choose one',
#  'g class early tomorrow thus trying smoke lt gt',
#  'superb thought grateful u dont everything u want mean u still opportunity happier tomorrow u today',
#  'hope good week checking',
#  'used hope agent drop since booked thing year whole boston nyc experiment',
#  'thursday night yeah sure thing work',
#  'free ringtone waiting collected simply text password mix verify get usher britney fml',
#  'probably money worry thing coming due several outstanding invoice work two three month ago',
#  'possible teach',
#  'wonder phone battery went dead tell love babe',
#  'lovely smell bus tobacco',
#  'getting worried derek taylor already assumed worst',
#  'hey charles sorry late reply',
#  'lastest stereophonics marley dizzee racal libertine stroke win nookii game flirt click themob wap bookmark text wap',
#  'give plus said grinule greet whenever speak',
#  'white fudge oreo store',
#  'january male sale hot gay chat cheaper call national rate p min cheap p min peak stop text call p min',
#  'love come took long leave zaher got word ym happy see sad left miss',
#  'sorry hurt',
#  'feel nauseous pissed eat sweet week cause today planning pig dieting week hungry',
#  'ok lor early still project meeting',
#  'call da waiting call',
#  'could ask carlos could get anybody else chip',
#  'actually send reminder today wonderful weekend',
#  'people see msg think iam addicted msging wrong bcoz know iam addicted sweet friend bslvyl',
#  'hey gave photo registered driving ah tmr wanna meet yck',
#  'dont talk ever ok word',
#  'u wana see',
#  'way school pls send ashley number',
#  'shall fine avalarr hollalater',
#  'went attend another two round today still reach home',
#  'actually deleted old website blogging magicalsongs blogspot com',
#  'k wait chikku il send aftr lt gt min',
#  'diet ate many slice pizza yesterday ugh always diet',
#  'k give kvb acc detail',
#  'oh come ah',
#  'money r lucky winner claim prize text money million give away ppt x normal text rate box w jy',
#  'really sorry b able friday hope u find alternative hope yr term going ok',
#  'congratulation ore mo owo wa enjoy wish many happy moment fro wherever go',
#  'samus shoulder yet',
#  'time think need know near campus',
#  'dear matthew please call landline complimentary lux tenerife holiday cash await collection ppm sae c box sk xh',
#  'dun wear jean lor',
#  'since side fever vomitin',
#  'k k college',
#  'urgent call landline complimentary tenerife holiday cash await collection sae c box hp yf ppm',
#  'better made friday stuffed like pig yesterday feel bleh least writhing pain kind bleh',
#  'sell ton coin sell coin someone thru paypal voila money back life pocket',
#  'theyre lot place hospital medical place safe',
#  'getting touch folk waiting company txt back name age opt enjoy community p sm',
#  'also sorta blown couple time recently id rather text blue looking weed',
#  'sent score sophas secondary application school think thinking applying research cost also contact joke ogunrinde school one le expensive one',
#  'cant wait see photo useful',
#  'ur cash balance currently pound maximize ur cash send go p msg cc po box tcr w',
#  'hey booked kb sat already lesson going ah keep sat night free need meet confirm lodging',
#  'chk ur belovd m dict',
#  'time want come',
#  'awesome lemme know whenever around',
#  'shb b ok lor thanx',
#  'beautiful truth gravity read carefully heart feel light someone feel heavy someone leaf good night',
#  'also remember get dobby bowl car',
#  'filthy story girl waiting',
#  'sorry c ur msg yar lor poor thing one night tmr u brand new room sleep',
#  'love decision feeling could decide love life would much simpler le magical',
#  'welp apparently retired',
#  'sort code acc bank natwest reply confirm sent right person',
#  '',
#  'u sure u take sick time',
#  'urgent trying contact u today draw show prize guaranteed call land line claim valid hr',
#  'watching cartoon listening music amp eve go temple amp church u',
#  'yo chad gymnastics class wanna take site say christian class full',
#  'much buzy',
#  'better still catch let ask sell lt gt',
#  'sure night menu know noon menu',
#  'u want come back beautiful necklace token heart thats give wife liking see one give dont call wait till come',
#  'willing go aptitude class',
#  'wont b trying sort house ok',
#  'yar lor wan go c horse racing today mah eat earlier lor ate chicken rice u',
#  'haha awesome omw back',
#  'yup thk e shop close lor',
#  'account number',
#  'eh u send wrongly lar',
#  'hey ad crap nite borin without ya boggy u boring biatch thanx u wait til nxt time il ave ya',
#  'ok shall talk',
#  'dont hesitate know second time weakness like keep notebook eat day anything changed day sure nothing',
#  'hey pay salary de lt gt',
#  'another month need chocolate weed alcohol',
#  'started searching get job day great potential talent',
#  'reckon need town eightish walk carpark',
#  'congrats mobile g videophones r call videochat wid mate play java game dload polyph music noline rentl',
#  'look fuckin time fuck think',
#  'yo guess dropped',
#  'carlos say mu lt gt minute',
#  'office call lt gt min',
#  'geeee miss already know think fuck wait till next year together loving kiss',
#  'yun ah ubi one say wan call tomorrow call look irene ere got bus ubi cres ubi tech park ph st wkg day n',
#  'ugh gotta drive back sd la butt sore',
#  'th july',
#  'hi im relaxing time ever get every day party good night get home tomorrow ish',
#  'wan come come lor din c stripe skirt',
#  'xmas story peace xmas msg love xmas miracle jesus hav blessed month ahead amp wish u merry xmas',
#  'number',
#  'change e one next escalator',
#  'yetunde class run water make ok pls',
#  'lot happened feel quiet beth aunt charlie working lot helen mo',
#  'wait bus stop aft ur lect lar dun c go get car come back n pick',
#  'aight thanks comin',
#  ...]

# %% [markdown]
# ### gensim model used for word to vector conversion

# %%
import gensim
print(gensim.__version__)
# Out:
# 4.3.3

# %%
import gensim
from nltk import sent_tokenize
from gensim.utils import simple_preprocess

# %% [markdown]
# ##### simple_preprocess()
# ###### Convert a document into a list of lowercase tokens, ignoring tokens that are too short or too long.

# %%
words = []
for sent in corpus:
    sent_token = sent_tokenize(sent)
    for sent in sent_token:
        words.append(simple_preprocess(sent))

# %%
words
# Out:
# [['go',
#   'jurong',
#   'point',
#   'crazy',
#   'available',
#   'bugis',
#   'great',
#   'world',
#   'la',
#   'buffet',
#   'cine',
#   'got',
#   'amore',
#   'wat'],
#  ['ok', 'lar', 'joking', 'wif', 'oni'],
#  ['free',
#   'entry',
#   'wkly',
#   'comp',
#   'win',
#   'fa',
#   'cup',
#   'final',
#   'tkts',
#   'st',
#   'may',
#   'text',
#   'fa',
#   'receive',
#   'entry',
#   'question',
#   'std',
#   'txt',
#   'rate',
#   'apply'],
#  ['dun', 'say', 'early', 'hor', 'already', 'say'],
#  ['nah', 'think', 'go', 'usf', 'life', 'around', 'though'],
#  ['freemsg',
#   'hey',
#   'darling',
#   'week',
#   'word',
#   'back',
#   'like',
#   'fun',
#   'still',
#   'tb',
#   'ok',
#   'xxx',
#   'std',
#   'chgs',
#   'send',
#   'rcv'],
#  ['even', 'brother', 'like', 'speak', 'treat', 'like', 'aid', 'patent'],
#  ['per',
#   'request',
#   'melle',
#   'melle',
#   'oru',
#   'minnaminunginte',
#   'nurungu',
#   'vettam',
#   'set',
#   'callertune',
#   'caller',
#   'press',
#   'copy',
#   'friend',
#   'callertune'],
#  ['winner',
#   'valued',
#   'network',
#   'customer',
#   'selected',
#   'receivea',
#   'prize',
#   'reward',
#   'claim',
#   'call',
#   'claim',
#   'code',
#   'kl',
#   'valid',
#   'hour'],
#  ['mobile',
#   'month',
#   'entitled',
#   'update',
#   'latest',
#   'colour',
#   'mobile',
#   'camera',
#   'free',
#   'call',
#   'mobile',
#   'update',
#   'co',
#   'free'],
#  ['gonna',
#   'home',
#   'soon',
#   'want',
#   'talk',
#   'stuff',
#   'anymore',
#   'tonight',
#   'cried',
#   'enough',
#   'today'],
#  ['six',
#   'chance',
#   'win',
#   'cash',
#   'pound',
#   'txt',
#   'csh',
#   'send',
#   'cost',
#   'day',
#   'day',
#   'tsandcs',
#   'apply',
#   'reply',
#   'hl',
#   'info'],
#  ['urgent',
#   'week',
#   'free',
#   'membership',
#   'prize',
#   'jackpot',
#   'txt',
#   'word',
#   'claim',
#   'www',
#   'dbuk',
#   'net',
#   'lccltd',
#   'pobox',
#   'ldnw',
#   'rw'],
#  ['searching',
#   'right',
#   'word',
#   'thank',
#   'breather',
#   'promise',
#   'wont',
#   'take',
#   'help',
#   'granted',
#   'fulfil',
#   'promise',
#   'wonderful',
#   'blessing',
#   'time'],
#  ['date', 'sunday'],
#  ['use',
#   'credit',
#   'click',
#   'wap',
#   'link',
#   'next',
#   'txt',
#   'message',
#   'click',
#   'http',
#   'wap',
#   'com',
#   'qjkgighjjgcbl'],
#  ['oh', 'watching'],
#  ['eh', 'remember', 'spell', 'name', 'yes', 'naughty', 'make', 'wet'],
#  ['fine', 'way', 'feel', 'way', 'gota'],
#  ['england',
#   'macedonia',
#   'dont',
#   'miss',
#   'goal',
#   'team',
#   'news',
#   'txt',
#   'ur',
#   'national',
#   'team',
#   'eg',
#   'england',
#   'try',
#   'wale',
#   'scotland',
#   'txt',
#   'poboxox',
#   'wq'],
#  ['seriously', 'spell', 'name'],
#  ['going', 'try', 'month', 'ha', 'ha', 'joking'],
#  ['pay', 'first', 'lar', 'da', 'stock', 'comin'],
#  ['aft',
#   'finish',
#   'lunch',
#   'go',
#   'str',
#   'lor',
#   'ard',
#   'smth',
#   'lor',
#   'finish',
#   'ur',
#   'lunch',
#   'already'],
#  ['ffffffffff', 'alright', 'way', 'meet', 'sooner'],
#  ['forced',
#   'eat',
#   'slice',
#   'really',
#   'hungry',
#   'tho',
#   'suck',
#   'mark',
#   'getting',
#   'worried',
#   'know',
#   'sick',
#   'turn',
#   'pizza',
#   'lol'],
#  ['lol', 'always', 'convincing'],
#  ['catch',
#   'bus',
#   'frying',
#   'egg',
#   'make',
#   'tea',
#   'eating',
#   'mom',
#   'left',
#   'dinner',
#   'feel',
#   'love'],
#  ['back', 'amp', 'packing', 'car', 'let', 'know', 'room'],
#  ['ahhh', 'work', 'vaguely', 'remember', 'feel', 'like', 'lol'],
#  ['wait', 'still', 'clear', 'sure', 'sarcastic', 'want', 'live'],
#  ['yeah',
#   'got',
#   'apologetic',
#   'fallen',
#   'actin',
#   'like',
#   'spoilt',
#   'child',
#   'got',
#   'caught',
#   'till',
#   'go',
#   'badly',
#   'cheer'],
#  ['tell', 'anything'],
#  ['fear', 'fainting', 'housework', 'quick', 'cuppa'],
#  ['thanks',
#   'subscription',
#   'ringtone',
#   'uk',
#   'mobile',
#   'charged',
#   'month',
#   'please',
#   'confirm',
#   'replying',
#   'yes',
#   'reply',
#   'charged'],
#  ['yup',
#   'ok',
#   'go',
#   'home',
#   'look',
#   'timing',
#   'msg',
#   'xuhui',
#   'going',
#   'learn',
#   'nd',
#   'may',
#   'lesson'],
#  ['oops', 'let', 'know', 'roommate', 'done'],
#  ['see', 'letter', 'car'],
#  ['anything', 'lor', 'decide'],
#  ['hello',
#   'saturday',
#   'go',
#   'texting',
#   'see',
#   'decided',
#   'anything',
#   'tomo',
#   'trying',
#   'invite',
#   'anything'],
#  ['pls',
#   'go',
#   'ahead',
#   'watt',
#   'wanted',
#   'sure',
#   'great',
#   'weekend',
#   'abiola'],
#  ['forget',
#   'tell',
#   'want',
#   'need',
#   'crave',
#   'love',
#   'sweet',
#   'arabian',
#   'steed',
#   'mmmmmm',
#   'yummy'],
#  ['rodger',
#   'burn',
#   'msg',
#   'tried',
#   'call',
#   'reply',
#   'sm',
#   'free',
#   'nokia',
#   'mobile',
#   'free',
#   'camcorder',
#   'please',
#   'call',
#   'delivery',
#   'tomorrow'],
#  ['seeing'],
#  ['great', 'hope', 'like', 'man', 'well', 'endowed', 'lt', 'gt', 'inch'],
#  ['call', 'message', 'missed', 'call'],
#  ['get', 'hep', 'immunisation', 'nigeria'],
#  ['fair', 'enough', 'anything', 'going'],
#  ['yeah', 'hopefully', 'tyler', 'could', 'maybe', 'ask', 'around', 'bit'],
#  ['know',
#   'stubborn',
#   'even',
#   'want',
#   'go',
#   'hospital',
#   'kept',
#   'telling',
#   'mark',
#   'weak',
#   'sucker',
#   'hospital',
#   'weak',
#   'sucker'],
#  ['thinked', 'first', 'time', 'saw', 'class'],
#  ['gram',
#   'usually',
#   'run',
#   'like',
#   'lt',
#   'gt',
#   'half',
#   'eighth',
#   'smarter',
#   'though',
#   'get',
#   'almost',
#   'whole',
#   'second',
#   'gram',
#   'lt',
#   'gt'],
#  ['fyi',
#   'ride',
#   'early',
#   'tomorrow',
#   'morning',
#   'crashing',
#   'place',
#   'tonight'],
#  ['wow',
#   'never',
#   'realized',
#   'embarassed',
#   'accomodations',
#   'thought',
#   'liked',
#   'since',
#   'best',
#   'could',
#   'always',
#   'seemed',
#   'happy',
#   'cave',
#   'sorry',
#   'give',
#   'sorry',
#   'offered',
#   'sorry',
#   'room',
#   'embarassing'],
#  ['sm',
#   'ac',
#   'sptv',
#   'new',
#   'jersey',
#   'devil',
#   'detroit',
#   'red',
#   'wing',
#   'play',
#   'ice',
#   'hockey',
#   'correct',
#   'incorrect',
#   'end',
#   'reply',
#   'end',
#   'sptv'],
#  ['know', 'mallika', 'sherawat', 'yesterday', 'find', 'lt', 'url', 'gt'],
#  ['congrats',
#   'year',
#   'special',
#   'cinema',
#   'pas',
#   'call',
#   'suprman',
#   'matrix',
#   'starwars',
#   'etc',
#   'free',
#   'bx',
#   'ip',
#   'pm',
#   'dont',
#   'miss'],
#  ['sorry', 'call', 'later', 'meeting'],
#  ['tell', 'reached'],
#  ['yes', 'gauti', 'sehwag', 'odi', 'series'],
#  ['gonna', 'pick', 'burger', 'way', 'home', 'even', 'move', 'pain', 'killing'],
#  ['ha', 'ha', 'ha', 'good', 'joke', 'girl', 'situation', 'seeker'],
#  ['part', 'checking', 'iq'],
#  ['sorry', 'roommate', 'took', 'forever', 'ok', 'come'],
#  ['ok',
#   'lar',
#   'double',
#   'check',
#   'wif',
#   'da',
#   'hair',
#   'dresser',
#   'already',
#   'said',
#   'wun',
#   'cut',
#   'short',
#   'said',
#   'cut',
#   'look',
#   'nice'],
#  ['valued',
#   'customer',
#   'pleased',
#   'advise',
#   'following',
#   'recent',
#   'review',
#   'mob',
#   'awarded',
#   'bonus',
#   'prize',
#   'call'],
#  ['today',
#   'song',
#   'dedicated',
#   'day',
#   'song',
#   'dedicate',
#   'send',
#   'ur',
#   'valuable',
#   'frnds',
#   'first',
#   'rply'],
#  ['urgent',
#   'ur',
#   'awarded',
#   'complimentary',
#   'trip',
#   'eurodisinc',
#   'trav',
#   'aco',
#   'entry',
#   'claim',
#   'txt',
#   'dis',
#   'morefrmmob',
#   'aj'],
#  ['hear', 'new', 'divorce', 'barbie', 'come', 'ken', 'stuff'],
#  ['plane', 'give', 'month', 'end'],
#  ['wah', 'lucky', 'man', 'save', 'money', 'hee'],
#  ['finished', 'class'],
#  ['hi', 'babe', 'im', 'home', 'wanna', 'something', 'xx'],
#  ['performed'],
#  ['call'],
#  ['waiting', 'machan', 'call', 'free'],
#  ['thats', 'cool', 'gentleman', 'treat', 'dignity', 'respect'],
#  ['like', 'people', 'much', 'shy', 'pa'],
#  ['operate', 'lt', 'gt'],
#  ['still', 'looking', 'job', 'much', 'ta', 'earn'],
#  ['sorry', 'call', 'later'],
#  ['call', 'ah'],
#  ['ok', 'way', 'home', 'hi', 'hi'],
#  ['place', 'man'],
#  ['yup', 'next', 'stop'],
#  ['call', 'later', 'network', 'urgnt', 'sm'],
#  ['real',
#   'getting',
#   'yo',
#   'need',
#   'ticket',
#   'one',
#   'jacket',
#   'done',
#   'already',
#   'used',
#   'multis'],
#  ['yes',
#   'started',
#   'send',
#   'request',
#   'make',
#   'pain',
#   'came',
#   'back',
#   'back',
#   'bed',
#   'double',
#   'coin',
#   'factory',
#   'gotta',
#   'cash',
#   'nitros'],
#  ['really', 'still', 'tonight', 'babe'],
#  ['ela', 'kano', 'il', 'download', 'come', 'wen', 'ur', 'free'],
#  ['yeah', 'stand', 'close', 'tho', 'catch', 'something'],
#  ['sorry',
#   'pain',
#   'ok',
#   'meet',
#   'another',
#   'night',
#   'spent',
#   'late',
#   'afternoon',
#   'casualty',
#   'mean',
#   'done',
#   'stuff',
#   'moro',
#   'includes',
#   'time',
#   'sheet',
#   'sorry'],
#  ['smile',
#   'pleasure',
#   'smile',
#   'pain',
#   'smile',
#   'trouble',
#   'pours',
#   'like',
#   'rain',
#   'smile',
#   'sum',
#   'hurt',
#   'smile',
#   'becoz',
#   'someone',
#   'still',
#   'love',
#   'see',
#   'smiling'],
#  ['please',
#   'call',
#   'customer',
#   'service',
#   'representative',
#   'pm',
#   'guaranteed',
#   'cash',
#   'prize'],
#  ['havent',
#   'planning',
#   'buy',
#   'later',
#   'check',
#   'already',
#   'lido',
#   'got',
#   'show',
#   'afternoon',
#   'finish',
#   'work',
#   'already'],
#  ['free',
#   'ringtone',
#   'waiting',
#   'collected',
#   'simply',
#   'text',
#   'password',
#   'mix',
#   'verify',
#   'get',
#   'usher',
#   'britney',
#   'fml'],
#  ['watching', 'telugu', 'movie', 'wat', 'abt'],
#  ['see', 'finish', 'load', 'loan', 'pay'],
#  ['hi',
#   'wk',
#   'ok',
#   'hols',
#   'yes',
#   'bit',
#   'run',
#   'forgot',
#   'hairdresser',
#   'appointment',
#   'four',
#   'need',
#   'get',
#   'home',
#   'shower',
#   'beforehand',
#   'cause',
#   'prob',
#   'ham'],
#  ['please', 'text', 'anymore', 'nothing', 'else', 'say'],
#  ['okay',
#   'name',
#   'ur',
#   'price',
#   'long',
#   'legal',
#   'wen',
#   'pick',
#   'ave',
#   'am',
#   'xx'],
#  ['still', 'looking', 'car', 'buy', 'gone', 'driving', 'test', 'yet'],
#  ['per',
#   'request',
#   'melle',
#   'melle',
#   'oru',
#   'minnaminunginte',
#   'nurungu',
#   'vettam',
#   'set',
#   'callertune',
#   'caller',
#   'press',
#   'copy',
#   'friend',
#   'callertune'],
#  ['wow',
#   'right',
#   'mean',
#   'guess',
#   'gave',
#   'boston',
#   'men',
#   'changed',
#   'search',
#   'location',
#   'nyc',
#   'something',
#   'changed',
#   'cuz',
#   'signin',
#   'page',
#   'still',
#   'say',
#   'boston'],
#  ['umma', 'life', 'vava', 'umma', 'love', 'lot', 'dear'],
#  ['thanks',
#   'lot',
#   'wish',
#   'birthday',
#   'thanks',
#   'making',
#   'birthday',
#   'truly',
#   'memorable'],
#  ['aight', 'hit', 'get', 'cash'],
#  ['would',
#   'ip',
#   'address',
#   'test',
#   'considering',
#   'computer',
#   'minecraft',
#   'server'],
#  ['know',
#   'grumpy',
#   'old',
#   'people',
#   'mom',
#   'like',
#   'better',
#   'lying',
#   'always',
#   'one',
#   'play',
#   'joke'],
#  ['dont', 'worry', 'guess', 'busy'],
#  ['plural', 'noun', 'research'],
#  ['going', 'dinner', 'msg'],
#  ['ok',
#   'wif',
#   'co',
#   'like',
#   'try',
#   'new',
#   'thing',
#   'scared',
#   'dun',
#   'like',
#   'mah',
#   'co',
#   'said',
#   'loud'],
#  ['gent',
#   'trying',
#   'contact',
#   'last',
#   'weekend',
#   'draw',
#   'show',
#   'prize',
#   'guaranteed',
#   'call',
#   'claim',
#   'code',
#   'valid',
#   'hr',
#   'ppm'],
#  ['wa',
#   'ur',
#   'openin',
#   'sentence',
#   'formal',
#   'anyway',
#   'fine',
#   'juz',
#   'tt',
#   'eatin',
#   'much',
#   'puttin',
#   'weight',
#   'haha',
#   'anythin',
#   'special',
#   'happened'],
#  ['entered',
#   'cabin',
#   'pa',
#   'said',
#   'happy',
#   'day',
#   'bos',
#   'felt',
#   'special',
#   'askd',
#   'lunch',
#   'lunch',
#   'invited',
#   'apartment',
#   'went'],
#  ['winner',
#   'specially',
#   'selected',
#   'receive',
#   'holiday',
#   'flight',
#   'inc',
#   'speak',
#   'live',
#   'operator',
#   'claim',
#   'min'],
#  ['goodo',
#   'yes',
#   'must',
#   'speak',
#   'friday',
#   'egg',
#   'potato',
#   'ratio',
#   'tortilla',
#   'needed'],
#  ['hmm',
#   'uncle',
#   'informed',
#   'paying',
#   'school',
#   'directly',
#   'pls',
#   'buy',
#   'food'],
#  ['private',
#   'account',
#   'statement',
#   'show',
#   'unredeemed',
#   'bonus',
#   'point',
#   'claim',
#   'call',
#   'identifier',
#   'code',
#   'expires'],
#  ['urgent',
#   'mobile',
#   'awarded',
#   'bonus',
#   'caller',
#   'prize',
#   'final',
#   'try',
#   'contact',
#   'call',
#   'landline',
#   'box',
#   'wr',
#   'ppm'],
#  ['new', 'address', 'apple', 'pair', 'malarky'],
#  ['today',
#   'voda',
#   'number',
#   'ending',
#   'selected',
#   'receive',
#   'award',
#   'match',
#   'please',
#   'call',
#   'quoting',
#   'claim',
#   'code',
#   'standard',
#   'rate',
#   'app'],
#  ['going', 'sao', 'mu', 'today', 'done'],
#  ['predict', 'wat', 'time', 'finish', 'buying'],
#  ['good', 'stuff'],
#  ['know',
#   'yetunde',
#   'sent',
#   'money',
#   'yet',
#   'sent',
#   'text',
#   'bother',
#   'sending',
#   'dont',
#   'involve',
#   'anything',
#   'imposed',
#   'anything',
#   'first',
#   'place',
#   'apologise'],
#  ['room'],
#  ['hey',
#   'girl',
#   'hope',
#   'well',
#   'del',
#   'bak',
#   'long',
#   'time',
#   'give',
#   'call',
#   'sum',
#   'time',
#   'lucyxx'],
#  ['much', 'cost'],
#  ['home'],
#  ['dear', 'call', 'tmorrow', 'pls', 'accomodate'],
#  ['first', 'answer', 'question'],
#  ['sunshine',
#   'quiz',
#   'wkly',
#   'win',
#   'top',
#   'sony',
#   'dvd',
#   'player',
#   'know',
#   'country',
#   'algarve',
#   'txt',
#   'ansr',
#   'sp',
#   'tyrone'],
#  ['want',
#   'get',
#   'laid',
#   'tonight',
#   'want',
#   'real',
#   'dogging',
#   'location',
#   'sent',
#   'direct',
#   'ur',
#   'mob',
#   'join',
#   'uk',
#   'largest',
#   'dogging',
#   'network',
#   'bt',
#   'txting',
#   'gravel',
#   'nt',
#   'ec',
#   'msg'],
#  ['haf', 'msn', 'yijue', 'hotmail', 'com'],
#  ['call', 'meet'],
#  ['check', 'room', 'befor', 'activity'],
#  ['rcv',
#   'msg',
#   'chat',
#   'svc',
#   'free',
#   'hardcore',
#   'service',
#   'text',
#   'go',
#   'get',
#   'nothing',
#   'must',
#   'age',
#   'verify',
#   'yr',
#   'network',
#   'try'],
#  ['got', 'lazy', 'type', 'forgot', 'lect', 'saw', 'pouch', 'like', 'nice'],
#  ['text', 'way'],
#  ['sir', 'waiting', 'mail'],
#  ['swt',
#   'thought',
#   'nver',
#   'get',
#   'tired',
#   'little',
#   'thing',
#   'lovable',
#   'person',
#   'coz',
#   'somtimes',
#   'little',
#   'thing',
#   'occupy',
#   'biggest',
#   'part',
#   'heart',
#   'gud',
#   'ni'],
#  ['know', 'pls', 'open', 'back'],
#  ['yes', 'see', 'ya', 'dot'],
#  ['whats', 'staff', 'name', 'taking', 'class'],
#  ['freemsg',
#   'replied',
#   'text',
#   'randy',
#   'sexy',
#   'female',
#   'live',
#   'local',
#   'luv',
#   'hear',
#   'netcollex',
#   'ltd',
#   'per',
#   'msg',
#   'reply',
#   'stop',
#   'end'],
#  ['ummma', 'call', 'check', 'life', 'begin', 'qatar', 'pls', 'pray', 'hard'],
#  ['deleted', 'contact'],
#  ['sindu', 'got', 'job', 'birla', 'soft'],
#  ['wine', 'flowing', 'nevering'],
#  ['yup', 'thk', 'cine', 'better', 'co', 'need', 'go', 'plaza', 'mah'],
#  ['ok', 'ur', 'typical', 'reply'],
#  ['per',
#   'request',
#   'melle',
#   'melle',
#   'oru',
#   'minnaminunginte',
#   'nurungu',
#   'vettam',
#   'set',
#   'callertune',
#   'caller',
#   'press',
#   'copy',
#   'friend',
#   'callertune'],
#  ['everywhere',
#   'dirt',
#   'floor',
#   'window',
#   'even',
#   'shirt',
#   'sometimes',
#   'open',
#   'mouth',
#   'come',
#   'flowing',
#   'dream',
#   'world',
#   'without',
#   'half',
#   'chore',
#   'time',
#   'joy',
#   'lot',
#   'tv',
#   'show',
#   'see',
#   'guess',
#   'like',
#   'thing',
#   'must',
#   'exist',
#   'like',
#   'rain',
#   'hail',
#   'mist',
#   'time',
#   'done',
#   'become',
#   'one'],
#  ['aaooooright', 'work'],
#  ['leaving', 'house'],
#  ['hello',
#   'love',
#   'get',
#   'interview',
#   'today',
#   'happy',
#   'good',
#   'boy',
#   'think',
#   'missing'],
#  ['customer',
#   'service',
#   'annoncement',
#   'new',
#   'year',
#   'delivery',
#   'waiting',
#   'please',
#   'call',
#   'arrange',
#   'delivery'],
#  ['winner',
#   'specially',
#   'selected',
#   'receive',
#   'cash',
#   'holiday',
#   'flight',
#   'inc',
#   'speak',
#   'live',
#   'operator',
#   'claim'],
#  ['keep',
#   'safe',
#   'need',
#   'miss',
#   'already',
#   'envy',
#   'everyone',
#   'see',
#   'real',
#   'life'],
#  ['new', 'car', 'house', 'parent', 'new', 'job', 'hand'],
#  ['love', 'excited', 'day', 'spend', 'make', 'happy'],
#  ['pls',
#   'stop',
#   'bootydelious',
#   'inviting',
#   'friend',
#   'reply',
#   'yes',
#   'see',
#   'www',
#   'sm',
#   'ac',
#   'bootydelious',
#   'stop',
#   'send',
#   'stop',
#   'frnd'],
#  ['bangbabes',
#   'ur',
#   'order',
#   'way',
#   'receive',
#   'service',
#   'msg',
#   'download',
#   'ur',
#   'content',
#   'goto',
#   'wap',
#   'bangb',
#   'tv',
#   'ur',
#   'mobile',
#   'internet',
#   'service',
#   'menu'],
#  ['place', 'ur', 'point', 'culture', 'module', 'already'],
#  ['urgent',
#   'trying',
#   'contact',
#   'last',
#   'weekend',
#   'draw',
#   'show',
#   'prize',
#   'guaranteed',
#   'call',
#   'claim',
#   'code',
#   'valid',
#   'hr'],
#  ['hi',
#   'frnd',
#   'best',
#   'way',
#   'avoid',
#   'missunderstding',
#   'wit',
#   'beloved',
#   'one'],
#  ['great', 'escape', 'fancy', 'bridge', 'need', 'lager', 'see', 'tomo'],
#  ['yes', 'completely', 'form', 'clark', 'also', 'utter', 'waste'],
#  ['sir', 'need', 'axis', 'bank', 'account', 'bank', 'address'],
#  ['hmmm',
#   'thk',
#   'sure',
#   'got',
#   'time',
#   'hop',
#   'ard',
#   'ya',
#   'go',
#   'free',
#   'abt',
#   'muz',
#   'call',
#   'discus',
#   'liao'],
#  ['time', 'coming', 'later'],
#  ['bloody',
#   'hell',
#   'cant',
#   'believe',
#   'forgot',
#   'surname',
#   'mr',
#   'ill',
#   'give',
#   'clue',
#   'spanish',
#   'begin'],
#  ['well', 'gonna', 'finish', 'bath', 'good', 'fine', 'night'],
#  ['let', 'know', 'got', 'money', 'carlos', 'make', 'call'],
#  ['still', 'going', 'mall'],
#  ['turn',
#   'friend',
#   'staying',
#   'whole',
#   'show',
#   'back',
#   'til',
#   'lt',
#   'gt',
#   'feel',
#   'free',
#   'go',
#   'ahead',
#   'smoke',
#   'lt',
#   'gt',
#   'worth'],
#  ['text', 'doesnt', 'reply', 'let', 'know', 'log'],
#  ['hi',
#   'spoke',
#   'maneesha',
#   'like',
#   'know',
#   'satisfied',
#   'experience',
#   'reply',
#   'toll',
#   'free',
#   'yes'],
#  ['lifted',
#   'hope',
#   'offer',
#   'money',
#   'need',
#   'especially',
#   'end',
#   'month',
#   'approach',
#   'hurt',
#   'studying',
#   'anyways',
#   'gr',
#   'weekend'],
#  ['lol', 'trust'],
#  ['ok', 'gentleman', 'treat', 'dignity', 'respect'],
#  ['guy', 'close'],
#  ['going', 'nothing', 'great', 'bye'],
#  ['hello',
#   'handsome',
#   'finding',
#   'job',
#   'lazy',
#   'working',
#   'towards',
#   'getting',
#   'back',
#   'net',
#   'mummy',
#   'boytoy',
#   'miss'],
#  ['haha', 'awesome', 'minute'],
#  ['please',
#   'call',
#   'customer',
#   'service',
#   'representative',
#   'freephone',
#   'pm',
#   'guaranteed',
#   'cash',
#   'prize'],
#  ['got', 'xmas', 'radio', 'time', 'get'],
#  ['jus',
#   'reached',
#   'home',
#   'go',
#   'bathe',
#   'first',
#   'si',
#   'using',
#   'net',
#   'tell',
#   'finish'],
#  ['unique',
#   'enough',
#   'find',
#   'th',
#   'august',
#   'www',
#   'areyouunique',
#   'co',
#   'uk'],
#  ['sorry',
#   'joined',
#   'league',
#   'people',
#   'dont',
#   'keep',
#   'touch',
#   'mean',
#   'great',
#   'deal',
#   'friend',
#   'time',
#   'even',
#   'great',
#   'personal',
#   'cost',
#   'great',
#   'week'],
#  ['hi', 'finally', 'completed', 'course'],
#  ['stop',
#   'however',
#   'suggest',
#   'stay',
#   'someone',
#   'able',
#   'give',
#   'or',
#   'every',
#   'stool'],
#  ['hope', 'settled', 'new', 'school', 'year', 'wishin', 'gr', 'day'],
#  ['gud', 'mrng', 'dear', 'hav', 'nice', 'day'],
#  ['got', 'person', 'story'],
#  ['hamster', 'dead', 'hey', 'tmr', 'meet', 'pm', 'orchard', 'mrt'],
#  ['hi',
#   'kate',
#   'evening',
#   'hope',
#   'see',
#   'tomorrow',
#   'bit',
#   'bloody',
#   'babyjontet',
#   'txt',
#   'back',
#   'xxx'],
#  ['found', 'enc', 'lt', 'gt'],
#  ['sent', 'lt', 'gt', 'buck'],
#  ['hello',
#   'darlin',
#   'ive',
#   'finished',
#   'college',
#   'txt',
#   'finish',
#   'love',
#   'kate',
#   'xxx'],
#  ['account',
#   'refilled',
#   'successfully',
#   'inr',
#   'lt',
#   'decimal',
#   'gt',
#   'keralacircle',
#   'prepaid',
#   'account',
#   'balance',
#   'lt',
#   'decimal',
#   'gt',
#   'transaction',
#   'id',
#   'kr',
#   'lt',
#   'gt'],
#  ['goodmorning', 'sleeping', 'ga'],
#  ['call', 'alter', 'ok'],
#  ['say',
#   'like',
#   'dat',
#   'dun',
#   'buy',
#   'ericsson',
#   'oso',
#   'cannot',
#   'oredi',
#   'lar'],
#  ['entered',
#   'cabin',
#   'pa',
#   'said',
#   'happy',
#   'day',
#   'bos',
#   'felt',
#   'special',
#   'askd',
#   'lunch',
#   'lunch',
#   'invited',
#   'apartment',
#   'went'],
#  ['aight', 'yo', 'dat', 'straight', 'dogg'],
#  ['please',
#   'give',
#   'connection',
#   'today',
#   'lt',
#   'decimal',
#   'gt',
#   'refund',
#   'bill'],
#  ['shoot', 'big', 'load', 'get', 'ready'],
#  ['bruv', 'hope', 'great', 'break', 'rewarding', 'semester'],
#  ['home', 'always', 'chat'],
#  ['good', 'study', 'well'],
#  ['yup', 'noe', 'leh'],
#  ['sound', 'great', 'home'],
#  ['finally', 'match', 'heading', 'towards', 'draw', 'prediction'],
#  ['tired', 'slept', 'well', 'past', 'night'],
#  ['easy', 'ah', 'sen', 'got', 'selected', 'mean', 'good'],
#  ['take', 'exam', 'march'],
#  ['yeah',
#   'think',
#   'use',
#   'gt',
#   'atm',
#   'register',
#   'sure',
#   'anyway',
#   'help',
#   'let',
#   'know',
#   'sure',
#   'ready'],
#  ['ok', 'prob', 'take', 'ur', 'time'],
#  ['called',
#   'ubandu',
#   'run',
#   'without',
#   'installing',
#   'hard',
#   'disk',
#   'use',
#   'copy',
#   'important',
#   'file',
#   'system',
#   'give',
#   'repair',
#   'shop'],
#  ['sorry', 'call', 'later'],
#  ['say',
#   'leh',
#   'course',
#   'nothing',
#   'happen',
#   'lar',
#   'say',
#   'romantic',
#   'jus',
#   'bit',
#   'lor',
#   'thk',
#   'nite',
#   'scenery',
#   'nice',
#   'leh'],
#  ['new',
#   'mobile',
#   'must',
#   'go',
#   'txt',
#   'nokia',
#   'collect',
#   'today',
#   'www',
#   'tc',
#   'biz',
#   'optout',
#   'gbp',
#   'mtmsg'],
#  ['would', 'really', 'appreciate', 'call', 'need', 'someone', 'talk'],
#  ['meet',
#   'ur',
#   'dream',
#   'partner',
#   'soon',
#   'ur',
#   'career',
#   'flyng',
#   'start',
#   'find',
#   'free',
#   'txt',
#   'horo',
#   'followed',
#   'ur',
#   'star',
#   'sign',
#   'horo',
#   'aries'],
#  ['hey', 'company', 'elama', 'po', 'mudyadhu'],
#  ['life',
#   'strict',
#   'teacher',
#   'bcoz',
#   'teacher',
#   'teach',
#   'lesson',
#   'amp',
#   'conduct',
#   'exam',
#   'life',
#   'first',
#   'conduct',
#   'exam',
#   'amp',
#   'teach',
#   'lesson',
#   'happy',
#   'morning'],
#  ['dear', 'good', 'morning'],
#  ['get',
#   'gandhipuram',
#   'walk',
#   'cross',
#   'cut',
#   'road',
#   'right',
#   'side',
#   'lt',
#   'gt',
#   'street',
#   'road',
#   'turn',
#   'first',
#   'right'],
#  ['dear', 'going', 'rubber', 'place'],
#  ['sorry', 'battery', 'died', 'yeah'],
#  ['yes', 'tv', 'always', 'available', 'work', 'place'],
#  ['text',
#   'meet',
#   'someone',
#   'sexy',
#   'today',
#   'find',
#   'date',
#   'even',
#   'flirt',
#   'join',
#   'reply',
#   'name',
#   'age',
#   'eg',
#   'sam',
#   'msg',
#   'recd',
#   'thirtyeight',
#   'penny'],
#  ['printed', 'oh', 'lt', 'gt', 'come', 'upstairs'],
#  ['ill', 'little', 'closer', 'like', 'bus', 'stop', 'street'],
#  ['wil', 'reach'],
#  ['new',
#   'theory',
#   'argument',
#   'win',
#   'situation',
#   'loses',
#   'person',
#   'dont',
#   'argue',
#   'ur',
#   'friend',
#   'kick',
#   'amp',
#   'say',
#   'always',
#   'correct'],
#  ['secret',
#   'admirer',
#   'looking',
#   'make',
#   'contact',
#   'find',
#   'reveal',
#   'think',
#   'ur',
#   'special',
#   'call'],
#  ['tomarrow', 'final', 'hearing', 'laptop', 'case', 'cant'],
#  ['tel', 'avent', 'done', 'sportsx'],
#  ['okay', 'shining', 'meant', 'signing', 'sound', 'better'],
#  ['although',
#   'told',
#   'dat',
#   'baig',
#   'face',
#   'watch',
#   'really',
#   'like',
#   'watch',
#   'gave',
#   'co',
#   'fr',
#   'thanx',
#   'everything',
#   'dat',
#   'done',
#   'today',
#   'touched'],
#  ['remember', 'old', 'commercial'],
#  ['late', 'said', 'website', 'dont', 'slipper'],
#  ['asked', 'call', 'ok'],
#  ['kallis', 'wont', 'bat', 'nd', 'inning'],
#  ['didnt',
#   'work',
#   'oh',
#   'ok',
#   'goodnight',
#   'fix',
#   'ready',
#   'time',
#   'wake',
#   'dearly',
#   'missed',
#   'good',
#   'night',
#   'sleep'],
#  ['congratulation',
#   'ur',
#   'awarded',
#   'cd',
#   'voucher',
#   'gift',
#   'guaranteed',
#   'free',
#   'entry',
#   'wkly',
#   'draw',
#   'txt',
#   'music',
#   'tncs',
#   'www',
#   'ldew',
#   'com',
#   'win',
#   'ppmx',
#   'age'],
#  ['ranjith', 'cal', 'drpd', 'deeraj', 'deepak', 'min', 'hold'],
#  ['wen',
#   'ur',
#   'lovable',
#   'bcums',
#   'angry',
#   'wid',
#   'dnt',
#   'take',
#   'seriously',
#   'coz',
#   'angry',
#   'childish',
#   'true',
#   'way',
#   'showing',
#   'deep',
#   'affection',
#   'care',
#   'luv',
#   'kettoda',
#   'manda',
#   'nice',
#   'day',
#   'da'],
#  ['ups',
#   'day',
#   'also',
#   'shipping',
#   'company',
#   'take',
#   'wks',
#   'way',
#   'usps',
#   'take',
#   'week',
#   'get',
#   'lag',
#   'may',
#   'bribe',
#   'nipost',
#   'get',
#   'stuff'],
#  ['back', 'lemme', 'know', 'ready'],
#  ['necessarily', 'expect', 'done', 'get', 'back', 'though', 'headin'],
#  ['mmm', 'yummy', 'babe', 'nice', 'jolt', 'suzy'],
#  ['lover', 'need'],
#  ['tried',
#   'contact',
#   'reply',
#   'offer',
#   'video',
#   'handset',
#   'anytime',
#   'network',
#   'min',
#   'unlimited',
#   'text',
#   'camcorder',
#   'reply',
#   'call'],
#  ['parked', 'next', 'mini', 'coming', 'today', 'think'],
#  ['yup'],
#  ['anyway',
#   'going',
#   'shopping',
#   'co',
#   'si',
#   'done',
#   'yet',
#   'dun',
#   'disturb',
#   'liao'],
#  ['luton', 'ring', 'ur', 'around'],
#  ['hey',
#   'really',
#   'horny',
#   'want',
#   'chat',
#   'see',
#   'naked',
#   'text',
#   'hot',
#   'text',
#   'charged',
#   'pm',
#   'unsubscribe',
#   'text',
#   'stop'],
#  ['dint', 'come'],
#  ['wana', 'plan', 'trip', 'sometme'],
#  ['sure', 'yet', 'still', 'trying', 'get', 'hold'],
#  ['ur',
#   'ringtone',
#   'service',
#   'changed',
#   'free',
#   'credit',
#   'go',
#   'club',
#   'mobile',
#   'com',
#   'choose',
#   'content',
#   'stop',
#   'txt',
#   'club',
#   'stop',
#   'wk',
#   'club',
#   'po',
#   'box',
#   'mk',
#   'wt'],
#  ['evo', 'download', 'flash', 'jealous'],
#  ['ringtone',
#   'club',
#   'get',
#   'uk',
#   'single',
#   'chart',
#   'mobile',
#   'week',
#   'choose',
#   'top',
#   'quality',
#   'ringtone',
#   'message',
#   'free',
#   'charge'],
#  ['come', 'mu', 'sorting', 'narcotic', 'situation'],
#  ['night',
#   'ended',
#   'another',
#   'day',
#   'morning',
#   'come',
#   'special',
#   'way',
#   'may',
#   'smile',
#   'like',
#   'sunny',
#   'ray',
#   'leaf',
#   'worry',
#   'blue',
#   'blue',
#   'bay'],
#  ['hmv',
#   'bonus',
#   'special',
#   'pound',
#   'genuine',
#   'hmv',
#   'voucher',
#   'answer',
#   'easy',
#   'question',
#   'play',
#   'send',
#   'hmv',
#   'info',
#   'www',
#   'percent',
#   'real',
#   'com'],
#  ['usf', 'guess', 'might', 'well', 'take', 'car'],
#  ['objection', 'bf', 'coming'],
#  ['thanx'],
#  ['tell', 'rob', 'mack', 'gf', 'theater'],
#  ['awesome', 'see', 'bit'],
#  ['sent', 'type', 'food', 'like'],
#  ['done', 'handed', 'celebration', 'full', 'swing', 'yet'],
#  ['got', 'called', 'tool'],
#  ['wen', 'miss', 'someone'],
#  ['ok', 'asked', 'money', 'far'],
#  ['okie'],
#  ['yeah',
#   'think',
#   'usual',
#   'guy',
#   'still',
#   'passed',
#   'last',
#   'night',
#   'get',
#   'ahold',
#   'anybody',
#   'let',
#   'know',
#   'throw'],
#  ['might', 'come', 'tonight', 'class', 'let', 'early'],
#  ['ok'],
#  ['hi',
#   'baby',
#   'im',
#   'cruisin',
#   'girl',
#   'friend',
#   'give',
#   'call',
#   'hour',
#   'home',
#   'thats',
#   'alright',
#   'fone',
#   'fone',
#   'love',
#   'jenny',
#   'xxx'],
#  ['life',
#   'mean',
#   'lot',
#   'love',
#   'life',
#   'love',
#   'people',
#   'life',
#   'world',
#   'call',
#   'friend',
#   'call',
#   'world',
#   'ge'],
#  ['dear',
#   'shall',
#   'mail',
#   'tonite',
#   'busy',
#   'street',
#   'shall',
#   'update',
#   'tonite',
#   'thing',
#   'looking',
#   'ok',
#   'varunnathu',
#   'edukkukayee',
#   'raksha',
#   'ollu',
#   'good',
#   'one',
#   'real',
#   'sense'],
#  ['hey', 'told', 'name', 'gautham', 'ah'],
#  ['haf', 'found', 'feel', 'stupid', 'da', 'cam', 'working'],
#  ['oops', 'got', 'bit'],
#  ['much', 'buzy'],
#  ['accidentally', 'deleted', 'message', 'resend', 'please'],
#  ['mobile',
#   'customer',
#   'may',
#   'claim',
#   'free',
#   'camera',
#   'phone',
#   'upgrade',
#   'pay',
#   'go',
#   'sim',
#   'card',
#   'loyalty',
#   'call',
#   'offer',
#   'end',
#   'thfeb',
#   'apply'],
#  ['unless', 'situation', 'go', 'gurl', 'would', 'appropriate'],
#  ['hurt',
#   'tease',
#   'make',
#   'cry',
#   'end',
#   'life',
#   'die',
#   'plz',
#   'keep',
#   'one',
#   'rose',
#   'grave',
#   'say',
#   'stupid',
#   'miss',
#   'nice',
#   'day',
#   'bslvyl'],
#  ['cant', 'pick', 'phone', 'right', 'pls', 'send', 'message'],
#  ['need', 'coffee', 'run', 'tomo', 'believe', 'time', 'week', 'already'],
#  ['awesome',
#   'remember',
#   'last',
#   'time',
#   'got',
#   'somebody',
#   'high',
#   'first',
#   'time',
#   'diesel'],
#  ['shit',
#   'really',
#   'shocking',
#   'scary',
#   'cant',
#   'imagine',
#   'second',
#   'def',
#   'night',
#   'think',
#   'somewhere',
#   'could',
#   'crash',
#   'night',
#   'save',
#   'taxi'],
#  ['oh', 'way', 'food', 'fridge', 'want', 'go', 'meal', 'tonight'],
#  ['womdarfull', 'actor'],
#  ['sm',
#   'ac',
#   'blind',
#   'date',
#   'rodds',
#   'aberdeen',
#   'united',
#   'kingdom',
#   'check',
#   'http',
#   'img',
#   'sm',
#   'ac',
#   'icmb',
#   'cktz',
#   'blind',
#   'date',
#   'send',
#   'hide'],
#  ['yup', 'remb', 'think', 'book'],
#  ['jos', 'ask', 'wana', 'meet'],
#  ['lol', 'yes', 'friendship', 'hanging', 'thread', 'cause', 'buy', 'stuff'],
#  ['themob',
#   'check',
#   'newest',
#   'selection',
#   'content',
#   'game',
#   'tone',
#   'gossip',
#   'babe',
#   'sport',
#   'keep',
#   'mobile',
#   'fit',
#   'funky',
#   'text',
#   'wap'],
#  ['garage', 'key', 'bookshelf'],
#  ['today',
#   'accept',
#   'day',
#   'accept',
#   'brother',
#   'sister',
#   'lover',
#   'dear',
#   'best',
#   'clos',
#   'lvblefrnd',
#   'jstfrnd',
#   'cutefrnd',
#   'lifpartnr',
#   'belovd',
#   'swtheart',
#   'bstfrnd',
#   'rply',
#   'mean',
#   'enemy'],
#  ['think',
#   'ur',
#   'smart',
#   'win',
#   'week',
#   'weekly',
#   'quiz',
#   'text',
#   'play',
#   'winnersclub',
#   'po',
#   'box',
#   'uz',
#   'gbp',
#   'week'],
#  ['say',
#   'give',
#   'call',
#   'friend',
#   'got',
#   'money',
#   'definitely',
#   'buying',
#   'end',
#   'week'],
#  ['hi',
#   'way',
#   'day',
#   'normal',
#   'way',
#   'real',
#   'ur',
#   'unique',
#   'hope',
#   'know',
#   'rest',
#   'mylife',
#   'hope',
#   'find',
#   'wot',
#   'lost'],
#  ['made', 'day', 'great', 'day'],
#  ['advance', 'happy', 'pongal'],
#  ['hmmm',
#   'guess',
#   'go',
#   'kb',
#   'power',
#   'yoga',
#   'haha',
#   'dunno',
#   'tahan',
#   'power',
#   'yoga',
#   'anot',
#   'thk',
#   'got',
#   'lo',
#   'oso',
#   'forgot',
#   'liao'],
#  ['really', 'dude', 'friend', 'afraid'],
#  ['december',
#   'mobile',
#   'mths',
#   'entitled',
#   'update',
#   'latest',
#   'colour',
#   'camera',
#   'mobile',
#   'free',
#   'call',
#   'mobile',
#   'update',
#   'co',
#   'free'],
#  ['coffee', 'cake', 'guess'],
#  ['merry', 'christmas', 'babe', 'love', 'ya', 'kiss'],
#  ['hey', 'dont', 'go', 'watch', 'men', 'lunch', 'haha'],
#  ['cud',
#   'tell',
#   'ppl',
#   'im',
#   'gona',
#   'bit',
#   'co',
#   'bus',
#   'hav',
#   'gon',
#   'past',
#   'co',
#   'full',
#   'im',
#   'still',
#   'waitin',
#   'pete'],
#  ['would',
#   'great',
#   'guild',
#   'could',
#   'meet',
#   'bristol',
#   'road',
#   'somewhere',
#   'get',
#   'touch',
#   'weekend',
#   'plan',
#   'take',
#   'flight',
#   'good',
#   'week'],
#  ['problem'],
#  ['call', 'message', 'missed', 'call'],
#  ['hi', 'da', 'today', 'class'],
#  ['say',
#   'good',
#   'sign',
#   'well',
#   'know',
#   'track',
#   'record',
#   'reading',
#   'woman'],
#  ['cool', 'text', 'parked'],
#  ['reading', 'text', 'sent', 'meant', 'joke', 'read', 'light'],
#  ['apo', 'good', 'movie'],
#  ['maybe',
#   'could',
#   'get',
#   'book',
#   'tomo',
#   'return',
#   'immediately',
#   'something'],
#  ['call',
#   'germany',
#   'penny',
#   'per',
#   'minute',
#   'call',
#   'fixed',
#   'line',
#   'via',
#   'access',
#   'number',
#   'prepayment',
#   'direct',
#   'access'],
#  ['chance',
#   'might',
#   'evaporated',
#   'soon',
#   'violated',
#   'privacy',
#   'stealing',
#   'phone',
#   'number',
#   'employer',
#   'paperwork',
#   'cool',
#   'please',
#   'contact',
#   'report',
#   'supervisor'],
#  ['valentine',
#   'day',
#   'special',
#   'win',
#   'quiz',
#   'take',
#   'partner',
#   'trip',
#   'lifetime',
#   'send',
#   'go',
#   'msg',
#   'rcvd',
#   'custcare'],
#  ['ta', 'daaaaa', 'home', 'babe', 'still'],
#  ['cool', 'come', 'havent', 'wined', 'dined'],
#  ['sleeping', 'surfing'],
#  ['sorry', 'call', 'later'],
#  ['calling', 'right', 'call', 'hand', 'phone'],
#  ['ok', 'great', 'thanx', 'lot'],
#  ['take',
#   'post',
#   'come',
#   'must',
#   'text',
#   'happy',
#   'reading',
#   'one',
#   'wiv',
#   'hello',
#   'caroline',
#   'end',
#   'favourite',
#   'bless'],
#  ['hiding', 'stranger'],
#  ['interested', 'like'],
#  ['sister', 'cleared', 'two', 'round', 'birla', 'soft', 'yesterday'],
#  ['gudnite', 'tc', 'practice', 'going'],
#  ['dis',
#   'yijue',
#   'jus',
#   'saw',
#   'ur',
#   'mail',
#   'case',
#   'huiming',
#   'havent',
#   'sent',
#   'num',
#   'dis',
#   'num'],
#  ['one', 'small', 'prestige', 'problem'],
#  ['fancy',
#   'shag',
#   'interested',
#   'sextextuk',
#   'com',
#   'txt',
#   'xxuk',
#   'suzy',
#   'txts',
#   'cost',
#   'per',
#   'msg',
#   'tncs',
#   'website'],
#  ['checking', 'really', 'miss', 'seeing', 'jeremiah', 'great', 'month'],
#  ['nah', 'help', 'never', 'iphone'],
#  ['car', 'hour', 'half', 'going', 'apeshit'],
#  ['today',
#   'sorry',
#   'day',
#   'ever',
#   'angry',
#   'ever',
#   'misbehaved',
#   'hurt',
#   'plz',
#   'plz',
#   'slap',
#   'urself',
#   'bcoz',
#   'ur',
#   'fault',
#   'basically',
#   'good'],
#  ['yo',
#   'guy',
#   'ever',
#   'figure',
#   'much',
#   'need',
#   'alcohol',
#   'jay',
#   'trying',
#   'figure',
#   'much',
#   'safely',
#   'spend',
#   'weed'],
#  ['lt', 'gt', 'ish', 'minute', 'minute', 'ago', 'wtf'],
#  ['thank',
#   'calling',
#   'forgot',
#   'say',
#   'happy',
#   'onam',
#   'sirji',
#   'fine',
#   'remembered',
#   'met',
#   'insurance',
#   'person',
#   'meet',
#   'qatar',
#   'insha',
#   'allah',
#   'rakhesh',
#   'ex',
#   'tata',
#   'aig',
#   'joined',
#   'tissco',
#   'tayseer'],
#  ['congratulation',
#   'ur',
#   'awarded',
#   'cd',
#   'voucher',
#   'gift',
#   'guaranteed',
#   'free',
#   'entry',
#   'wkly',
#   'draw',
#   'txt',
#   'music',
#   'tncs',
#   'www',
#   'ldew',
#   'com',
#   'win',
#   'ppmx',
#   'age'],
#  ['ur',
#   'cash',
#   'balance',
#   'currently',
#   'pound',
#   'maximize',
#   'ur',
#   'cash',
#   'send',
#   'cash',
#   'msg',
#   'cc',
#   'hg',
#   'suite',
#   'land',
#   'row',
#   'hl'],
#  ['actor',
#   'work',
#   'work',
#   'evening',
#   'sleep',
#   'late',
#   'since',
#   'unemployed',
#   'moment',
#   'always',
#   'sleep',
#   'late',
#   'unemployed',
#   'every',
#   'day',
#   'saturday'],
#  ['hello',
#   'got',
#   'st',
#   'andrew',
#   'boy',
#   'long',
#   'way',
#   'cold',
#   'keep',
#   'posted'],
#  ['ha', 'ha', 'cool', 'cool', 'chikku', 'chikku', 'db'],
#  ['oh', 'ok', 'prob'],
#  ['check', 'audrey', 'status', 'right'],
#  ['busy',
#   'trying',
#   'finish',
#   'new',
#   'year',
#   'looking',
#   'forward',
#   'finally',
#   'meeting'],
#  ['good',
#   'afternoon',
#   'sunshine',
#   'dawn',
#   'day',
#   'refreshed',
#   'happy',
#   'alive',
#   'breathe',
#   'air',
#   'smile',
#   'think',
#   'love',
#   'always'],
#  ['well', 'know', 'take', 'care', 'worry'],
#  ['update',
#   'xmas',
#   'offer',
#   'latest',
#   'motorola',
#   'sonyericsson',
#   'nokia',
#   'free',
#   'bluetooth',
#   'double',
#   'min',
#   'txt',
#   'orange',
#   'call',
#   'mobileupd',
#   'call',
#   'optout'],
#  ['discount',
#   'code',
#   'rp',
#   'stop',
#   'message',
#   'reply',
#   'stop',
#   'www',
#   'regalportfolio',
#   'co',
#   'uk',
#   'customer',
#   'service'],
#  ['wat', 'uniform', 'get'],
#  ['cool', 'text', 'ready'],
#  ['hello',
#   'boytoy',
#   'geeee',
#   'miss',
#   'already',
#   'woke',
#   'wish',
#   'bed',
#   'cuddling',
#   'love'],
#  ['spoil', 'bed', 'well'],
#  ['going', 'bath', 'msg', 'next', 'lt', 'gt', 'min'],
#  ['cant',
#   'keep',
#   'talking',
#   'people',
#   'sure',
#   'pay',
#   'agree',
#   'price',
#   'pls',
#   'tell',
#   'want',
#   'really',
#   'buy',
#   'much',
#   'willing',
#   'pay'],
#  ['thanks',
#   'ringtone',
#   'order',
#   'reference',
#   'charged',
#   'gbp',
#   'per',
#   'week',
#   'unsubscribe',
#   'anytime',
#   'calling',
#   'customer',
#   'service'],
#  ['say', 'happen'],
#  ['could', 'seen', 'recognise', 'face'],
#  ['well',
#   'lot',
#   'thing',
#   'happening',
#   'lindsay',
#   'new',
#   'year',
#   'sigh',
#   'bar',
#   'ptbo',
#   'blue',
#   'heron',
#   'something',
#   'going'],
#  ['keep', 'payasam', 'rinu', 'brings'],
#  ['taught',
#   'ranjith',
#   'sir',
#   'called',
#   'sm',
#   'like',
#   'becaus',
#   'he',
#   'verifying',
#   'project',
#   'prabu',
#   'told',
#   'today',
#   'pa',
#   'dont',
#   'mistake'],
#  ['guess',
#   'worried',
#   'must',
#   'know',
#   'way',
#   'body',
#   'repair',
#   'quite',
#   'sure',
#   'worry',
#   'take',
#   'slow',
#   'first',
#   'test',
#   'guide',
#   'ovulation',
#   'relax',
#   'nothing',
#   'said',
#   'reason',
#   'worry',
#   'keep',
#   'followin'],
#  ['yeah', 'sure', 'give', 'couple', 'minute', 'track', 'wallet'],
#  ['hey', 'leave', 'big', 'deal', 'take', 'care'],
#  ['hey', 'late', 'ah', 'meet'],
#  ['double',
#   'min',
#   'txts',
#   'month',
#   'free',
#   'bluetooth',
#   'orange',
#   'available',
#   'sony',
#   'nokia',
#   'motorola',
#   'phone',
#   'call',
#   'mobileupd',
#   'call',
#   'optout',
#   'dx'],
#  ['took', 'mr', 'owl', 'lick'],
#  ['customer', 'place', 'call'],
#  ['mm', 'time', 'dont', 'like', 'fun'],
#  ['mths',
#   'half',
#   'price',
#   'orange',
#   'line',
#   'rental',
#   'latest',
#   'camera',
#   'phone',
#   'free',
#   'phone',
#   'mths',
#   'call',
#   'mobilesdirect',
#   'free',
#   'update',
#   'stoptxt'],
#  ['yup', 'lunch', 'buffet', 'eat', 'already'],
#  ['huh', 'late', 'fr', 'dinner'],
#  ['hey', 'sat', 'going', 'intro', 'pilate', 'kickboxing'],
#  ['morning', 'ok'],
#  ['yes',
#   'think',
#   'office',
#   'lap',
#   'room',
#   'think',
#   'thats',
#   'last',
#   'day',
#   'didnt',
#   'shut'],
#  ['pick', 'bout', 'ish', 'time', 'going'],
#  ['performance',
#   'award',
#   'calculated',
#   'every',
#   'two',
#   'month',
#   'current',
#   'one',
#   'month',
#   'period'],
#  ['actually',
#   'sleeping',
#   'still',
#   'might',
#   'call',
#   'back',
#   'text',
#   'gr',
#   'rock',
#   'si',
#   'send',
#   'text',
#   'wen',
#   'wake'],
#  ['always',
#   'putting',
#   'business',
#   'put',
#   'picture',
#   'as',
#   'facebook',
#   'one',
#   'open',
#   'people',
#   'ever',
#   'met',
#   'would',
#   'think',
#   'picture',
#   'room',
#   'would',
#   'hurt',
#   'make',
#   'feel',
#   'violated'],
#  ['good',
#   'evening',
#   'sir',
#   'al',
#   'salam',
#   'wahleykkum',
#   'sharing',
#   'happy',
#   'news',
#   'grace',
#   'god',
#   'got',
#   'offer',
#   'tayseer',
#   'tissco',
#   'joined',
#   'hope',
#   'fine',
#   'inshah',
#   'allah',
#   'meet',
#   'sometime',
#   'rakhesh',
#   'visitor',
#   'india'],
#  ['hmmm',
#   'want',
#   'change',
#   'field',
#   'quickly',
#   'da',
#   'wanna',
#   'get',
#   'system',
#   'administrator',
#   'network',
#   'administrator'],
#  ['free',
#   'ringtone',
#   'text',
#   'first',
#   'poly',
#   'text',
#   'get',
#   'true',
#   'tone',
#   'help',
#   'st',
#   'free',
#   'tone',
#   'pw',
#   'nd',
#   'txt',
#   'stop'],
#  ['dear', 'chechi', 'talk'],
#  ['hair', 'cream', 'shipped'],
#  ['none', 'happening', 'til', 'get', 'though'],
#  ['yep',
#   'great',
#   'loxahatchee',
#   'xmas',
#   'tree',
#   'burning',
#   'lt',
#   'gt',
#   'start',
#   'hour'],
#  ['haha', 'get', 'used', 'driving', 'usf', 'man', 'know', 'lot', 'stoner'],
#  ['well',
#   'slightly',
#   'disastrous',
#   'class',
#   'pm',
#   'fav',
#   'darling',
#   'hope',
#   'day',
#   'ok',
#   'coffee',
#   'wld',
#   'good',
#   'stay',
#   'late',
#   'tomorrow',
#   'time',
#   'place',
#   'always'],
#  ['hello', 'good', 'week', 'fancy', 'drink', 'something', 'later'],
#  ['headin', 'towards', 'busetop'],
#  ['message',
#   'text',
#   'missing',
#   'sender',
#   'name',
#   'missing',
#   'number',
#   'missing',
#   'sent',
#   'date',
#   'missing',
#   'missing',
#   'lot',
#   'thats',
#   'everything',
#   'missing',
#   'sent',
#   'via',
#   'fullonsms',
#   'com'],
#  ['come', 'room', 'point', 'iron', 'plan', 'weekend'],
#  ['co', 'want', 'thing'],
#  ['okies',
#   'go',
#   'yan',
#   'jiu',
#   'skip',
#   'ard',
#   'oso',
#   'go',
#   'cine',
#   'den',
#   'go',
#   'mrt',
#   'one',
#   'blah',
#   'blah',
#   'blah'],
#  ['bring', 'home', 'wendy'],
#  ['dating', 'service', 'cal', 'box', 'sk', 'ch'],
#  ['whatsup', 'dont', 'want', 'sleep'],
#  ['alright', 'new', 'goal'],
#  ['free',
#   'entry',
#   'weekly',
#   'competition',
#   'text',
#   'word',
#   'win',
#   'www',
#   'txttowin',
#   'co',
#   'uk'],
#  ['alright', 'head', 'minute', 'text', 'meet'],
#  ['send',
#   'logo',
#   'ur',
#   'lover',
#   'name',
#   'joined',
#   'heart',
#   'txt',
#   'love',
#   'name',
#   'name',
#   'mobno',
#   'eg',
#   'love',
#   'adam',
#   'eve',
#   'yahoo',
#   'pobox',
#   'wq',
#   'txtno',
#   'ad'],
#  ['yes', 'last', 'week', 'taking', 'live', 'call'],
#  ['someone',
#   'contacted',
#   'dating',
#   'service',
#   'entered',
#   'phone',
#   'fancy',
#   'find',
#   'call',
#   'landline',
#   'pobox',
#   'tf'],
#  ['siva', 'hostel', 'aha'],
#  ['urgent',
#   'mobile',
#   'number',
#   'awarded',
#   'prize',
#   'guaranteed',
#   'call',
#   'land',
#   'line',
#   'claim',
#   'valid',
#   'hr'],
#  ['send',
#   'ur',
#   'friend',
#   'receive',
#   'something',
#   'ur',
#   'voice',
#   'speaking',
#   'expression',
#   'childish',
#   'naughty',
#   'sentiment',
#   'rowdy',
#   'ful',
#   'attitude',
#   'romantic',
#   'shy',
#   'attractive',
#   'funny',
#   'lt',
#   'gt',
#   'irritating',
#   'lt',
#   'gt',
#   'lovable',
#   'reply'],
#  ['ok', 'ok', 'guess'],
#  ['aathi', 'dear'],
#  ['pain', 'urination', 'thing', 'else'],
#  ['esplanade', 'mind', 'giving', 'lift', 'co', 'got', 'car', 'today'],
#  ['wnt',
#   'buy',
#   'bmw',
#   'car',
#   'urgently',
#   'vry',
#   'urgent',
#   'hv',
#   'shortage',
#   'lt',
#   'gt',
#   'lac',
#   'source',
#   'arng',
#   'dis',
#   'amt',
#   'lt',
#   'gt',
#   'lac',
#   'thats',
#   'prob'],
#  ['home', 'watching', 'tv', 'lor'],
#  ['usually',
#   'take',
#   'fifteen',
#   'fucking',
#   'minute',
#   'respond',
#   'yes',
#   'question'],
#  ['congrats',
#   'nokia',
#   'video',
#   'camera',
#   'phone',
#   'call',
#   'call',
#   'cost',
#   'ppm',
#   'ave',
#   'call',
#   'min',
#   'vary',
#   'mobile',
#   'close',
#   'post',
#   'bcm',
#   'ldn',
#   'wc',
#   'xx'],
#  ['booked', 'ticket', 'pongal'],
#  ['available',
#   'like',
#   'right',
#   'around',
#   'hillsborough',
#   'amp',
#   'lt',
#   'gt',
#   'th'],
#  ['message',
#   'sent',
#   'askin',
#   'lt',
#   'gt',
#   'dollar',
#   'shoul',
#   'pay',
#   'lt',
#   'gt',
#   'lt',
#   'gt'],
#  ['ask', 'iouri', 'told', 'story', 'like', 'ten', 'time', 'already'],
#  ['long', 'applebees', 'fucking', 'take'],
#  ['hi',
#   'hope',
#   'get',
#   'txt',
#   'journey',
#   'hasnt',
#   'gd',
#   'min',
#   'late',
#   'think'],
#  ['like', 'love', 'arrange'],
#  ['yes',
#   'really',
#   'great',
#   'bhaji',
#   'told',
#   'kallis',
#   'best',
#   'cricketer',
#   'sachin',
#   'world',
#   'tough',
#   'get'],
#  ['supposed', 'wake', 'gt'],
#  ['oic', 'saw', 'tot', 'din', 'found', 'group', 'liao'],
#  ['sorry', 'call', 'later'],
#  ['hey',
#   'hey',
#   'werethe',
#   'monkeespeople',
#   'say',
#   'monkeyaround',
#   'howdy',
#   'gorgeous'],
#  ['sorry', 'battery', 'died', 'come', 'getting', 'gram', 'place'],
#  ['well',
#   'done',
#   'blimey',
#   'exercise',
#   'yeah',
#   'kinda',
#   'remember',
#   'wot',
#   'hmm'],
#  ['wont', 'get', 'concentration', 'dear', 'know', 'mind', 'everything'],
#  ['lol', 'made', 'plan', 'new', 'year'],
#  ['min', 'later'],
#  ['hank', 'lotsly'],
#  ['thanks', 'hope', 'good', 'day', 'today'],
#  ['detail', 'want', 'transfer', 'acc', 'enough'],
#  ['ok',
#   'tell',
#   'stay',
#   'yeah',
#   'tough',
#   'optimistic',
#   'thing',
#   'improve',
#   'month'],
#  ['loan',
#   'purpose',
#   'homeowner',
#   'tenant',
#   'welcome',
#   'previously',
#   'refused',
#   'still',
#   'help',
#   'call',
#   'free',
#   'text',
#   'back',
#   'help'],
#  ['si', 'si', 'think', 'ill', 'go', 'make', 'oreo', 'truffle'],
#  ['look',
#   'amy',
#   'ure',
#   'beautiful',
#   'intelligent',
#   'woman',
#   'like',
#   'lot',
#   'know',
#   'like',
#   'like',
#   'worry'],
#  ['hope',
#   'result',
#   'consistently',
#   'intelligent',
#   'kind',
#   'start',
#   'asking',
#   'practicum',
#   'link',
#   'keep',
#   'ear',
#   'open',
#   'best',
#   'ttyl'],
#  ['call',
#   'cost',
#   'guess',
#   'isnt',
#   'bad',
#   'miss',
#   'ya',
#   'need',
#   'ya',
#   'want',
#   'ya',
#   'love',
#   'ya'],
#  ['going',
#   'thru',
#   'different',
#   'feeling',
#   'wavering',
#   'decision',
#   'coping',
#   'individual',
#   'time',
#   'heal',
#   'everything',
#   'believe'],
#  ['go', 'phone', 'gonna', 'die', 'stay'],
#  ['great', 'never', 'better', 'day', 'give', 'even', 'reason', 'thank', 'god'],
#  ['upgrdcentre',
#   'orange',
#   'customer',
#   'may',
#   'claim',
#   'free',
#   'camera',
#   'phone',
#   'upgrade',
#   'loyalty',
#   'call',
#   'offer',
#   'end',
#   'th',
#   'july',
#   'apply',
#   'opt',
#   'available'],
#  ['sorry', 'call', 'later', 'ok', 'bye'],
#  ['ok', 'way', 'railway'],
#  ['great',
#   'princess',
#   'love',
#   'giving',
#   'receiving',
#   'oral',
#   'doggy',
#   'style',
#   'fave',
#   'position',
#   'enjoy',
#   'making',
#   'love',
#   'lt',
#   'gt',
#   'time',
#   'per',
#   'night'],
#  ['put', 'stuff', 'road', 'keep', 'getting', 'slippery'],
#  ['going', 'ride', 'bike'],
#  ['yup', 'need', 'jus', 'wait', 'rain', 'stop'],
#  ['many', 'company', 'tell', 'language'],
#  ['okmail',
#   'dear',
#   'dave',
#   'final',
#   'notice',
#   'collect',
#   'tenerife',
#   'holiday',
#   'cash',
#   'award',
#   'call',
#   'landline',
#   'tc',
#   'sae',
#   'box',
#   'cw',
#   'wx',
#   'ppm'],
#  ['long', 'since', 'screamed', 'princess'],
#  ['nothing',
#   'meant',
#   'money',
#   'enters',
#   'account',
#   'bank',
#   'remove',
#   'flat',
#   'rate',
#   'someone',
#   'transfered',
#   'lt',
#   'gt',
#   'account',
#   'lt',
#   'gt',
#   'dollar',
#   'got',
#   'removed',
#   'bank',
#   'differ',
#   'charge',
#   'also',
#   'differ',
#   'sure',
#   'trust',
#   'ja',
#   'person',
#   'sending',
#   'account',
#   'detail',
#   'co'],
#  ['want',
#   'get',
#   'laid',
#   'tonight',
#   'want',
#   'real',
#   'dogging',
#   'location',
#   'sent',
#   'direct',
#   'ur',
#   'mob',
#   'join',
#   'uk',
#   'largest',
#   'dogging',
#   'network',
#   'txting',
#   'moan',
#   'nyt',
#   'ec',
#   'msg'],
#  ['nice',
#   'line',
#   'said',
#   'broken',
#   'heart',
#   'plz',
#   'cum',
#   'time',
#   'infront',
#   'wise',
#   'trust',
#   'good'],
#  ['ok', 'gonna', 'head', 'usf', 'like', 'fifteen', 'minute'],
#  ['love', 'aathi', 'love', 'lot'],
#  ['tension', 'ah', 'machi', 'problem'],
#  ['pick', 'another', 'th', 'done'],
#  ['guy', 'getting', 'back', 'said', 'thinking', 'staying', 'mcr'],
#  ['almost', 'see', 'sec'],
#  ['yo', 'carlos', 'friend', 'already', 'asking', 'working', 'weekend'],
#  ['watching', 'tv', 'lor'],
#  ['thank', 'baby', 'cant', 'wait', 'taste', 'real', 'thing'],
#  ['change', 'fb', 'jaykwon', 'thuglyfe', 'falconerf'],
#  ['win', 'really', 'side', 'long', 'time'],
#  ['free',
#   'message',
#   'activate',
#   'free',
#   'text',
#   'message',
#   'replying',
#   'message',
#   'word',
#   'free',
#   'term',
#   'condition',
#   'visit',
#   'www',
#   'com'],
#  ['dear', 'reached', 'railway', 'happen'],
#  ['depends',
#   'quality',
#   'want',
#   'type',
#   'sent',
#   'boye',
#   'faded',
#   'glory',
#   'want',
#   'ralphs',
#   'maybe'],
#  ['think', 'fixed', 'send', 'test', 'message'],
#  ['sorry',
#   'man',
#   'account',
#   'dry',
#   'would',
#   'want',
#   'could',
#   'trade',
#   'back',
#   'half',
#   'could',
#   'buy',
#   'shit',
#   'credit',
#   'card'],
#  ['congrats',
#   'year',
#   'special',
#   'cinema',
#   'pas',
#   'call',
#   'suprman',
#   'matrix',
#   'starwars',
#   'etc',
#   'free',
#   'bx',
#   'ip',
#   'pm',
#   'dont',
#   'miss'],
#  ['sorry', 'meeting', 'call', 'later'],
#  ['class', 'lt', 'gt', 'reunion'],
#  ['free', 'call'],
#  ['got', 'meh'],
#  ['nope', 'think', 'go', 'monday', 'sorry', 'replied', 'late'],
#  ['told', 'accenture', 'confirm', 'true'],
#  ['kate', 'jackson', 'rec', 'center', 'ish', 'right'],
#  ['dear', 'reache', 'room'],
#  ['fighting',
#   'world',
#   'easy',
#   'either',
#   'win',
#   'lose',
#   'bt',
#   'fightng',
#   'close',
#   'dificult',
#   'lose',
#   'lose',
#   'win',
#   'still',
#   'lose'],
#  ['come'],
#  ['check', 'nuerologist'],
#  ['lolnice', 'went', 'fish', 'water'],
#  ['congratulation',
#   'week',
#   'competition',
#   'draw',
#   'prize',
#   'claim',
#   'call',
#   'stop',
#   'sm',
#   'ppm'],
#  ['waiting',
#   'car',
#   'dat',
#   'bored',
#   'wat',
#   'co',
#   'wait',
#   'outside',
#   'got',
#   'nothing',
#   'home',
#   'stuff',
#   'watch',
#   'tv',
#   'wat'],
#  ['maybe', 'westshore', 'hyde', 'park', 'village', 'place', 'near', 'house'],
#  ['know',
#   'anthony',
#   'bringing',
#   'money',
#   'school',
#   'fee',
#   'pay',
#   'rent',
#   'stuff',
#   'like',
#   'thats',
#   'need',
#   'help',
#   'friend',
#   'need'],
#  ['significance'],
#  ['opinion',
#   'jada',
#   'kusruthi',
#   'lovable',
#   'silent',
#   'spl',
#   'character',
#   'matured',
#   'stylish',
#   'simple',
#   'pls',
#   'reply'],
#  ['latest', 'still', 'scrounge', 'ammo', 'want', 'give', 'new', 'ak', 'try'],
#  ['prabha', 'soryda', 'realy', 'frm', 'heart', 'sory'],
#  ['lol', 'ok', 'forgiven'],
#  ['jst', 'change', 'tat'],
#  ['guaranteed',
#   'latest',
#   'nokia',
#   'phone',
#   'gb',
#   'ipod',
#   'mp',
#   'player',
#   'prize',
#   'txt',
#   'word',
#   'collect',
#   'ibhltd',
#   'ldnw',
#   'mtmsgrcvd'],
#  ['competition'],
#  ['boltblue',
#   'tone',
#   'reply',
#   'poly',
#   'mono',
#   'eg',
#   'poly',
#   'cha',
#   'cha',
#   'slide',
#   'yeah',
#   'slow',
#   'jamz',
#   'toxic',
#   'come',
#   'stop',
#   'tone',
#   'txt'],
#  ['credit',
#   'topped',
#   'http',
#   'www',
#   'bubbletext',
#   'com',
#   'renewal',
#   'pin',
#   'tgxxrz'],
#  ['way',
#   'transport',
#   'le',
#   'problematic',
#   'sat',
#   'night',
#   'way',
#   'want',
#   'ask',
#   'join',
#   'bday',
#   'feel',
#   'free',
#   'need',
#   'know',
#   'definite',
#   'no',
#   'booking',
#   'fri'],
#  ['usually',
#   'person',
#   'unconscious',
#   'child',
#   'adult',
#   'may',
#   'behave',
#   'abnormally',
#   'call'],
#  ['ebay', 'might', 'le', 'elsewhere'],
#  ['shall', 'come', 'get', 'pickle'],
#  ['gonna', 'go', 'get', 'taco'],
#  ['rude', 'campus'],
#  ['urgent',
#   'mobile',
#   'awarded',
#   'bonus',
#   'caller',
#   'prize',
#   'nd',
#   'attempt',
#   'contact',
#   'call',
#   'box',
#   'qu'],
#  ['hi', 'ard', 'christmas', 'enjoy', 'merry', 'ma'],
#  ['today',
#   'offer',
#   'claim',
#   'ur',
#   'worth',
#   'discount',
#   'voucher',
#   'text',
#   'yes',
#   'savamob',
#   'member',
#   'offer',
#   'mobile',
#   'sub',
#   'unsub',
#   'reply'],
#  ['yes', 'pretty', 'lady', 'like', 'single'],
#  ['recieve',
#   'tone',
#   'within',
#   'next',
#   'hr',
#   'term',
#   'condition',
#   'please',
#   'see',
#   'channel',
#   'teletext',
#   'pg'],
#  ['jay', 'say', 'double', 'faggot'],
#  ['private',
#   'account',
#   'statement',
#   'show',
#   'un',
#   'redeemed',
#   'point',
#   'call',
#   'identifier',
#   'code',
#   'expires'],
#  ['today', 'sunday', 'sunday', 'holiday', 'work'],
#  ['gudnite', 'tc', 'practice', 'going'],
#  ['late'],
#  ['called',
#   'hoping',
#   'malaria',
# ...
#   'ago'],
#  ['surely', 'result', 'offer'],
#  ['good', 'morning', 'dear', 'great', 'amp', 'successful', 'day'],
#  ['want',
#   'anytime',
#   'network',
#   'min',
#   'text',
#   'new',
#   'video',
#   'phone',
#   'five',
#   'pound',
#   'per',
#   'week',
#   'call',
#   'reply',
#   'delivery',
#   'tomorrow'],
#  ['sir',
#   'late',
#   'paying',
#   'rent',
#   'past',
#   'month',
#   'pay',
#   'lt',
#   'gt',
#   'charge',
#   'felt',
#   'would',
#   'inconsiderate',
#   'nag',
#   'something',
#   'give',
#   'great',
#   'cost',
#   'didnt',
#   'speak',
#   'however',
#   'recession',
#   'wont',
#   'able',
#   'pay',
#   'charge',
#   'month',
#   'hence',
#   'askin',
#   'well',
#   'ahead',
#   'month',
#   'end',
#   'please',
#   'help',
#   'thanks'],
#  ['tried',
#   'contact',
#   'offer',
#   'new',
#   'video',
#   'phone',
#   'anytime',
#   'network',
#   'min',
#   'half',
#   'price',
#   'rental',
#   'camcorder',
#   'call',
#   'reply',
#   'delivery',
#   'wed'],
#  ['last',
#   'chance',
#   'claim',
#   'ur',
#   'worth',
#   'discount',
#   'voucher',
#   'text',
#   'yes',
#   'savamob',
#   'member',
#   'offer',
#   'mobile',
#   'sub',
#   'remove',
#   'txt',
#   'stop'],
#  ['luv',
#   'soo',
#   'much',
#   'understand',
#   'special',
#   'ring',
#   'morrow',
#   'luv',
#   'xxx'],
#  ['pls', 'send', 'comprehensive', 'mail', 'paying', 'much'],
#  ['prashanthettan',
#   'mother',
#   'passed',
#   'away',
#   'last',
#   'night',
#   'pray',
#   'family'],
#  ['urgent',
#   'call',
#   'landline',
#   'complimentary',
#   'ibiza',
#   'holiday',
#   'cash',
#   'await',
#   'collection',
#   'sae',
#   'po',
#   'box',
#   'sk',
#   'wp',
#   'ppm'],
#  ['going'],
#  ['meanwhile',
#   'shit',
#   'suite',
#   'xavier',
#   'decided',
#   'give',
#   'lt',
#   'gt',
#   'second',
#   'warning',
#   'samantha',
#   'coming',
#   'playing',
#   'jay',
#   'guitar',
#   'impress',
#   'shit',
#   'also',
#   'think',
#   'doug',
#   'realizes',
#   'live',
#   'anymore'],
#  ['stomach',
#   'thru',
#   'much',
#   'trauma',
#   'swear',
#   'eat',
#   'better',
#   'lose',
#   'weight'],
#  ['office', 'whats', 'matter', 'msg', 'call', 'break'],
#  ['yeah',
#   'barely',
#   'enough',
#   'room',
#   'two',
#   'many',
#   'fucking',
#   'shoe',
#   'sorry',
#   'man',
#   'see',
#   'later'],
#  ['today',
#   'offer',
#   'claim',
#   'ur',
#   'worth',
#   'discount',
#   'voucher',
#   'text',
#   'yes',
#   'savamob',
#   'member',
#   'offer',
#   'mobile',
#   'sub',
#   'unsub',
#   'reply'],
#  ['reach', 'orchard', 'already', 'wan', 'go', 'buy', 'ticket', 'first'],
#  ['real', 'baby', 'want', 'bring', 'inner', 'tigress'],
#  ['da', 'run', 'activate', 'full', 'version', 'da'],
#  ['ah',
#   'poor',
#   'baby',
#   'hope',
#   'urfeeling',
#   'bettersn',
#   'luv',
#   'probthat',
#   'overdose',
#   'work',
#   'hey',
#   'go',
#   'careful',
#   'spk',
#   'sn',
#   'lot',
#   'lovejen',
#   'xxx'],
#  ['stop', 'story', 'told', 'returned', 'saying', 'order'],
#  ['talk',
#   'sexy',
#   'make',
#   'new',
#   'friend',
#   'fall',
#   'love',
#   'world',
#   'discreet',
#   'text',
#   'dating',
#   'service',
#   'text',
#   'vip',
#   'see',
#   'could',
#   'meet'],
#  ['going', 'take', 'babe'],
#  ['hai',
#   'ana',
#   'tomarrow',
#   'coming',
#   'morning',
#   'lt',
#   'decimal',
#   'gt',
#   'ill',
#   'sathy',
#   'go',
#   'rto',
#   'office',
#   'reply',
#   'came',
#   'home'],
#  ['spoon', 'okay'],
#  ['say', 'somebody', 'named', 'tampa'],
#  ['work', 'going', 'min'],
#  ['brother', 'genius'],
#  ['sorry',
#   'guess',
#   'whenever',
#   'get',
#   'hold',
#   'connection',
#   'maybe',
#   'hour',
#   'two',
#   'text'],
#  ['find', 'time', 'bus', 'coz', 'need', 'sort', 'stuff'],
#  ['dude', 'ive', 'seeing', 'lotta', 'corvette', 'lately'],
#  ['congratulation',
#   'ur',
#   'awarded',
#   'either',
#   'yr',
#   'supply',
#   'cd',
#   'virgin',
#   'record',
#   'mystery',
#   'gift',
#   'guaranteed',
#   'call',
#   'www',
#   'smsco',
#   'net',
#   'pm',
#   'approx',
#   'min'],
#  ['consider',
#   'wall',
#   'bunker',
#   'shit',
#   'important',
#   'never',
#   'play',
#   'peaceful',
#   'guess',
#   'place',
#   'high',
#   'enough',
#   'matter'],
#  ['private',
#   'account',
#   'statement',
#   'xxxxxx',
#   'show',
#   'un',
#   'redeemed',
#   'point',
#   'call',
#   'identifier',
#   'code',
#   'expires'],
#  ['hello',
#   'need',
#   'posh',
#   'bird',
#   'chap',
#   'user',
#   'trial',
#   'prod',
#   'champneys',
#   'put',
#   'need',
#   'address',
#   'dob',
#   'asap',
#   'ta'],
#  ['want',
#   'xmas',
#   'free',
#   'text',
#   'message',
#   'new',
#   'video',
#   'phone',
#   'half',
#   'price',
#   'line',
#   'rental',
#   'call',
#   'free',
#   'find'],
#  ['well',
#   'officially',
#   'philosophical',
#   'hole',
#   'wanna',
#   'call',
#   'home',
#   'ready',
#   'saved'],
#  ['going',
#   'good',
#   'problem',
#   'still',
#   'need',
#   'little',
#   'experience',
#   'understand',
#   'american',
#   'customer',
#   'voice'],
#  ['text', 'drop'],
#  ['ugh', 'long', 'day', 'exhausted', 'want', 'cuddle', 'take', 'nap'],
#  ['talk',
#   'atleast',
#   'day',
#   'otherwise',
#   'miss',
#   'best',
#   'friend',
#   'world',
#   'shakespeare',
#   'shesil',
#   'lt',
#   'gt'],
#  ['shop',
#   'till',
#   'drop',
#   'either',
#   'cash',
#   'travel',
#   'voucher',
#   'call',
#   'ntt',
#   'po',
#   'box',
#   'cr',
#   'bt',
#   'fixedline',
#   'cost',
#   'ppm',
#   'mobile',
#   'vary'],
#  ['castor', 'need', 'see', 'something'],
#  ['sunshine',
#   'quiz',
#   'wkly',
#   'win',
#   'top',
#   'sony',
#   'dvd',
#   'player',
#   'know',
#   'country',
#   'liverpool',
#   'played',
#   'mid',
#   'week',
#   'txt',
#   'ansr',
#   'sp',
#   'tyrone'],
#  ['secret',
#   'admirer',
#   'looking',
#   'make',
#   'contact',
#   'find',
#   'reveal',
#   'think',
#   'ur',
#   'special',
#   'call'],
#  ['secret',
#   'admirer',
#   'looking',
#   'make',
#   'contact',
#   'find',
#   'reveal',
#   'think',
#   'ur',
#   'special',
#   'call',
#   'stopsms'],
#  ['reminder',
#   'downloaded',
#   'content',
#   'already',
#   'paid',
#   'goto',
#   'http',
#   'doit',
#   'mymoby',
#   'tv',
#   'collect',
#   'content'],
#  ['see',
#   'knew',
#   'giving',
#   'break',
#   'time',
#   'woul',
#   'lead',
#   'always',
#   'wanting',
#   'miss',
#   'curfew',
#   'gonna',
#   'gibe',
#   'til',
#   'one',
#   'midnight',
#   'movie',
#   'gonna',
#   'get',
#   'til',
#   'need',
#   'come',
#   'home',
#   'need',
#   'getsleep',
#   'anything',
#   'need',
#   'studdying',
#   'ear',
#   'training'],
#  ['love', 'give', 'massage', 'use', 'lot', 'baby', 'oil', 'fave', 'position'],
#  ['dude', 'go', 'sup'],
#  ['yoyyooo',
#   'know',
#   'change',
#   'permission',
#   'drive',
#   'mac',
#   'usb',
#   'flash',
#   'drive'],
#  ['gibbs', 'unsold', 'mike', 'hussey'],
#  ['like', 'talk', 'pa', 'able', 'dont', 'know'],
#  ['dun', 'cut', 'short', 'leh', 'dun', 'like', 'ah', 'failed', 'quite', 'sad'],
#  ['unbelievable', 'faglord'],
#  ['wife', 'knew', 'time', 'murder', 'exactly'],
#  ['ask', 'princess'],
#  ['great', 'princess', 'thinking'],
#  ['nutter', 'cutter', 'ctter', 'cttergg', 'cttargg', 'ctargg', 'ctagg', 'ie'],
#  ['ok',
#   'noe',
#   'busy',
#   'really',
#   'bored',
#   'msg',
#   'oso',
#   'dunno',
#   'wat',
#   'colour',
#   'choose',
#   'one'],
#  ['class', 'early', 'tomorrow', 'thus', 'trying', 'smoke', 'lt', 'gt'],
#  ['superb',
#   'thought',
#   'grateful',
#   'dont',
#   'everything',
#   'want',
#   'mean',
#   'still',
#   'opportunity',
#   'happier',
#   'tomorrow',
#   'today'],
#  ['hope', 'good', 'week', 'checking'],
#  ['used',
#   'hope',
#   'agent',
#   'drop',
#   'since',
#   'booked',
#   'thing',
#   'year',
#   'whole',
#   'boston',
#   'nyc',
#   'experiment'],
#  ['thursday', 'night', 'yeah', 'sure', 'thing', 'work'],
#  ['free',
#   'ringtone',
#   'waiting',
#   'collected',
#   'simply',
#   'text',
#   'password',
#   'mix',
#   'verify',
#   'get',
#   'usher',
#   'britney',
#   'fml'],
#  ['probably',
#   'money',
#   'worry',
#   'thing',
#   'coming',
#   'due',
#   'several',
#   'outstanding',
#   'invoice',
#   'work',
#   'two',
#   'three',
#   'month',
#   'ago'],
#  ['possible', 'teach'],
#  ['wonder', 'phone', 'battery', 'went', 'dead', 'tell', 'love', 'babe'],
#  ['lovely', 'smell', 'bus', 'tobacco'],
#  ['getting', 'worried', 'derek', 'taylor', 'already', 'assumed', 'worst'],
#  ['hey', 'charles', 'sorry', 'late', 'reply'],
#  ['lastest',
#   'stereophonics',
#   'marley',
#   'dizzee',
#   'racal',
#   'libertine',
#   'stroke',
#   'win',
#   'nookii',
#   'game',
#   'flirt',
#   'click',
#   'themob',
#   'wap',
#   'bookmark',
#   'text',
#   'wap'],
#  ['give', 'plus', 'said', 'grinule', 'greet', 'whenever', 'speak'],
#  ['white', 'fudge', 'oreo', 'store'],
#  ['january',
#   'male',
#   'sale',
#   'hot',
#   'gay',
#   'chat',
#   'cheaper',
#   'call',
#   'national',
#   'rate',
#   'min',
#   'cheap',
#   'min',
#   'peak',
#   'stop',
#   'text',
#   'call',
#   'min'],
#  ['love',
#   'come',
#   'took',
#   'long',
#   'leave',
#   'zaher',
#   'got',
#   'word',
#   'ym',
#   'happy',
#   'see',
#   'sad',
#   'left',
#   'miss'],
#  ['sorry', 'hurt'],
#  ['feel',
#   'nauseous',
#   'pissed',
#   'eat',
#   'sweet',
#   'week',
#   'cause',
#   'today',
#   'planning',
#   'pig',
#   'dieting',
#   'week',
#   'hungry'],
#  ['ok', 'lor', 'early', 'still', 'project', 'meeting'],
#  ['call', 'da', 'waiting', 'call'],
#  ['could', 'ask', 'carlos', 'could', 'get', 'anybody', 'else', 'chip'],
#  ['actually', 'send', 'reminder', 'today', 'wonderful', 'weekend'],
#  ['people',
#   'see',
#   'msg',
#   'think',
#   'iam',
#   'addicted',
#   'msging',
#   'wrong',
#   'bcoz',
#   'know',
#   'iam',
#   'addicted',
#   'sweet',
#   'friend',
#   'bslvyl'],
#  ['hey',
#   'gave',
#   'photo',
#   'registered',
#   'driving',
#   'ah',
#   'tmr',
#   'wanna',
#   'meet',
#   'yck'],
#  ['dont', 'talk', 'ever', 'ok', 'word'],
#  ['wana', 'see'],
#  ['way', 'school', 'pls', 'send', 'ashley', 'number'],
#  ['shall', 'fine', 'avalarr', 'hollalater'],
#  ['went',
#   'attend',
#   'another',
#   'two',
#   'round',
#   'today',
#   'still',
#   'reach',
#   'home'],
#  ['actually',
#   'deleted',
#   'old',
#   'website',
#   'blogging',
#   'magicalsongs',
#   'blogspot',
#   'com'],
#  ['wait', 'chikku', 'il', 'send', 'aftr', 'lt', 'gt', 'min'],
#  ['diet',
#   'ate',
#   'many',
#   'slice',
#   'pizza',
#   'yesterday',
#   'ugh',
#   'always',
#   'diet'],
#  ['give', 'kvb', 'acc', 'detail'],
#  ['oh', 'come', 'ah'],
#  ['money',
#   'lucky',
#   'winner',
#   'claim',
#   'prize',
#   'text',
#   'money',
#   'million',
#   'give',
#   'away',
#   'ppt',
#   'normal',
#   'text',
#   'rate',
#   'box',
#   'jy'],
#  ['really',
#   'sorry',
#   'able',
#   'friday',
#   'hope',
#   'find',
#   'alternative',
#   'hope',
#   'yr',
#   'term',
#   'going',
#   'ok'],
#  ['congratulation',
#   'ore',
#   'mo',
#   'owo',
#   'wa',
#   'enjoy',
#   'wish',
#   'many',
#   'happy',
#   'moment',
#   'fro',
#   'wherever',
#   'go'],
#  ['samus', 'shoulder', 'yet'],
#  ['time', 'think', 'need', 'know', 'near', 'campus'],
#  ['dear',
#   'matthew',
#   'please',
#   'call',
#   'landline',
#   'complimentary',
#   'lux',
#   'tenerife',
#   'holiday',
#   'cash',
#   'await',
#   'collection',
#   'ppm',
#   'sae',
#   'box',
#   'sk',
#   'xh'],
#  ['dun', 'wear', 'jean', 'lor'],
#  ['since', 'side', 'fever', 'vomitin'],
#  ['college'],
#  ['urgent',
#   'call',
#   'landline',
#   'complimentary',
#   'tenerife',
#   'holiday',
#   'cash',
#   'await',
#   'collection',
#   'sae',
#   'box',
#   'hp',
#   'yf',
#   'ppm'],
#  ['better',
#   'made',
#   'friday',
#   'stuffed',
#   'like',
#   'pig',
#   'yesterday',
#   'feel',
#   'bleh',
#   'least',
#   'writhing',
#   'pain',
#   'kind',
#   'bleh'],
#  ['sell',
#   'ton',
#   'coin',
#   'sell',
#   'coin',
#   'someone',
#   'thru',
#   'paypal',
#   'voila',
#   'money',
#   'back',
#   'life',
#   'pocket'],
#  ['theyre', 'lot', 'place', 'hospital', 'medical', 'place', 'safe'],
#  ['getting',
#   'touch',
#   'folk',
#   'waiting',
#   'company',
#   'txt',
#   'back',
#   'name',
#   'age',
#   'opt',
#   'enjoy',
#   'community',
#   'sm'],
#  ['also',
#   'sorta',
#   'blown',
#   'couple',
#   'time',
#   'recently',
#   'id',
#   'rather',
#   'text',
#   'blue',
#   'looking',
#   'weed'],
#  ['sent',
#   'score',
#   'sophas',
#   'secondary',
#   'application',
#   'school',
#   'think',
#   'thinking',
#   'applying',
#   'research',
#   'cost',
#   'also',
#   'contact',
#   'joke',
#   'ogunrinde',
#   'school',
#   'one',
#   'le',
#   'expensive',
#   'one'],
#  ['cant', 'wait', 'see', 'photo', 'useful'],
#  ['ur',
#   'cash',
#   'balance',
#   'currently',
#   'pound',
#   'maximize',
#   'ur',
#   'cash',
#   'send',
#   'go',
#   'msg',
#   'cc',
#   'po',
#   'box',
#   'tcr'],
#  ['hey',
#   'booked',
#   'kb',
#   'sat',
#   'already',
#   'lesson',
#   'going',
#   'ah',
#   'keep',
#   'sat',
#   'night',
#   'free',
#   'need',
#   'meet',
#   'confirm',
#   'lodging'],
#  ['chk', 'ur', 'belovd', 'dict'],
#  ['time', 'want', 'come'],
#  ['awesome', 'lemme', 'know', 'whenever', 'around'],
#  ['shb', 'ok', 'lor', 'thanx'],
#  ['beautiful',
#   'truth',
#   'gravity',
#   'read',
#   'carefully',
#   'heart',
#   'feel',
#   'light',
#   'someone',
#   'feel',
#   'heavy',
#   'someone',
#   'leaf',
#   'good',
#   'night'],
#  ['also', 'remember', 'get', 'dobby', 'bowl', 'car'],
#  ['filthy', 'story', 'girl', 'waiting'],
#  ['sorry',
#   'ur',
#   'msg',
#   'yar',
#   'lor',
#   'poor',
#   'thing',
#   'one',
#   'night',
#   'tmr',
#   'brand',
#   'new',
#   'room',
#   'sleep'],
#  ['love',
#   'decision',
#   'feeling',
#   'could',
#   'decide',
#   'love',
#   'life',
#   'would',
#   'much',
#   'simpler',
#   'le',
#   'magical'],
#  ['welp', 'apparently', 'retired'],
#  ['sort',
#   'code',
#   'acc',
#   'bank',
#   'natwest',
#   'reply',
#   'confirm',
#   'sent',
#   'right',
#   'person'],
#  ['sure', 'take', 'sick', 'time'],
#  ['urgent',
#   'trying',
#   'contact',
#   'today',
#   'draw',
#   'show',
#   'prize',
#   'guaranteed',
#   'call',
#   'land',
#   'line',
#   'claim',
#   'valid',
#   'hr'],
#  ['watching',
#   'cartoon',
#   'listening',
#   'music',
#   'amp',
#   'eve',
#   'go',
#   'temple',
#   'amp',
#   'church'],
#  ['yo',
#   'chad',
#   'gymnastics',
#   'class',
#   'wanna',
#   'take',
#   'site',
#   'say',
#   'christian',
#   'class',
#   'full'],
#  ['much', 'buzy'],
#  ['better', 'still', 'catch', 'let', 'ask', 'sell', 'lt', 'gt'],
#  ['sure', 'night', 'menu', 'know', 'noon', 'menu'],
#  ['want',
#   'come',
#   'back',
#   'beautiful',
#   'necklace',
#   'token',
#   'heart',
#   'thats',
#   'give',
#   'wife',
#   'liking',
#   'see',
#   'one',
#   'give',
#   'dont',
#   'call',
#   'wait',
#   'till',
#   'come'],
#  ['willing', 'go', 'aptitude', 'class'],
#  ['wont', 'trying', 'sort', 'house', 'ok'],
#  ['yar',
#   'lor',
#   'wan',
#   'go',
#   'horse',
#   'racing',
#   'today',
#   'mah',
#   'eat',
#   'earlier',
#   'lor',
#   'ate',
#   'chicken',
#   'rice'],
#  ['haha', 'awesome', 'omw', 'back'],
#  ['yup', 'thk', 'shop', 'close', 'lor'],
#  ['account', 'number'],
#  ['eh', 'send', 'wrongly', 'lar'],
#  ['hey',
#   'ad',
#   'crap',
#   'nite',
#   'borin',
#   'without',
#   'ya',
#   'boggy',
#   'boring',
#   'biatch',
#   'thanx',
#   'wait',
#   'til',
#   'nxt',
#   'time',
#   'il',
#   'ave',
#   'ya'],
#  ['ok', 'shall', 'talk'],
#  ['dont',
#   'hesitate',
#   'know',
#   'second',
#   'time',
#   'weakness',
#   'like',
#   'keep',
#   'notebook',
#   'eat',
#   'day',
#   'anything',
#   'changed',
#   'day',
#   'sure',
#   'nothing'],
#  ['hey', 'pay', 'salary', 'de', 'lt', 'gt'],
#  ['another', 'month', 'need', 'chocolate', 'weed', 'alcohol'],
#  ['started', 'searching', 'get', 'job', 'day', 'great', 'potential', 'talent'],
#  ['reckon', 'need', 'town', 'eightish', 'walk', 'carpark'],
#  ['congrats',
#   'mobile',
#   'videophones',
#   'call',
#   'videochat',
#   'wid',
#   'mate',
#   'play',
#   'java',
#   'game',
#   'dload',
#   'polyph',
#   'music',
#   'noline',
#   'rentl'],
#  ['look', 'fuckin', 'time', 'fuck', 'think'],
#  ['yo', 'guess', 'dropped'],
#  ['carlos', 'say', 'mu', 'lt', 'gt', 'minute'],
#  ['office', 'call', 'lt', 'gt', 'min'],
#  ['geeee',
#   'miss',
#   'already',
#   'know',
#   'think',
#   'fuck',
#   'wait',
#   'till',
#   'next',
#   'year',
#   'together',
#   'loving',
#   'kiss'],
#  ['yun',
#   'ah',
#   'ubi',
#   'one',
#   'say',
#   'wan',
#   'call',
#   'tomorrow',
#   'call',
#   'look',
#   'irene',
#   'ere',
#   'got',
#   'bus',
#   'ubi',
#   'cres',
#   'ubi',
#   'tech',
#   'park',
#   'ph',
#   'st',
#   'wkg',
#   'day'],
#  ['ugh', 'gotta', 'drive', 'back', 'sd', 'la', 'butt', 'sore'],
#  ['th', 'july'],
#  ['hi',
#   'im',
#   'relaxing',
#   'time',
#   'ever',
#   'get',
#   'every',
#   'day',
#   'party',
#   'good',
#   'night',
#   'get',
#   'home',
#   'tomorrow',
#   'ish'],
#  ['wan', 'come', 'come', 'lor', 'din', 'stripe', 'skirt'],
#  ['xmas',
#   'story',
#   'peace',
#   'xmas',
#   'msg',
#   'love',
#   'xmas',
#   'miracle',
#   'jesus',
#   'hav',
#   'blessed',
#   'month',
#   'ahead',
#   'amp',
#   'wish',
#   'merry',
#   'xmas'],
#  ['number'],
#  ['change', 'one', 'next', 'escalator'],
#  ['yetunde', 'class', 'run', 'water', 'make', 'ok', 'pls'],
#  ['lot',
#   'happened',
#   'feel',
#   'quiet',
#   'beth',
#   'aunt',
#   'charlie',
#   'working',
#   'lot',
#   'helen',
#   'mo'],
#  ['wait',
#   'bus',
#   'stop',
#   'aft',
#   'ur',
#   'lect',
#   'lar',
#   'dun',
#   'go',
#   'get',
#   'car',
#   'come',
#   'back',
#   'pick'],
#  ['aight', 'thanks', 'comin'],
#  ['heard', 'abt', 'tat'],
#  ['please',
#   'call',
#   'customer',
#   'service',
#   'representative',
#   'freephone',
#   'pm',
#   'guaranteed',
#   'cash',
#   'prize'],
#  ...]

# %%
## Train our Word2Vec model
import gensim
model = gensim.models.Word2Vec(sentences=words, vector_size=100, window=5, min_count=1, workers=4)

# %%
print("Vocabulary size:", len(model.wv.index_to_key))
# Out:
# Vocabulary size: 7000

# %%
# Check the corpus count (number of sentences used in training)
print("Number of sentences used for training:", model.corpus_count)
# Out:
# Number of sentences used for training: 5564

# %%
model.epochs
# Out:
# 5

# %%
model.wv.similar_by_word('good')
# Out:
# [('get', 0.9996623992919922),
#  ('day', 0.9996502995491028),
#  ('going', 0.9996358752250671),
#  ('go', 0.9996338486671448),
#  ('need', 0.999631404876709),
#  ('much', 0.9996204972267151),
#  ('got', 0.9996193647384644),
#  ('want', 0.9996174573898315),
#  ('last', 0.9996129274368286),
#  ('love', 0.9995866417884827)]

# %%
model.wv['good'].shape
# Out:
# (100,)

# %%
vocabulary = set(model.wv.index_to_key)
def avg_word2vec(doc):
    # Convert generator to a list before computing mean
    vectors = [model.wv[word] for word in doc if word in vocabulary]
    if vectors:  # Ensure there are valid vectors to compute mean
        return np.mean(vectors, axis=0)
    else:
        return np.zeros(model.vector_size)  # Return a zero vector if no words are in the vocabulary

# %%
import numpy as np
X = []
for i in range(len(words)):
    X.append(avg_word2vec(words[i]))

# %%
X
# Out:
# [array([-0.09921931,  0.18664375,  0.02273461, -0.00734869, -0.009332  ,
#         -0.24551101,  0.05735633,  0.37138054, -0.1881552 , -0.07047191,
#         -0.11365795, -0.31849512,  0.00401605,  0.09237561,  0.08308922,
#         -0.12875429,  0.00487332, -0.2557651 , -0.01167506, -0.29734755,
#          0.12172519,  0.09048425,  0.04277093, -0.07871895, -0.10768671,
#          0.02599582, -0.11684384, -0.11285295, -0.17783244, -0.006338  ,
#          0.15730672,  0.02510151,  0.00371873, -0.11982765, -0.07131241,
#          0.17965353,  0.01781662, -0.1436274 , -0.09651916, -0.35865885,
#          0.02896593, -0.15491556, -0.08288794,  0.00891151,  0.16288865,
#         -0.07734079, -0.147913  ,  0.00147562,  0.08367565,  0.12892683,
#          0.08670188, -0.17420624, -0.04672887, -0.00653089, -0.14222674,
#          0.10217095,  0.13701563, -0.02815722, -0.19021773,  0.06352683,
#          0.03124337,  0.09515809, -0.07496464,  0.01442155, -0.18588556,
#          0.16619763,  0.07806679,  0.11052433, -0.2498301 ,  0.24425836,
#         -0.08734541,  0.06062856,  0.25269288, -0.0444518 ,  0.20234612,
#          0.14316857,  0.03324363, -0.04438128, -0.18003507,  0.06930882,
#         -0.07762302, -0.02297012, -0.21575724,  0.25648132, -0.06758267,
#          0.01054422, -0.03518768,  0.22555853,  0.255755  ,  0.09417102,
#          0.20470819,  0.10592727, -0.01475927,  0.05962008,  0.32943994,
#          0.20700379,  0.13042791, -0.234744  ,  0.10457172,  0.03486326],
#        dtype=float32),
#  array([-0.07298904,  0.13914861,  0.01631689, -0.00746641, -0.00394057,
#         -0.18432249,  0.04404784,  0.27501303, -0.1442374 , -0.05043934,
#         -0.08231859, -0.23579511,  0.0024766 ,  0.06974808,  0.05922014,
#         -0.09599338,  0.00765095, -0.19072255, -0.0104052 , -0.22454047,
#          0.09114142,  0.06921145,  0.03470588, -0.06526689, -0.08066843,
#          0.01520495, -0.08993185, -0.08620898, -0.13733533, -0.00305484,
#          0.12417017,  0.01945881,  0.00454549, -0.08597343, -0.05421511,
#          0.14062434,  0.01262561, -0.10620065, -0.07620917, -0.27140063,
#          0.02321   , -0.11781148, -0.06188246,  0.00945242,  0.1257671 ,
#         -0.05915464, -0.11118644, -0.0005936 ,  0.0668482 ,  0.09677251,
#          0.06101345, -0.13358802, -0.03654791,  0.00141032, -0.11006151,
#          0.07422549,  0.10151236, -0.02248561, -0.137948  ,  0.04669007,
#          0.02264911,  0.07281975, -0.05489714,  0.01405608, -0.14100996,
#          0.12439138,  0.05995987,  0.08350464, -0.18985118,  0.18587486,
#         -0.06453302,  0.04143475,  0.1911969 , -0.03346127,  0.15243477,
#          0.10818219,  0.02350782, -0.03440493, -0.1382877 ,  0.05065358,
#         -0.05405623, -0.01254075, -0.16817653,  0.19808082, -0.05137438,
#          0.01078126, -0.02289509,  0.16522144,  0.19375995,  0.07158696,
#          0.1546962 ,  0.07959048, -0.01344737,  0.04457664,  0.24462152,
#          0.1560053 ,  0.10009722, -0.17829219,  0.07834308,  0.0256155 ],
#        dtype=float32),
#  array([-0.10502845,  0.20634846,  0.02241805, -0.00408375, -0.00420002,
#         -0.25306898,  0.06059093,  0.38763937, -0.19541357, -0.0728898 ,
#         -0.117278  , -0.3374783 ,  0.00362998,  0.10014929,  0.08640939,
#         -0.13415878,  0.00206894, -0.2676012 , -0.0147143 , -0.30850938,
#          0.12855288,  0.09860243,  0.04195199, -0.07722722, -0.10558721,
#          0.02557223, -0.11965498, -0.11694537, -0.18793881, -0.00837969,
#          0.16508646,  0.01810583,  0.00255601, -0.12407591, -0.07048661,
#          0.19461969,  0.02292269, -0.15046723, -0.09688289, -0.3808177 ,
#          0.0256672 , -0.16213708, -0.08644529,  0.01439641,  0.16620678,
#         -0.08269088, -0.1469119 ,  0.00288176,  0.08422295,  0.13289794,
#          0.08787234, -0.18392241, -0.0437057 , -0.00097771, -0.14932846,
#          0.10811017,  0.14492567, -0.03070058, -0.19784924,  0.06499269,
#          0.03419624,  0.10029592, -0.07600321,  0.01615167, -0.19457774,
#          0.17589037,  0.08624209,  0.11438876, -0.25948507,  0.2617557 ,
#         -0.08819071,  0.06314851,  0.26834548, -0.04163799,  0.21008885,
#          0.15441735,  0.02892254, -0.05156443, -0.18800029,  0.07202376,
#         -0.08308358, -0.0262129 , -0.22389027,  0.27279574, -0.07169373,
#          0.0091603 , -0.03729065,  0.23457181,  0.26995775,  0.10043822,
#          0.21323612,  0.11469042, -0.0142002 ,  0.06356892,  0.3474961 ,
#          0.21659033,  0.139137  , -0.24541506,  0.11070915,  0.03971911],
#        dtype=float32),
#  array([-0.14164767,  0.2676531 ,  0.03145637, -0.00502406, -0.01277768,
#         -0.34679505,  0.08153529,  0.5324363 , -0.2731038 , -0.09513023,
#         -0.16708903, -0.45439824,  0.0049569 ,  0.13185667,  0.11828565,
#         -0.18654954,  0.00884163, -0.36610794, -0.01848067, -0.4229802 ,
#          0.17603342,  0.1332836 ,  0.07110431, -0.11334623, -0.15176617,
#          0.03845949, -0.16619505, -0.15739359, -0.25284216, -0.00636351,
#          0.22402829,  0.0300004 ,  0.00997172, -0.1790152 , -0.09767512,
#          0.26014867,  0.02198704, -0.20566891, -0.13797759, -0.51931715,
#          0.03620311, -0.2222177 , -0.11951375,  0.02340136,  0.23201603,
#         -0.10876736, -0.20945643,  0.00063561,  0.119172  ,  0.18135102,
#          0.12725322, -0.24846645, -0.07258642, -0.00519794, -0.19807197,
#          0.14482485,  0.19227302, -0.04226564, -0.2691765 ,  0.0911161 ,
#          0.04182656,  0.13389917, -0.11068875,  0.02476063, -0.26853153,
#          0.23830475,  0.11501971,  0.1600305 , -0.35399747,  0.35798785,
#         -0.12819368,  0.08407757,  0.36168587, -0.05600415,  0.2872227 ,
#          0.2048734 ,  0.04547047, -0.0705841 , -0.25730157,  0.09931841,
#         -0.10609917, -0.02615338, -0.3123437 ,  0.36110184, -0.09938503,
#          0.01254869, -0.05293939,  0.31952   ,  0.36286554,  0.13118333,
#          0.29158673,  0.15288764, -0.01922549,  0.08673629,  0.47008076,
#          0.29206738,  0.19142312, -0.33172655,  0.14482577,  0.04736409],
#        dtype=float32),
#  array([-0.14553784,  0.26830158,  0.03492146, -0.01355123, -0.011538  ,
#         -0.3462163 ,  0.07875204,  0.5286499 , -0.26798925, -0.09960394,
#         -0.16300239, -0.4568595 ,  0.00578497,  0.13426538,  0.11993514,
#         -0.18642919,  0.00142013, -0.36720905, -0.01904486, -0.4247629 ,
#          0.17159496,  0.12835817,  0.06482213, -0.11218963, -0.15331848,
#          0.03568686, -0.16235499, -0.15918462, -0.25443292, -0.01203947,
#          0.22824235,  0.03477981,  0.00474782, -0.17646071, -0.09877597,
#          0.2579618 ,  0.02899494, -0.20421007, -0.13544202, -0.52045596,
#          0.04324005, -0.21928419, -0.1164286 ,  0.01680281,  0.23212878,
#         -0.11242967, -0.20761605,  0.00637268,  0.11895593,  0.18360102,
#          0.12388929, -0.2420461 , -0.06755652, -0.00366483, -0.20618705,
#          0.1410955 ,  0.18865451, -0.04008433, -0.270294  ,  0.08855215,
#          0.04151589,  0.13793664, -0.10256671,  0.02061401, -0.26724488,
#          0.23594058,  0.11468625,  0.15479147, -0.3565154 ,  0.3509536 ,
#         -0.12158792,  0.0860809 ,  0.36203864, -0.05742004,  0.2880419 ,
#          0.20712098,  0.04269769, -0.06359394, -0.257288  ,  0.09975326,
#         -0.11159768, -0.0309067 , -0.31003943,  0.3632231 , -0.09954109,
#          0.01068178, -0.05323375,  0.3186011 ,  0.36794615,  0.13361727,
#          0.2927854 ,  0.15518527, -0.02443538,  0.07924015,  0.46620753,
#          0.29458493,  0.18879367, -0.33361596,  0.15072891,  0.04806675],
#        dtype=float32),
#  array([-0.1283451 ,  0.23718023,  0.0293916 , -0.00539986, -0.00595906,
#         -0.3140252 ,  0.06867149,  0.47450772, -0.24093443, -0.08980049,
#         -0.14481698, -0.4070542 ,  0.00376065,  0.12212104,  0.10780884,
#         -0.16432017,  0.00385403, -0.32978272, -0.01364156, -0.38011768,
#          0.15630475,  0.11221799,  0.05657987, -0.10229252, -0.13632122,
#          0.03213893, -0.14836662, -0.13900596, -0.22802052, -0.00726897,
#          0.20325994,  0.03063482,  0.00743233, -0.15378311, -0.08636709,
#          0.23027202,  0.02355672, -0.18510261, -0.12331548, -0.46290657,
#          0.03407499, -0.19632964, -0.10239244,  0.01640199,  0.20760752,
#         -0.10008772, -0.18713847,  0.00412391,  0.10507555,  0.1666265 ,
#          0.10943237, -0.22190611, -0.05791194, -0.00291442, -0.18246609,
#          0.12710692,  0.17379066, -0.03445919, -0.23941712,  0.08151063,
#          0.03926821,  0.12383164, -0.09344961,  0.02671094, -0.23994611,
#          0.21302849,  0.10371323,  0.14187345, -0.32120454,  0.31961405,
#         -0.10871979,  0.07629312,  0.3274705 , -0.05063003,  0.25815287,
#          0.1847617 ,  0.03823049, -0.05729387, -0.22922048,  0.08747139,
#         -0.09868351, -0.02768308, -0.27932677,  0.3313349 , -0.08697976,
#          0.01029055, -0.04268041,  0.28617555,  0.32933837,  0.11921132,
#          0.26196948,  0.13707843, -0.02092262,  0.07742342,  0.41723117,
#          0.26369926,  0.16710398, -0.30324775,  0.13530865,  0.04565648],
#        dtype=float32),
#  array([-0.12320516,  0.24137212,  0.02996034, -0.01032562, -0.0047385 ,
#         -0.30929387,  0.0723028 ,  0.47044978, -0.23804241, -0.0905517 ,
#         -0.14162585, -0.39787084,  0.00410363,  0.12219215,  0.10808553,
#         -0.16429824,  0.0080135 , -0.3279095 , -0.01160376, -0.377958  ,
#          0.1559542 ,  0.11322922,  0.05715996, -0.10394567, -0.13625543,
#          0.0306812 , -0.14268315, -0.13744211, -0.2238263 , -0.00693676,
#          0.19717947,  0.03152259,  0.0041546 , -0.15476474, -0.08433899,
#          0.22834902,  0.02495486, -0.1792412 , -0.11927883, -0.46027583,
#          0.03445535, -0.19320203, -0.10705009,  0.015158  ,  0.20599069,
#         -0.09897724, -0.18418689,  0.00639221,  0.10307045,  0.16415274,
#          0.11010794, -0.2167651 , -0.05852704, -0.00388932, -0.18303509,
#          0.1254772 ,  0.16886495, -0.03108666, -0.23800915,  0.07985236,
#          0.04072838,  0.12141693, -0.0931051 ,  0.02224325, -0.2402658 ,
#          0.20986603,  0.1040475 ,  0.13930036, -0.31505853,  0.31415194,
#         -0.11204128,  0.08119038,  0.31871432, -0.04806311,  0.25678778,
#          0.1853774 ,  0.03801227, -0.05302414, -0.22814533,  0.08837971,
#         -0.09601978, -0.02369027, -0.2737319 ,  0.32376587, -0.0857617 ,
#          0.01336824, -0.04045175,  0.2787914 ,  0.33148366,  0.12103287,
#          0.25858697,  0.1316706 , -0.02310137,  0.07480716,  0.4165589 ,
#          0.25829676,  0.16157347, -0.2996671 ,  0.13294753,  0.0446782 ],
#        dtype=float32),
#  array([-0.05412358,  0.10206947,  0.01264785, -0.00352337, -0.00352335,
#         -0.12929021,  0.02866951,  0.19320911, -0.10226826, -0.03632518,
#         -0.06262083, -0.17192486,  0.00074796,  0.0503317 ,  0.04630128,
#         -0.06857143,  0.0030447 , -0.1370271 , -0.00674505, -0.15750855,
#          0.06516499,  0.04609758,  0.0227506 , -0.04039582, -0.0588953 ,
#          0.01213697, -0.06031666, -0.05827319, -0.09516943, -0.00225882,
#          0.08268932,  0.00953909,  0.00302864, -0.06438693, -0.03296055,
#          0.09921603,  0.01141164, -0.07763018, -0.05125354, -0.19459863,
#          0.01131243, -0.08215227, -0.04375565,  0.00593385,  0.08613907,
#         -0.03989374, -0.07585151,  0.00232083,  0.04782113,  0.06882504,
#          0.04417388, -0.0924239 , -0.02222137, -0.0029437 , -0.07848228,
#          0.0527342 ,  0.07179256, -0.01404864, -0.09803502,  0.03239301,
#          0.01625929,  0.05570208, -0.04164913,  0.01153976, -0.09501007,
#          0.09093437,  0.04319479,  0.0596688 , -0.13415079,  0.13029201,
#         -0.04596033,  0.02878485,  0.13628004, -0.02116623,  0.1116943 ,
#          0.07634805,  0.02063619, -0.02457856, -0.09443033,  0.03723216,
#         -0.04003668, -0.01249767, -0.11468475,  0.14153682, -0.03961801,
#          0.00293871, -0.0174266 ,  0.11850985,  0.1409052 ,  0.05180278,
#          0.10522809,  0.05722986, -0.00855058,  0.03465144,  0.17405273,
#          0.10943141,  0.07049176, -0.12701117,  0.05465122,  0.02035576],
#        dtype=float32),
#  array([-0.10589079,  0.21601142,  0.02847751, -0.00487245, -0.01149757,
#         -0.2604555 ,  0.06479993,  0.40401125, -0.20381196, -0.07815735,
#         -0.11911712, -0.35411546,  0.00101287,  0.10302436,  0.08279193,
#         -0.13668185,  0.00847417, -0.2777935 , -0.01571574, -0.31690633,
#          0.13151534,  0.10679342,  0.04394114, -0.07695936, -0.10775764,
#          0.02540675, -0.12215833, -0.11614498, -0.19323112, -0.00750934,
#          0.1674103 ,  0.01783871,  0.00395396, -0.13270955, -0.07094727,
#          0.19944724,  0.02838442, -0.16586685, -0.09484474, -0.39997306,
#          0.01901009, -0.16514198, -0.09077518,  0.01473574,  0.17740835,
#         -0.08276746, -0.15287592,  0.00842559,  0.09155674,  0.14175244,
#          0.08415432, -0.19060658, -0.05100756, -0.00373772, -0.15396804,
#          0.11056281,  0.14763641, -0.03218545, -0.20659648,  0.06685711,
#          0.03911022,  0.10262539, -0.08492673,  0.01704912, -0.20352148,
#          0.18318623,  0.08552756,  0.12266432, -0.2714919 ,  0.26218528,
#         -0.09430625,  0.06564663,  0.27587494, -0.0424319 ,  0.22331648,
#          0.16681118,  0.02939811, -0.06114312, -0.193878  ,  0.07434803,
#         -0.08264519, -0.02569823, -0.22831018,  0.29412365, -0.07196905,
#          0.00776513, -0.04453409,  0.23959345,  0.27114037,  0.10998319,
#          0.22149016,  0.11811323, -0.01684024,  0.06353145,  0.36627415,
#          0.22754936,  0.14419454, -0.26008922,  0.11736748,  0.0427319 ],
#        dtype=float32),
#  array([-0.17739321,  0.3451155 ,  0.04044179, -0.00307589, -0.00999787,
#         -0.42197594,  0.10564811,  0.6445344 , -0.32396737, -0.11240929,
#         -0.19365923, -0.5595968 ,  0.00547054,  0.16309634,  0.1428646 ,
#         -0.22829959,  0.00363594, -0.44776672, -0.01950012, -0.5086934 ,
#          0.22133228,  0.15874949,  0.0749047 , -0.13221996, -0.17384999,
#          0.04250612, -0.2023712 , -0.1888497 , -0.31633067, -0.02261803,
#          0.27011186,  0.03159353,  0.01278939, -0.20360373, -0.11502637,
#          0.31209472,  0.04278354, -0.24889512, -0.16360189, -0.62459296,
#          0.02929076, -0.26653352, -0.13986517,  0.02053085,  0.27445203,
#         -0.14023831, -0.2429142 ,  0.01339879,  0.1426558 ,  0.22794183,
#          0.13876991, -0.30454904, -0.07926043, -0.00372223, -0.2460983 ,
#          0.17044012,  0.24255851, -0.05730632, -0.32595655,  0.104192  ,
#          0.0565731 ,  0.16244671, -0.12645042,  0.02249005, -0.32825947,
#          0.2918388 ,  0.13336562,  0.19284153, -0.43466884,  0.43145558,
#         -0.15018733,  0.1050038 ,  0.45317173, -0.06703459,  0.3463555 ,
#          0.25713348,  0.04721347, -0.08505137, -0.31511238,  0.11477286,
#         -0.13460824, -0.04065358, -0.36969274,  0.45448032, -0.11357876,
#          0.01542905, -0.06325858,  0.38322327,  0.446282  ,  0.16504891,
#          0.35019916,  0.18970004, -0.01734152,  0.09957527,  0.5759806 ,
#          0.35739064,  0.22155473, -0.4016815 ,  0.17779395,  0.0628605 ],
#        dtype=float32),
#  array([-0.1220471 ,  0.22925109,  0.03134276, -0.00483693, -0.01027472,
#         -0.30058077,  0.07103703,  0.45264122, -0.23241691, -0.0875742 ,
#         -0.13984978, -0.38860658,  0.00367083,  0.11408227,  0.1019801 ,
#         -0.15899843,  0.00701444, -0.31443605, -0.01673209, -0.3617552 ,
#          0.14573774,  0.10885905,  0.05307585, -0.09773812, -0.12971605,
#          0.03042242, -0.14002715, -0.13509312, -0.21441402, -0.00792241,
#          0.19056271,  0.03177837,  0.00896709, -0.14697585, -0.0834428 ,
#          0.22018619,  0.02860685, -0.17571653, -0.11738691, -0.43653348,
#          0.03520594, -0.186549  , -0.09737459,  0.01449281,  0.19638993,
#         -0.09807611, -0.17675097,  0.00171571,  0.10146365,  0.1551973 ,
#          0.10963646, -0.21063353, -0.05760157, -0.00546992, -0.1688684 ,
#          0.12305333,  0.1656176 , -0.03452004, -0.22585867,  0.07999111,
#          0.0324398 ,  0.11771536, -0.09121329,  0.01822691, -0.22714931,
#          0.20291515,  0.09707606,  0.13319546, -0.30289373,  0.29952362,
#         -0.10702689,  0.07056119,  0.30749926, -0.0480492 ,  0.24448389,
#          0.17936793,  0.03846034, -0.0527867 , -0.22138824,  0.08713823,
#         -0.09340691, -0.02030055, -0.26324755,  0.3118522 , -0.08069552,
#          0.01730222, -0.0409873 ,  0.27004853,  0.3174753 ,  0.11666603,
#          0.25152653,  0.1309558 , -0.01624616,  0.07010024,  0.3998811 ,
#          0.24902281,  0.16110565, -0.28893554,  0.13177381,  0.04610856],
#        dtype=float32),
#  array([-0.14244989,  0.27142757,  0.03336047, -0.00529757, -0.00643971,
#         -0.34751847,  0.07953357,  0.5277133 , -0.26725516, -0.09935078,
#         -0.16282092, -0.4612019 ,  0.00898218,  0.1360455 ,  0.11724679,
#         -0.18193918,  0.00325588, -0.36274967, -0.01779381, -0.4229839 ,
#          0.17625871,  0.13116027,  0.06090125, -0.11214177, -0.14702897,
#          0.03572626, -0.16129668, -0.15655597, -0.2543657 , -0.00991733,
#          0.22318944,  0.0321219 ,  0.00626947, -0.17340209, -0.09922295,
#          0.25950113,  0.02938626, -0.20628926, -0.13428633, -0.5206178 ,
#          0.04003572, -0.22109754, -0.11719955,  0.01821348,  0.22992183,
#         -0.11408815, -0.20691343,  0.00301772,  0.11911412,  0.1831725 ,
#          0.11901502, -0.25198337, -0.06154222, -0.00718219, -0.20180392,
#          0.1469853 ,  0.19446515, -0.04034881, -0.26694205,  0.09052636,
#          0.04524698,  0.13717894, -0.10785757,  0.02716118, -0.26564798,
#          0.24076508,  0.11380692,  0.15515545, -0.35606688,  0.35302123,
#         -0.12068617,  0.08303079,  0.3666909 , -0.05718694,  0.28916255,
#          0.20937566,  0.04116144, -0.07135315, -0.2574833 ,  0.09661683,
#         -0.11125501, -0.03327957, -0.31039903,  0.37238663, -0.09795659,
#          0.01092185, -0.04849891,  0.3208563 ,  0.36759007,  0.13650551,
#          0.2932179 ,  0.15672347, -0.02211265,  0.08379439,  0.4702344 ,
#          0.29617468,  0.18342921, -0.33785683,  0.15113187,  0.05313159],
#        dtype=float32),
#  array([-0.12814446,  0.24824731,  0.03063774, -0.00543841, -0.0081003 ,
#         -0.30398765,  0.07392614,  0.46701407, -0.23444985, -0.08636274,
#         -0.14153919, -0.4067128 ,  0.00292893,  0.11914053,  0.10135384,
#         -0.15897343,  0.00337881, -0.32156038, -0.01727525, -0.36879936,
#          0.15441808,  0.1179472 ,  0.05222825, -0.09370106, -0.1260591 ,
#          0.03162617, -0.1417465 , -0.13459119, -0.22432639, -0.01051006,
#          0.19579822,  0.02314433,  0.00535963, -0.14745165, -0.08543065,
#          0.22952138,  0.02907506, -0.18506378, -0.11342505, -0.4597454 ,
#          0.02492976, -0.19366561, -0.1038606 ,  0.01755887,  0.201405  ,
#         -0.10014703, -0.17668259,  0.00507112,  0.10316065,  0.16348356,
#          0.10533387, -0.22054853, -0.05566956, -0.00639277, -0.18099111,
#          0.13024707,  0.17594694, -0.03464547, -0.23497328,  0.0758931 ,
#          0.04039831,  0.11961104, -0.09324871,  0.02095195, -0.23486279,
#          0.21168076,  0.1000808 ,  0.1392732 , -0.3155227 ,  0.30941156,
#         -0.10768558,  0.07631522,  0.32114485, -0.04702966,  0.2527853 ,
#          0.18554904,  0.03477547, -0.06397481, -0.22602925,  0.08633254,
#         -0.09527712, -0.02852484, -0.26965755,  0.33187586, -0.08556177,
#          0.01071192, -0.04296359,  0.27862096,  0.31779835,  0.12202561,
#          0.25703   ,  0.13668476, -0.02005233,  0.07354554,  0.41820222,
#          0.26504484,  0.1655785 , -0.29657885,  0.13279296,  0.04905939],
#        dtype=float32),
#  array([-0.08546595,  0.15000723,  0.02109674, -0.00573757, -0.00567572,
#         -0.19597608,  0.04424438,  0.29801717, -0.15089421, -0.05600376,
#         -0.09046044, -0.25516745,  0.0042789 ,  0.07690709,  0.06919184,
#         -0.10428549,  0.00224193, -0.20497067, -0.00753527, -0.23737335,
#          0.09864555,  0.07158648,  0.03326784, -0.06664603, -0.08365075,
#          0.01476717, -0.09467319, -0.08787321, -0.14317146, -0.00694001,
#          0.12576844,  0.02159433,  0.00452629, -0.09753982, -0.05509433,
#          0.14783846,  0.01724912, -0.11838822, -0.07739512, -0.29142353,
#          0.02263255, -0.12174397, -0.06245246,  0.00976878,  0.13073808,
#         -0.06356006, -0.11749821,  0.00289565,  0.06555918,  0.10326148,
#          0.07127487, -0.13723087, -0.03592337, -0.00117191, -0.11496461,
#          0.08146507,  0.10879546, -0.02415814, -0.1509052 ,  0.05139418,
#          0.02302997,  0.07783567, -0.05864912,  0.01412757, -0.15001127,
#          0.13353987,  0.06446625,  0.08814518, -0.20003782,  0.20002677,
#         -0.07117457,  0.05044685,  0.2043838 , -0.02847395,  0.16503511,
#          0.11597533,  0.02515691, -0.03717977, -0.14096574,  0.05637065,
#         -0.06328501, -0.01732195, -0.17471422,  0.20788184, -0.05754076,
#          0.01096119, -0.02412177,  0.1768443 ,  0.2068718 ,  0.07544501,
#          0.16255675,  0.0895847 , -0.01265042,  0.04733076,  0.26291198,
#          0.16334505,  0.1027168 , -0.19024563,  0.08425163,  0.0275812 ],
#        dtype=float32),
#  array([-0.04788323,  0.0897727 ,  0.00992249, -0.00418097, -0.00210336,
#         -0.11246249,  0.0269415 ,  0.17740302, -0.09155364, -0.03110663,
#         -0.04908929, -0.15167025,  0.00247371,  0.04426575,  0.03860617,
#         -0.05737654,  0.00278263, -0.12213241, -0.00795653, -0.1440653 ,
#          0.0640263 ,  0.04782484,  0.02436627, -0.03981742, -0.04525963,
#          0.01370457, -0.05038535, -0.06025606, -0.07870759, -0.00386326,
#          0.07146423,  0.0137848 , -0.00529002, -0.06261184, -0.0331259 ,
#          0.08707877,  0.00120635, -0.06821512, -0.05275888, -0.17184182,
#          0.004176  , -0.06663544, -0.04379474,  0.00723439,  0.06877002,
#         -0.0428994 , -0.06687264,  0.00560109,  0.04057054,  0.06372791,
#          0.04278211, -0.08276197, -0.01623507, -0.00048935, -0.064625  ,
#          0.04850587,  0.06450304, -0.0132188 , -0.0839525 ,  0.02542839,
#          0.01947112,  0.04875048, -0.04407311,  0.01220561, -0.09460878,
#          0.07263093,  0.03027863,  0.04899038, -0.11770238,  0.11002025,
#         -0.03606898,  0.03344901,  0.121903  , -0.01409237,  0.09121369,
#          0.06828834,  0.01807731, -0.02463811, -0.0880758 ,  0.02687224,
#         -0.03709377, -0.01618272, -0.10002834,  0.12018472, -0.02722866,
#          0.00511133, -0.02409966,  0.11327019,  0.12954111,  0.04834034,
#          0.10305107,  0.04449275, -0.0057188 ,  0.02786075,  0.15778024,
#          0.09629837,  0.06645896, -0.11535121,  0.05194147,  0.02144901],
#        dtype=float32),
#  array([-9.93711129e-02,  1.88715056e-01,  2.31279805e-02, -7.35943252e-03,
#         -5.35767339e-03, -2.36216366e-01,  5.27943932e-02,  3.60793084e-01,
#         -1.82315975e-01, -6.63990900e-02, -1.10295765e-01, -3.12016308e-01,
#          6.43011462e-03,  9.46814865e-02,  8.10953826e-02, -1.23260498e-01,
#          6.19042621e-05, -2.50265658e-01, -1.03473505e-02, -2.87785888e-01,
#          1.19886518e-01,  8.41696411e-02,  4.06707190e-02, -7.33808726e-02,
#         -1.00109071e-01,  1.89100914e-02, -1.15036689e-01, -1.06394447e-01,
#         -1.75839171e-01, -8.16662982e-03,  1.53293729e-01,  2.30891891e-02,
#          8.14889651e-03, -1.15611620e-01, -6.61901757e-02,  1.79016754e-01,
#          2.10353006e-02, -1.37808114e-01, -9.40341577e-02, -3.49974513e-01,
#          2.70837434e-02, -1.53567731e-01, -7.82088414e-02,  1.43019427e-02,
#          1.56552792e-01, -8.00383091e-02, -1.40882477e-01,  1.40016328e-03,
#          8.34012702e-02,  1.29755959e-01,  8.08997974e-02, -1.68531999e-01,
#         -4.28698622e-02,  1.34287577e-03, -1.38003111e-01,  9.66694355e-02,
#          1.35178298e-01, -2.81459223e-02, -1.81663439e-01,  6.20257184e-02,
#          3.06919515e-02,  9.27186385e-02, -6.89462721e-02,  1.87984928e-02,
#         -1.78777993e-01,  1.66073978e-01,  8.31687078e-02,  1.06299400e-01,
#         -2.45007351e-01,  2.45828807e-01, -8.18798617e-02,  5.91544434e-02,
#          2.48329654e-01, -3.85759510e-02,  1.95295900e-01,  1.38122618e-01,
#          2.86183935e-02, -4.44866829e-02, -1.74466074e-01,  6.60863966e-02,
#         -7.75855407e-02, -2.18584239e-02, -2.12635979e-01,  2.52529651e-01,
#         -6.64845631e-02,  1.20009175e-02, -3.61980721e-02,  2.15623632e-01,
#          2.49863610e-01,  9.34361219e-02,  1.96711168e-01,  1.04404457e-01,
#         -1.50178559e-02,  5.77926561e-02,  3.19444507e-01,  2.00362131e-01,
#          1.21661000e-01, -2.28667423e-01,  1.01062141e-01,  3.97092924e-02],
#        dtype=float32),
#  array([-1.16484642e-01,  2.23065466e-01,  2.48030908e-02, -1.52983621e-03,
#         -7.61537114e-03, -2.86277086e-01,  6.62841648e-02,  4.37961936e-01,
#         -2.19468340e-01, -8.33125561e-02, -1.29654527e-01, -3.67036194e-01,
#         -4.47017606e-03,  1.14550009e-01,  9.65503901e-02, -1.56107426e-01,
#          1.20940283e-02, -2.98635274e-01, -1.41543159e-02, -3.41967106e-01,
#          1.37998998e-01,  1.03855170e-01,  5.24548180e-02, -1.00060515e-01,
#         -1.30328238e-01,  1.99681688e-02, -1.34777814e-01, -1.30850255e-01,
#         -2.02158660e-01, -5.22704935e-03,  1.85933381e-01,  2.34282035e-02,
#         -1.44251157e-04, -1.39061570e-01, -8.70685875e-02,  2.12402135e-01,
#          2.45136395e-02, -1.68812826e-01, -1.11903697e-01, -4.16089386e-01,
#          3.81135568e-02, -1.76916599e-01, -9.28891227e-02,  1.39146522e-02,
#          1.87091261e-01, -9.30843130e-02, -1.71248510e-01,  5.44155948e-04,
#          1.01468764e-01,  1.52881742e-01,  1.06535286e-01, -2.03651339e-01,
#         -4.88209426e-02, -8.83811712e-03, -1.70526177e-01,  1.20705582e-01,
#          1.62464261e-01, -3.42665017e-02, -2.17189953e-01,  7.16354027e-02,
#          3.19218710e-02,  1.16092861e-01, -8.69476274e-02,  2.19235662e-02,
#         -2.10475326e-01,  1.86453983e-01,  8.54043737e-02,  1.31148770e-01,
#         -2.88209856e-01,  2.84610033e-01, -1.06138676e-01,  7.09211975e-02,
#          2.94761777e-01, -4.45327498e-02,  2.39100486e-01,  1.60026118e-01,
#          3.41814086e-02, -5.17895967e-02, -2.05547601e-01,  7.79863074e-02,
#         -8.95067751e-02, -2.65485961e-02, -2.55814910e-01,  3.03274453e-01,
#         -7.46388435e-02,  1.25025110e-02, -3.99363488e-02,  2.59268790e-01,
#          3.05652559e-01,  1.15413316e-01,  2.38558039e-01,  1.28805175e-01,
#         -1.34037705e-02,  6.67463988e-02,  3.82097900e-01,  2.36752599e-01,
#          1.46796554e-01, -2.72639453e-01,  1.27124026e-01,  4.04447466e-02],
#        dtype=float32),
#  array([-0.09128308,  0.17079525,  0.02116188, -0.00560733, -0.0090481 ,
#         -0.22883427,  0.05524315,  0.3437836 , -0.17506924, -0.06474612,
#         -0.107051  , -0.29448903, -0.00228219,  0.08739372,  0.07934695,
#         -0.11778536,  0.00247838, -0.24128248, -0.00830653, -0.27091402,
#          0.11283994,  0.08224644,  0.04172291, -0.07794517, -0.09655062,
#          0.02372475, -0.10959996, -0.104499  , -0.1620681 , -0.00718098,
#          0.14658266,  0.02043391,  0.00361264, -0.11102096, -0.06077756,
#          0.17104667,  0.01863865, -0.13215998, -0.09078286, -0.33778575,
#          0.02529945, -0.1454434 , -0.07635657,  0.01339825,  0.14951141,
#         -0.06931521, -0.13533531,  0.00294356,  0.07996976,  0.1213695 ,
#          0.07980675, -0.15967454, -0.04452707, -0.00353488, -0.13361494,
#          0.08733968,  0.12770982, -0.02464208, -0.17343915,  0.05671955,
#          0.02712718,  0.08709568, -0.06828374,  0.0186136 , -0.17182858,
#          0.15262015,  0.07478632,  0.10047147, -0.22940066,  0.23162068,
#         -0.08123881,  0.05683286,  0.23632424, -0.03918851,  0.18670066,
#          0.12989956,  0.03000057, -0.04235119, -0.16394101,  0.06416095,
#         -0.07021574, -0.02155449, -0.20385285,  0.23715605, -0.06054385,
#          0.00898872, -0.03011327,  0.20713149,  0.23805603,  0.08981343,
#          0.18692984,  0.10092923, -0.01750202,  0.05281565,  0.30308872,
#          0.19050533,  0.1158262 , -0.2208908 ,  0.09934602,  0.03449545],
#        dtype=float32),
#  array([-0.13612543,  0.25975022,  0.03651106, -0.00853147, -0.00610197,
#         -0.34046632,  0.08040272,  0.51070243, -0.26815984, -0.0943571 ,
#         -0.15930343, -0.44470245,  0.00495958,  0.12868658,  0.11918541,
#         -0.18078662,  0.00551065, -0.3557428 , -0.01492163, -0.40814084,
#          0.1739275 ,  0.12160877,  0.05805577, -0.11247268, -0.15157029,
#          0.0362568 , -0.15254757, -0.1542044 , -0.24784128, -0.00857056,
#          0.2211133 ,  0.03013199,  0.00527421, -0.16880052, -0.09562631,
#          0.24836671,  0.02874046, -0.19582698, -0.13119741, -0.49805102,
#          0.03786939, -0.21140814, -0.11459124,  0.01925826,  0.22377141,
#         -0.10536349, -0.20026252,  0.00266866,  0.1123708 ,  0.183897  ,
#          0.12828502, -0.24254091, -0.06508985, -0.00876988, -0.1978617 ,
#          0.14039215,  0.18078104, -0.0408911 , -0.26373234,  0.08366596,
#          0.0362496 ,  0.13736752, -0.10174289,  0.01913179, -0.25407216,
#          0.2307353 ,  0.11449474,  0.1529395 , -0.3451797 ,  0.3415424 ,
#         -0.11942367,  0.08300288,  0.34693903, -0.06166422,  0.28487214,
#          0.20616004,  0.03403642, -0.06038442, -0.24696425,  0.09729178,
#         -0.10496292, -0.02956941, -0.30514804,  0.35419407, -0.0967425 ,
#          0.01872796, -0.04797595,  0.30844694,  0.36288118,  0.13271266,
#          0.27918217,  0.15313378, -0.02007084,  0.07572702,  0.45117497,
#          0.27579537,  0.17947182, -0.3283715 ,  0.15296927,  0.04789127],
#        dtype=float32),
#  array([-0.09276731,  0.17543161,  0.02022237, -0.00339997, -0.00540128,
#         -0.22067861,  0.05159228,  0.33737263, -0.16969346, -0.05971394,
#         -0.10368398, -0.29201943,  0.00509423,  0.08418655,  0.07778212,
#         -0.11761557,  0.00397919, -0.2324522 , -0.00986004, -0.26671416,
#          0.11100155,  0.08230832,  0.03899152, -0.06925704, -0.09442907,
#          0.01968898, -0.10360496, -0.10243899, -0.1633275 , -0.00969024,
#          0.14151052,  0.02034633,  0.00612348, -0.11122838, -0.06394222,
#          0.1648002 ,  0.02210888, -0.13003214, -0.08353648, -0.32784808,
#          0.02308079, -0.13910119, -0.07733625,  0.012762  ,  0.1475306 ,
#         -0.07261379, -0.13096134,  0.00260794,  0.07722363,  0.11873987,
#          0.07733158, -0.15719706, -0.04213518, -0.00510886, -0.12951079,
#          0.09168126,  0.1248082 , -0.02646059, -0.17072088,  0.05509344,
#          0.02802635,  0.09004583, -0.06799366,  0.01455658, -0.16930334,
#          0.15071356,  0.07286172,  0.09977601, -0.22428286,  0.22586584,
#         -0.07963081,  0.05493994,  0.23305695, -0.03589027,  0.18579844,
#          0.13354674,  0.02919243, -0.04173647, -0.16208516,  0.06261373,
#         -0.06811794, -0.02191865, -0.19735709,  0.23630734, -0.06137726,
#          0.00470562, -0.03066   ,  0.20133577,  0.23370934,  0.08871512,
#          0.18509488,  0.10187709, -0.00955293,  0.05323993,  0.2987745 ,
#          0.18835957,  0.12072893, -0.211392  ,  0.09507705,  0.03251949],
#        dtype=float32),
#  array([-0.0699259 ,  0.12209298,  0.01874486,  0.00457052, -0.01186049,
#         -0.1581863 ,  0.03841146,  0.23783831, -0.123175  , -0.04593646,
#         -0.0729266 , -0.20197819,  0.00175734,  0.05793959,  0.0547498 ,
#         -0.08106957,  0.0023724 , -0.167992  , -0.00525424, -0.18409061,
#          0.08103756,  0.05911918,  0.03035546, -0.05385976, -0.06119573,
#          0.01830313, -0.07972053, -0.07270986, -0.11935839, -0.00760038,
#          0.10360551,  0.01452866,  0.00342951, -0.07147338, -0.04424912,
#          0.11735865,  0.01630064, -0.08498794, -0.05952803, -0.24174333,
#          0.01294252, -0.10089931, -0.05317425,  0.01465418,  0.10576124,
#         -0.05050294, -0.09333605,  0.00085433,  0.05771954,  0.08110089,
#          0.0597395 , -0.10956553, -0.03353348, -0.00259322, -0.09174063,
#          0.06103402,  0.09114784, -0.01183655, -0.12191311,  0.0390391 ,
#          0.02156115,  0.05686211, -0.04575491,  0.01118664, -0.11587449,
#          0.10139998,  0.04889998,  0.06915674, -0.16618045,  0.16052626,
#         -0.05485639,  0.0447217 ,  0.16243012, -0.03016766,  0.13277358,
#          0.0876959 ,  0.0170309 , -0.03040156, -0.11716444,  0.04030998,
#         -0.0559907 , -0.01109492, -0.14916256,  0.16978504, -0.03987688,
#          0.00179124, -0.0204816 ,  0.14221746,  0.16577993,  0.06163028,
#          0.12923844,  0.07750891, -0.01544423,  0.03717404,  0.21747245,
#          0.12938966,  0.08105717, -0.15786351,  0.07096645,  0.02598363],
#        dtype=float32),
#  array([-0.10145188,  0.18517725,  0.02523356, -0.00641162, -0.0096015 ,
#         -0.23541206,  0.04875726,  0.36183774, -0.1796652 , -0.06896437,
#         -0.10984642, -0.31037664,  0.00108719,  0.09167106,  0.07964949,
#         -0.12640622,  0.00685178, -0.24876796, -0.0104156 , -0.28604132,
#          0.11800727,  0.08368272,  0.04936177, -0.08192249, -0.10893015,
#          0.02237832, -0.11144736, -0.10451787, -0.16974455, -0.00397324,
#          0.15695082,  0.02595059,  0.00548972, -0.11489001, -0.06235869,
#          0.1722761 ,  0.02401896, -0.13130273, -0.09689719, -0.34513566,
#          0.02496667, -0.14932154, -0.08314446,  0.00434038,  0.15394187,
#         -0.07573026, -0.14320667,  0.00403519,  0.07933711,  0.12352691,
#          0.08207341, -0.16608317, -0.04520654, -0.00235929, -0.14523214,
#          0.09884696,  0.12947054, -0.02131992, -0.18062001,  0.06364441,
#          0.03200751,  0.09551879, -0.0745692 ,  0.01389365, -0.18076254,
#          0.15883923,  0.07535393,  0.10734004, -0.23800613,  0.24229115,
#         -0.08902859,  0.0565781 ,  0.247755  , -0.03849195,  0.19926684,
#          0.13966446,  0.02867599, -0.04880838, -0.17831117,  0.06474772,
#         -0.07784053, -0.02224399, -0.21266   ,  0.25236076, -0.06361307,
#          0.01299755, -0.03591796,  0.21924777,  0.24872895,  0.09328992,
#          0.20075178,  0.10760086, -0.01401675,  0.05686108,  0.31226555,
#          0.20195198,  0.12462354, -0.22717197,  0.10476711,  0.03542727],
#        dtype=float32),
#  array([-0.09375954,  0.1725475 ,  0.0228803 , -0.00513936, -0.00642535,
#         -0.2308016 ,  0.05487794,  0.34606215, -0.17723846, -0.06456205,
#         -0.10530575, -0.29199293, -0.00167809,  0.09034454,  0.07789899,
#         -0.1208823 ,  0.00448871, -0.23992135, -0.00980979, -0.2758614 ,
#          0.11131041,  0.08286168,  0.04436138, -0.06967718, -0.09997526,
#          0.02144153, -0.10604855, -0.10411448, -0.1652366 , -0.00556922,
#          0.14824863,  0.01774265,  0.00146196, -0.11319501, -0.06697616,
#          0.17011173,  0.01814324, -0.13637097, -0.08888557, -0.33752462,
#          0.0277809 , -0.14412032, -0.07715221,  0.010182  ,  0.1548007 ,
#         -0.07576323, -0.14019412,  0.00588949,  0.07857377,  0.11943575,
#          0.07800751, -0.15499802, -0.04260949, -0.00253422, -0.12899199,
#          0.09050027,  0.12772141, -0.02704502, -0.17310613,  0.05792371,
#          0.02424954,  0.09059306, -0.0722893 ,  0.01946542, -0.17426293,
#          0.15228662,  0.07672422,  0.10389772, -0.23126902,  0.22904204,
#         -0.08266971,  0.05189741,  0.2329917 , -0.03820063,  0.18721074,
#          0.13531402,  0.02404559, -0.04199399, -0.16780572,  0.06507143,
#         -0.06937315, -0.01857501, -0.20169652,  0.24267298, -0.06217169,
#          0.010077  , -0.03241351,  0.20622407,  0.24103121,  0.08334508,
#          0.19092274,  0.09696523, -0.01709618,  0.05188039,  0.3015539 ,
#          0.1906116 ,  0.12406754, -0.22324407,  0.10474572,  0.03408026],
#        dtype=float32),
#  array([-0.13777097,  0.25462154,  0.03022644, -0.00788406, -0.00698012,
#         -0.3328399 ,  0.07561654,  0.50996405, -0.2628705 , -0.08909159,
#         -0.15986644, -0.43090302,  0.00482847,  0.1298185 ,  0.11241239,
#         -0.17598829,  0.00959913, -0.35241985, -0.01784888, -0.40996364,
#          0.16339523,  0.12453555,  0.06363433, -0.10941287, -0.14859185,
#          0.03139488, -0.16086142, -0.15072006, -0.24705473, -0.00376609,
#          0.21588948,  0.03154927,  0.00687136, -0.16307482, -0.09607293,
#          0.2481446 ,  0.02229589, -0.19510117, -0.1301519 , -0.49628544,
#          0.04085758, -0.20970026, -0.11519694,  0.01496603,  0.21987598,
#         -0.10842545, -0.1962725 ,  0.0020664 ,  0.11447158,  0.17771982,
#          0.11968141, -0.23798686, -0.06572045, -0.00173231, -0.19898278,
#          0.14240994,  0.18439263, -0.04439192, -0.25623015,  0.08541313,
#          0.03995041,  0.13189863, -0.10182245,  0.02270556, -0.25752357,
#          0.22786409,  0.10952712,  0.14606844, -0.3441692 ,  0.3371024 ,
#         -0.11804541,  0.0836737 ,  0.34771076, -0.05840386,  0.27476403,
#          0.19791397,  0.04448145, -0.06425423, -0.24840425,  0.10019687,
#         -0.10241576, -0.02978767, -0.2974938 ,  0.35416704, -0.09317363,
#          0.01619167, -0.05202225,  0.30786437,  0.35223123,  0.1253375 ,
#          0.2842452 ,  0.14484027, -0.02012023,  0.0769314 ,  0.4499666 ,
#          0.28149217,  0.1798578 , -0.32386148,  0.14601633,  0.04534835],
#        dtype=float32),
#  array([-8.62113535e-02,  1.64706007e-01,  2.07374729e-02, -5.25790593e-03,
#         -4.86358022e-03, -2.12483451e-01,  4.48502451e-02,  3.20993006e-01,
#         -1.69226259e-01, -5.60525768e-02, -9.94232744e-02, -2.80218095e-01,
#          4.60971612e-03,  8.08403343e-02,  7.62235597e-02, -1.12873495e-01,
#          6.00842852e-03, -2.22313836e-01, -1.29239233e-02, -2.62868583e-01,
#          1.03953257e-01,  7.49728829e-02,  4.09328789e-02, -7.09192678e-02,
#         -9.74893942e-02,  2.07938496e-02, -9.68564972e-02, -9.14814621e-02,
#         -1.54668272e-01, -6.12599356e-03,  1.38214603e-01,  1.69015881e-02,
#          2.62344861e-03, -1.10086001e-01, -6.30662739e-02,  1.55919701e-01,
#          1.77598596e-02, -1.23353601e-01, -8.01279396e-02, -3.12927872e-01,
#          2.51177903e-02, -1.36456415e-01, -7.01225325e-02,  9.96658206e-03,
#          1.43402278e-01, -6.96249455e-02, -1.28963768e-01, -2.11340099e-04,
#          6.94622546e-02,  1.13012031e-01,  7.40450546e-02, -1.52386263e-01,
#         -3.58902551e-02, -5.46940649e-03, -1.27391681e-01,  8.17110687e-02,
#          1.12128064e-01, -3.02677862e-02, -1.62587672e-01,  5.63318841e-02,
#          2.22859420e-02,  8.32900852e-02, -6.18167147e-02,  1.63446814e-02,
#         -1.59134477e-01,  1.50030464e-01,  7.50508830e-02,  9.77068916e-02,
#         -2.21521527e-01,  2.15404436e-01, -7.84455687e-02,  5.03907390e-02,
#          2.20542192e-01, -4.14395742e-02,  1.74130619e-01,  1.26902476e-01,
#          2.01527067e-02, -3.62961218e-02, -1.52571782e-01,  5.89787364e-02,
#         -6.81560487e-02, -2.36644335e-02, -1.87966287e-01,  2.24125773e-01,
#         -6.08351752e-02,  1.41308801e-02, -3.80786061e-02,  1.93619460e-01,
#          2.23846510e-01,  8.02231580e-02,  1.80305272e-01,  9.43156108e-02,
#         -1.00299157e-02,  5.09241410e-02,  2.85500079e-01,  1.77939400e-01,
#          1.15402475e-01, -2.05986932e-01,  9.08384621e-02,  2.88140234e-02],
#        dtype=float32),
#  array([-0.07135633,  0.13291916,  0.01605686, -0.00206943, -0.0069368 ,
#         -0.17029603,  0.03678149,  0.260085  , -0.13405298, -0.05123939,
#         -0.08209157, -0.21885793, -0.00098812,  0.06630411,  0.05880395,
#         -0.0887351 ,  0.00359493, -0.18210742, -0.00781207, -0.20629153,
#          0.08580969,  0.06234789,  0.02996724, -0.05437423, -0.07323431,
#          0.01856618, -0.08027617, -0.07724807, -0.12636337, -0.00530633,
#          0.10993473,  0.01988549,  0.00335795, -0.08395639, -0.04869719,
#          0.12751457,  0.01556409, -0.09753119, -0.06588193, -0.25269353,
#          0.02067343, -0.10717636, -0.05722805,  0.0058989 ,  0.11295393,
#         -0.05347534, -0.10285778,  0.00214143,  0.05969337,  0.09013707,
#          0.0621315 , -0.11908245, -0.03315285, -0.00292559, -0.09906139,
#          0.0690821 ,  0.09381216, -0.01815545, -0.13003327,  0.04433315,
#          0.01966347,  0.06729483, -0.05247421,  0.01481511, -0.13191968,
#          0.11435921,  0.05544303,  0.07452323, -0.1755423 ,  0.17492072,
#         -0.06122058,  0.04351791,  0.17454801, -0.02995184,  0.14325176,
#          0.10003217,  0.02355905, -0.03118311, -0.12293834,  0.04894805,
#         -0.05122693, -0.01740826, -0.15134838,  0.18043752, -0.04528825,
#          0.00531194, -0.02422019,  0.15355977,  0.18061933,  0.06517684,
#          0.14039722,  0.07742146, -0.01083141,  0.04385693,  0.22816737,
#          0.14670496,  0.08704691, -0.16567001,  0.07638189,  0.02653025],
#        dtype=float32),
#  array([-8.98564979e-02,  1.67972624e-01,  1.94753874e-02, -3.85881984e-03,
#         -8.90150014e-03, -2.21914947e-01,  4.80905809e-02,  3.32115561e-01,
#         -1.66077584e-01, -6.37446642e-02, -9.97208431e-02, -2.83887118e-01,
#          3.56960297e-03,  8.48312601e-02,  7.62207881e-02, -1.19653516e-01,
#         -9.38488811e-04, -2.33679131e-01, -9.35199019e-03, -2.67804474e-01,
#          1.09289922e-01,  7.49700665e-02,  4.10288647e-02, -7.18559846e-02,
#         -9.51176509e-02,  2.05253381e-02, -1.06710680e-01, -9.55966413e-02,
#         -1.51681572e-01, -1.64000958e-03,  1.33582309e-01,  2.35752687e-02,
#          8.42306670e-03, -1.14942670e-01, -5.96504845e-02,  1.62330076e-01,
#          1.66295934e-02, -1.30724505e-01, -8.21840465e-02, -3.27754766e-01,
#          2.33279988e-02, -1.39983445e-01, -7.53981099e-02,  8.79231375e-03,
#          1.45427153e-01, -6.63455948e-02, -1.36189237e-01,  9.11421012e-05,
#          7.34619796e-02,  1.18675984e-01,  8.16978216e-02, -1.54517457e-01,
#         -3.75088044e-02, -3.87848500e-04, -1.22201122e-01,  8.75766277e-02,
#          1.19153708e-01, -1.82024557e-02, -1.67144731e-01,  5.10404371e-02,
#          2.50281300e-02,  8.60308930e-02, -6.47439510e-02,  1.89931691e-02,
#         -1.70200095e-01,  1.44280434e-01,  7.58075342e-02,  9.59713832e-02,
#         -2.24897251e-01,  2.17326030e-01, -7.58851096e-02,  4.90458161e-02,
#          2.26316646e-01, -3.78451459e-02,  1.83780134e-01,  1.26826853e-01,
#          3.56445611e-02, -4.06654626e-02, -1.64077580e-01,  6.39535561e-02,
#         -6.72848150e-02, -2.18640845e-02, -1.97097585e-01,  2.33048245e-01,
#         -6.07911795e-02,  6.82584383e-03, -3.11958790e-02,  1.95237890e-01,
#          2.29245499e-01,  8.65700543e-02,  1.82044193e-01,  9.42718685e-02,
#         -8.20369553e-03,  5.70082031e-02,  2.88860738e-01,  1.84781983e-01,
#          1.15912132e-01, -2.12135956e-01,  9.79658142e-02,  3.45716886e-02],
#        dtype=float32),
#  array([-8.70057270e-02,  1.67180583e-01,  2.16504727e-02, -7.22016580e-03,
#         -9.25515499e-03, -2.20763132e-01,  4.86812554e-02,  3.33655804e-01,
#         -1.70249358e-01, -5.89057766e-02, -1.03522576e-01, -2.85438925e-01,
#         -1.37833459e-03,  8.69722441e-02,  7.23390058e-02, -1.13923788e-01,
#          2.70267879e-03, -2.30947062e-01, -1.01292534e-02, -2.67752618e-01,
#          1.07940167e-01,  7.96480402e-02,  3.81997190e-02, -7.33944103e-02,
#         -9.87523422e-02,  2.32041646e-02, -1.01201959e-01, -1.04219444e-01,
#         -1.57223538e-01, -6.48169452e-03,  1.42804503e-01,  2.32413132e-02,
#          5.84970973e-03, -1.10352337e-01, -6.03179745e-02,  1.60767198e-01,
#          1.86679419e-02, -1.27063349e-01, -8.69584307e-02, -3.21554810e-01,
#          2.34439578e-02, -1.35947675e-01, -7.55670667e-02,  1.04937097e-02,
#          1.49738044e-01, -6.83937743e-02, -1.32486820e-01,  2.59175049e-05,
#          7.53631219e-02,  1.16731308e-01,  7.71925375e-02, -1.54678538e-01,
#         -4.21904735e-02, -3.86558170e-03, -1.29168406e-01,  9.04228166e-02,
#          1.18039280e-01, -2.63062511e-02, -1.71150759e-01,  5.71192838e-02,
#          2.63705086e-02,  8.62224922e-02, -6.71293736e-02,  1.65820625e-02,
#         -1.65523097e-01,  1.47514760e-01,  6.95021525e-02,  9.62653384e-02,
#         -2.21294031e-01,  2.23160431e-01, -7.78483376e-02,  5.34103625e-02,
#          2.25671574e-01, -3.62378955e-02,  1.82797149e-01,  1.29006907e-01,
#          2.90319975e-02, -4.24423851e-02, -1.56211153e-01,  6.19271956e-02,
#         -6.77049235e-02, -1.63421482e-02, -1.98086858e-01,  2.27606043e-01,
#         -6.01076633e-02,  6.08153408e-03, -3.26726846e-02,  2.00488925e-01,
#          2.29696974e-01,  8.30855966e-02,  1.83044791e-01,  9.64494273e-02,
#         -1.38487397e-02,  5.41447587e-02,  2.89762706e-01,  1.85558841e-01,
#          1.13671690e-01, -2.12042883e-01,  9.25802365e-02,  3.40065658e-02],
#        dtype=float32),
#  array([-0.16235118,  0.29575586,  0.03325545, -0.00624539, -0.01278296,
#         -0.38952094,  0.08635815,  0.59085566, -0.29799056, -0.11021499,
#         -0.17756377, -0.5017441 ,  0.0012726 ,  0.1456221 ,  0.13770272,
#         -0.20310065,  0.00864781, -0.40710476, -0.01382212, -0.4738684 ,
#          0.19048442,  0.1442218 ,  0.06688378, -0.1243467 , -0.16955908,
#          0.04164118, -0.18810606, -0.17522158, -0.28019837, -0.00946557,
#          0.24791953,  0.03789331,  0.01089959, -0.19135328, -0.10844866,
#          0.28783947,  0.02980274, -0.22785403, -0.1470732 , -0.5708411 ,
#          0.04610797, -0.24630138, -0.13237415,  0.01700015,  0.25892502,
#         -0.12046295, -0.23010066,  0.00632624,  0.134872  ,  0.20682916,
#          0.13739952, -0.2726252 , -0.07598048, -0.00448171, -0.22457385,
#          0.152539  ,  0.21077262, -0.04176062, -0.29186338,  0.09967501,
#          0.04659885,  0.15696774, -0.11851798,  0.02383651, -0.298601  ,
#          0.25805798,  0.12551703,  0.17624351, -0.39695737,  0.3910938 ,
#         -0.137354  ,  0.09982412,  0.40380856, -0.06671429,  0.32171145,
#          0.2245872 ,  0.05030131, -0.06989793, -0.2833513 ,  0.10852001,
#         -0.11637567, -0.03393067, -0.3430018 ,  0.4083302 , -0.10435791,
#          0.01714101, -0.05647136,  0.35603565,  0.40938783,  0.14757378,
#          0.3241039 ,  0.17267346, -0.02333255,  0.09601028,  0.52175176,
#          0.324697  ,  0.20588923, -0.373992  ,  0.17058961,  0.0545381 ],
#        dtype=float32),
#  array([-0.1275495 ,  0.24106579,  0.02934622, -0.00738147, -0.0070379 ,
#         -0.31128672,  0.06974407,  0.47508794, -0.24349634, -0.09005158,
#         -0.14613901, -0.40452495,  0.00259887,  0.120428  ,  0.10723823,
#         -0.16378605,  0.00547346, -0.33319888, -0.01299507, -0.37711263,
#          0.1511623 ,  0.109695  ,  0.05595302, -0.10185421, -0.1412276 ,
#          0.03245887, -0.1509812 , -0.14343107, -0.22620235, -0.00925438,
#          0.19776557,  0.03135032,  0.0029963 , -0.1606367 , -0.08869682,
#          0.23020871,  0.02455042, -0.18120281, -0.12487849, -0.46292952,
#          0.0333915 , -0.19473265, -0.10809398,  0.01380294,  0.2078464 ,
#         -0.09434684, -0.18784344, -0.00067846,  0.1058303 ,  0.1663536 ,
#          0.10947354, -0.21893533, -0.05999576, -0.00660938, -0.18096007,
#          0.12476125,  0.16725883, -0.03407488, -0.2380567 ,  0.07809506,
#          0.03736461,  0.12069272, -0.09595899,  0.02336204, -0.24124356,
#          0.21080415,  0.10626924,  0.13830839, -0.31770477,  0.3152284 ,
#         -0.10936759,  0.07903317,  0.31809565, -0.05117915,  0.2586469 ,
#          0.18391958,  0.03876707, -0.0570498 , -0.22481355,  0.08813046,
#         -0.09796075, -0.0258318 , -0.27857324,  0.32553816, -0.08795428,
#          0.01195374, -0.0416904 ,  0.28447977,  0.33070436,  0.11712269,
#          0.25679928,  0.1361128 , -0.01987491,  0.07504623,  0.41361484,
#          0.25728628,  0.16106848, -0.30064797,  0.13732897,  0.0470145 ],
#        dtype=float32),
#  array([-0.12820244,  0.24334995,  0.03127047, -0.01191455, -0.00362532,
#         -0.3179705 ,  0.07486111,  0.48142052, -0.24721196, -0.0896427 ,
#         -0.14769837, -0.41245097,  0.00653776,  0.12475902,  0.11135401,
#         -0.16614754,  0.00936455, -0.33265796, -0.01378386, -0.3856856 ,
#          0.1562232 ,  0.11744659,  0.0579254 , -0.10279471, -0.13509314,
#          0.03289575, -0.14647777, -0.14275928, -0.23231998, -0.01073944,
#          0.20167038,  0.03381484,  0.00812077, -0.15999518, -0.08374917,
#          0.23583528,  0.02269686, -0.18668136, -0.12481773, -0.46528473,
#          0.03647293, -0.19903834, -0.10701761,  0.02028319,  0.20874691,
#         -0.10391448, -0.19156219,  0.00296552,  0.10840946,  0.16730578,
#          0.11224066, -0.2220533 , -0.06390522, -0.00184039, -0.18479551,
#          0.1281469 ,  0.1770984 , -0.03512677, -0.2404125 ,  0.08358514,
#          0.03789332,  0.1263938 , -0.10023594,  0.02725175, -0.23943874,
#          0.21487485,  0.10313662,  0.140998  , -0.3263181 ,  0.3203259 ,
#         -0.11313694,  0.07598142,  0.32785898, -0.05083645,  0.2642059 ,
#          0.1903112 ,  0.043143  , -0.05846212, -0.23202458,  0.0969485 ,
#         -0.09922309, -0.02352616, -0.28117806,  0.3322825 , -0.09089952,
# ...
#          0.18058147,  0.23700865, -0.0446168 , -0.32819134,  0.11761913,
#          0.05279653,  0.17282751, -0.13213505,  0.0300552 , -0.32689402,
#          0.2913616 ,  0.14479087,  0.19619912, -0.43775374,  0.43845227,
#         -0.15750834,  0.10647269,  0.45080003, -0.06879234,  0.3575781 ,
#          0.2554117 ,  0.05310061, -0.07831297, -0.3134995 ,  0.12172034,
#         -0.13582028, -0.03401843, -0.38339722,  0.45580974, -0.1244521 ,
#          0.01611223, -0.05617763,  0.39489204,  0.4550629 ,  0.1613763 ,
#          0.36560103,  0.19157092, -0.02246928,  0.10247798,  0.57718587,
#          0.36023104,  0.2328543 , -0.41793472,  0.18452635,  0.06146899],
#        dtype=float32),
#  array([-0.116655  ,  0.2092136 ,  0.02683805, -0.0099235 , -0.00939742,
#         -0.28206453,  0.06512261,  0.42618236, -0.22155537, -0.07686444,
#         -0.12589902, -0.36312532,  0.00661804,  0.10499889,  0.09326088,
#         -0.14792803,  0.00994414, -0.2949702 , -0.01355852, -0.34299403,
#          0.14001878,  0.10222849,  0.05697954, -0.0907579 , -0.12519355,
#          0.02672324, -0.13265702, -0.12630609, -0.19859318, -0.00472493,
#          0.18305339,  0.02934512,  0.00701021, -0.13467412, -0.07338721,
#          0.20869398,  0.02152041, -0.16056123, -0.1114325 , -0.40676683,
#          0.03407487, -0.17391714, -0.09455512,  0.01722099,  0.1821811 ,
#         -0.09194122, -0.16324516,  0.00102318,  0.09487503,  0.14740488,
#          0.09683286, -0.19371139, -0.05515135, -0.0014835 , -0.1644787 ,
#          0.11473348,  0.15078549, -0.03363965, -0.21002485,  0.07540791,
#          0.03471085,  0.10765334, -0.08817923,  0.02397295, -0.21423386,
#          0.19217487,  0.08812107,  0.12295009, -0.2830959 ,  0.28390163,
#         -0.09779967,  0.06968198,  0.28629565, -0.04453496,  0.22792478,
#          0.16582926,  0.03716602, -0.05365347, -0.20746417,  0.08304205,
#         -0.08648983, -0.02163586, -0.24600455,  0.297895  , -0.08358431,
#          0.01600653, -0.04487317,  0.25560433,  0.29874042,  0.10706825,
#          0.23599538,  0.12198682, -0.0168531 ,  0.06893887,  0.3703122 ,
#          0.23409891,  0.15548442, -0.2705648 ,  0.12216836,  0.03589416],
#        dtype=float32),
#  array([-0.0883963 ,  0.1593622 ,  0.01875527, -0.00647051, -0.00761248,
#         -0.20584892,  0.04966533,  0.3174661 , -0.16250537, -0.05662205,
#         -0.09656931, -0.27456647,  0.00089089,  0.08300044,  0.06968355,
#         -0.11416654,  0.00238091, -0.220101  , -0.01211102, -0.25471514,
#          0.10532383,  0.07614163,  0.03662745, -0.06875914, -0.09177408,
#          0.02282849, -0.09781168, -0.09864259, -0.15414631, -0.00334054,
#          0.13503943,  0.02037283,  0.0058242 , -0.10563089, -0.05801101,
#          0.15741363,  0.01737116, -0.12426355, -0.0814479 , -0.3152306 ,
#          0.02402938, -0.1307305 , -0.07114369,  0.01026428,  0.13909616,
#         -0.06331477, -0.12441781,  0.00044508,  0.07419065,  0.11161873,
#          0.07452598, -0.14967746, -0.039686  ,  0.00098607, -0.12363345,
#          0.08571284,  0.11458716, -0.02003559, -0.16233924,  0.0555274 ,
#          0.02687737,  0.08280828, -0.06520332,  0.01793095, -0.16354322,
#          0.13867605,  0.06638331,  0.09231014, -0.21220794,  0.20911574,
#         -0.07606807,  0.05259939,  0.22344647, -0.03303536,  0.17200363,
#          0.12291287,  0.02599059, -0.03721118, -0.15286855,  0.06086121,
#         -0.06705655, -0.0175132 , -0.18701091,  0.22134237, -0.06013114,
#          0.00870332, -0.02798755,  0.19450545,  0.22184378,  0.08116072,
#          0.17595364,  0.09414665, -0.01327414,  0.05462653,  0.27983353,
#          0.17738055,  0.10926007, -0.20276012,  0.09099923,  0.02989297],
#        dtype=float32),
#  array([-0.18693888,  0.3886321 ,  0.04204312, -0.01697212, -0.025374  ,
#         -0.47471082,  0.11955696,  0.724664  , -0.36355403, -0.13035257,
#         -0.23093401, -0.6317187 , -0.00122567,  0.17811167,  0.16283897,
#         -0.26058364,  0.00334556, -0.51414937, -0.02989631, -0.5897195 ,
#          0.25309196,  0.19075917,  0.08352036, -0.15658608, -0.19685559,
#          0.04899382, -0.23279503, -0.22267753, -0.3505057 , -0.00900404,
#          0.3080829 ,  0.05548643,  0.01514518, -0.24124795, -0.12150101,
#          0.3718597 ,  0.0547169 , -0.27852398, -0.19450212, -0.7101106 ,
#          0.03463658, -0.3097864 , -0.1712631 ,  0.02377123,  0.3206763 ,
#         -0.16302676, -0.27335533,  0.01739465,  0.16703306,  0.2644357 ,
#          0.15924615, -0.35222667, -0.09018964, -0.00893982, -0.29117036,
#          0.1957243 ,  0.2670043 , -0.06640477, -0.36341003,  0.12810835,
#          0.07396375,  0.19337745, -0.13469274,  0.03512373, -0.3620564 ,
#          0.32720995,  0.15883666,  0.2274178 , -0.5033226 ,  0.4914642 ,
#         -0.17011082,  0.12525691,  0.4983681 , -0.07786737,  0.39112887,
#          0.28586754,  0.05027834, -0.09926981, -0.35244462,  0.14330375,
#         -0.14411855, -0.05406404, -0.42845687,  0.51411736, -0.12751439,
#          0.00616017, -0.06322649,  0.44450682,  0.50018394,  0.19994135,
#          0.4081268 ,  0.2148815 , -0.02051659,  0.10465541,  0.6448746 ,
#          0.40516308,  0.26886633, -0.4591193 ,  0.21362011,  0.06576326],
#        dtype=float32),
#  array([-0.1262769 ,  0.23671374,  0.03469709, -0.0061146 , -0.01014196,
#         -0.2988691 ,  0.07207803,  0.45628154, -0.23557466, -0.08794549,
#         -0.14297906, -0.39336482,  0.00570264,  0.11556383,  0.10645577,
#         -0.1656689 ,  0.00635321, -0.31972143, -0.01823525, -0.3704015 ,
#          0.14588404,  0.11447296,  0.05583299, -0.09691769, -0.13523112,
#          0.02848341, -0.1387842 , -0.13607852, -0.22213604, -0.00501148,
#          0.19777946,  0.02992129,  0.00610088, -0.14759877, -0.08409476,
#          0.22946665,  0.02182203, -0.17962217, -0.12176041, -0.4527726 ,
#          0.03446423, -0.19050816, -0.09820829,  0.01505066,  0.20048682,
#         -0.09802488, -0.17901993,  0.00258625,  0.10351691,  0.15925926,
#          0.10306046, -0.22045632, -0.06026123, -0.00531525, -0.17531061,
#          0.1275155 ,  0.17185007, -0.03632973, -0.22675331,  0.0817304 ,
#          0.03356158,  0.11950412, -0.08992735,  0.02158149, -0.23434655,
#          0.20130117,  0.09585106,  0.13716139, -0.30639613,  0.30432278,
#         -0.10972001,  0.0806316 ,  0.3197378 , -0.04610131,  0.24878556,
#          0.1803873 ,  0.04076812, -0.05745044, -0.2210801 ,  0.08381113,
#         -0.09460983, -0.02717574, -0.26826987,  0.3150104 , -0.08634612,
#          0.01180958, -0.0448537 ,  0.27323785,  0.3129257 ,  0.10714097,
#          0.2524617 ,  0.12871838, -0.02360161,  0.07340029,  0.40673473,
#          0.2512574 ,  0.15890834, -0.2935865 ,  0.13253628,  0.05089423],
#        dtype=float32),
#  array([-0.12503892,  0.23138504,  0.02503941, -0.00902448, -0.00957883,
#         -0.3108678 ,  0.07103916,  0.46903625, -0.23499465, -0.08654458,
#         -0.14178798, -0.3973438 ,  0.00135893,  0.12486671,  0.10181761,
#         -0.1610079 ,  0.00552841, -0.3221907 , -0.01307932, -0.3771353 ,
#          0.14905977,  0.11049306,  0.05798397, -0.10237869, -0.13344583,
#          0.0300371 , -0.14541218, -0.13893834, -0.22089715, -0.01171765,
#          0.1962963 ,  0.03246478,  0.00770502, -0.15460873, -0.08552638,
#          0.22780542,  0.02136677, -0.18201256, -0.12258478, -0.4551051 ,
#          0.033919  , -0.19094153, -0.10336333,  0.01039631,  0.20703164,
#         -0.09474213, -0.18644093,  0.00205046,  0.10270226,  0.16515876,
#          0.11049718, -0.21872489, -0.05975217, -0.00534564, -0.17705718,
#          0.12394203,  0.17042819, -0.04006302, -0.2291036 ,  0.07797897,
#          0.03624935,  0.11931765, -0.08964854,  0.0228917 , -0.23272835,
#          0.20706686,  0.09612811,  0.13589872, -0.3129378 ,  0.3102128 ,
#         -0.10691859,  0.07341792,  0.3173867 , -0.04895986,  0.25230592,
#          0.1777092 ,  0.04088416, -0.05575218, -0.22680761,  0.08592205,
#         -0.09664609, -0.02784288, -0.2747008 ,  0.32680723, -0.08423734,
#          0.01252904, -0.04028114,  0.28122124,  0.32536602,  0.12110423,
#          0.26240653,  0.13618733, -0.02268168,  0.07257035,  0.4128582 ,
#          0.25987378,  0.16357253, -0.3007923 ,  0.13184863,  0.04325435],
#        dtype=float32),
#  array([-0.05830881,  0.10594961,  0.01250138, -0.00309281, -0.00748814,
#         -0.13891816,  0.03162681,  0.20795332, -0.10700566, -0.03723898,
#         -0.06774337, -0.17962876,  0.00177002,  0.05611953,  0.04843365,
#         -0.07425652,  0.00105084, -0.14427227, -0.00800283, -0.16647084,
#          0.06848569,  0.05269682,  0.02316226, -0.04373914, -0.05909055,
#          0.01770024, -0.06411342, -0.0648716 , -0.09778306, -0.00470552,
#          0.08707117,  0.00960098,  0.00500401, -0.07057942, -0.03784034,
#          0.10102025,  0.01090834, -0.07720372, -0.05540171, -0.20235352,
#          0.01730114, -0.08539422, -0.04624056,  0.00630213,  0.08748858,
#         -0.04014572, -0.08483952,  0.00317469,  0.04885017,  0.07345054,
#          0.04629749, -0.09461883, -0.02936649, -0.00284178, -0.08187944,
#          0.05348318,  0.07289941, -0.01609004, -0.10690246,  0.03646491,
#          0.01504662,  0.05592081, -0.04133249,  0.0131903 , -0.1063617 ,
#          0.09426133,  0.04628244,  0.06012435, -0.1430393 ,  0.13853842,
#         -0.05052116,  0.0315758 ,  0.14364943, -0.02594331,  0.1167326 ,
#          0.08072437,  0.01267703, -0.0250662 , -0.09876795,  0.04225833,
#         -0.04270642, -0.00902119, -0.12144459,  0.14398038, -0.0383025 ,
#          0.00530896, -0.02085127,  0.12270977,  0.14439502,  0.05075332,
#          0.11335012,  0.06016237, -0.01016817,  0.03287956,  0.18309836,
#          0.11355047,  0.06940889, -0.13246983,  0.05599692,  0.0239881 ],
#        dtype=float32),
#  array([-0.17168382,  0.32409996,  0.0387979 , -0.00931578, -0.00899175,
#         -0.42043385,  0.09545422,  0.6377997 , -0.3259828 , -0.11820734,
#         -0.19334921, -0.5453258 ,  0.00316062,  0.16119114,  0.14399414,
#         -0.21961007,  0.00983914, -0.43977395, -0.02039465, -0.51065445,
#          0.202601  ,  0.1532855 ,  0.07807087, -0.13828683, -0.18189272,
#          0.04242498, -0.19938739, -0.18965952, -0.30746636, -0.00865192,
#          0.27153507,  0.03715159,  0.00757336, -0.20923893, -0.11474723,
#          0.3129518 ,  0.03467076, -0.24546476, -0.16383   , -0.61932325,
#          0.04773755, -0.26688176, -0.14446124,  0.02144726,  0.27833852,
#         -0.135177  , -0.24628997,  0.003839  ,  0.140282  ,  0.22313093,
#          0.14828263, -0.3000659 , -0.08169142, -0.00271995, -0.24393973,
#          0.17169534,  0.23168132, -0.04808008, -0.32247645,  0.11027051,
#          0.05329461,  0.16592817, -0.12446408,  0.03358457, -0.32124206,
#          0.28770837,  0.14162713,  0.18880896, -0.4309559 ,  0.42522234,
#         -0.14742683,  0.10261451,  0.43691996, -0.0668842 ,  0.34555212,
#          0.24924769,  0.05206485, -0.07774509, -0.3094395 ,  0.12171274,
#         -0.12914541, -0.03696984, -0.369777  ,  0.4401439 , -0.11533077,
#          0.01701358, -0.05884948,  0.38513225,  0.44278362,  0.15903175,
#          0.35185105,  0.18670164, -0.02246184,  0.10162632,  0.56093514,
#          0.3542686 ,  0.22769845, -0.40467378,  0.17990635,  0.06146208],
#        dtype=float32),
#  array([-7.43150413e-02,  1.33578122e-01,  1.36771789e-02, -1.63175585e-03,
#         -4.13658703e-03, -1.77411556e-01,  3.85912769e-02,  2.57330745e-01,
#         -1.35127470e-01, -5.01417369e-02, -8.19026604e-02, -2.22672120e-01,
#          1.31952914e-03,  7.08452240e-02,  6.13766499e-02, -9.37983766e-02,
#         -8.57448540e-05, -1.82000339e-01, -4.14781971e-03, -2.16702506e-01,
#          8.59732032e-02,  6.22506738e-02,  3.07031590e-02, -5.24175577e-02,
#         -7.47916996e-02,  1.63310710e-02, -8.53003263e-02, -7.62535855e-02,
#         -1.21369891e-01, -8.01365357e-03,  1.14048891e-01,  1.08056804e-02,
#          4.66463482e-03, -8.49515274e-02, -5.12661673e-02,  1.28029719e-01,
#          2.29144990e-02, -9.98610035e-02, -6.32372797e-02, -2.55205482e-01,
#          1.99398044e-02, -1.07931621e-01, -5.39353639e-02,  2.92816479e-03,
#          1.20586313e-01, -5.29036075e-02, -1.07866697e-01, -6.02443062e-04,
#          6.43373728e-02,  9.27477255e-02,  6.35618791e-02, -1.23982988e-01,
#         -3.24227884e-02, -5.90129942e-03, -9.89914164e-02,  7.04383105e-02,
#          9.51543674e-02, -2.62922924e-02, -1.35814801e-01,  3.81130166e-02,
#          1.58255901e-02,  7.21890107e-02, -5.00387959e-02,  1.21226488e-02,
#         -1.31974533e-01,  1.16643034e-01,  5.59228398e-02,  7.56118670e-02,
#         -1.78558245e-01,  1.80484757e-01, -5.86055368e-02,  4.39005680e-02,
#          1.73547849e-01, -2.50137597e-02,  1.39806941e-01,  1.07241653e-01,
#          1.96426492e-02, -2.93403585e-02, -1.29229411e-01,  4.99240644e-02,
#         -5.24869412e-02, -1.87800135e-02, -1.61183700e-01,  1.83863282e-01,
#         -5.21757714e-02,  1.45769529e-02, -2.25148853e-02,  1.54338881e-01,
#          1.82374313e-01,  6.15344308e-02,  1.44719243e-01,  7.47465417e-02,
#         -1.38132973e-02,  3.91583256e-02,  2.29888558e-01,  1.46687061e-01,
#          9.28600356e-02, -1.67822227e-01,  7.62592033e-02,  2.31454391e-02],
#        dtype=float32),
#  array([-0.03894334,  0.07681794,  0.00403274, -0.00045887,  0.00138487,
#         -0.09721567,  0.02084034,  0.15413766, -0.07583038, -0.02858299,
#         -0.05098527, -0.12968853,  0.00608353,  0.04058965,  0.0337156 ,
#         -0.05432734,  0.00189886, -0.10666183, -0.00658112, -0.1177546 ,
#          0.05140037,  0.03659527,  0.0267234 , -0.02958828, -0.05020023,
#          0.01333034, -0.04649443, -0.04735579, -0.06808851, -0.00494811,
#          0.06959664,  0.01297447, -0.00025531, -0.04730226, -0.02874706,
#          0.07377134,  0.0102112 , -0.06134753, -0.04018172, -0.15177701,
#          0.01225014, -0.06024667, -0.03126403,  0.00392315,  0.06727376,
#         -0.02660445, -0.05463682,  0.00187636,  0.03531602,  0.05189659,
#          0.0357108 , -0.07212842, -0.01671387, -0.00662646, -0.06164904,
#          0.03963687,  0.05862913, -0.01338529, -0.08205956,  0.01978286,
#          0.00896842,  0.03952023, -0.03731436,  0.01092595, -0.07686625,
#          0.07448898,  0.03283988,  0.04484024, -0.10979294,  0.09719631,
#         -0.03804509,  0.02471101,  0.10510957, -0.02054687,  0.08308993,
#          0.06090616,  0.01261056, -0.02284989, -0.07245564,  0.02663896,
#         -0.03433071, -0.00216243, -0.08153135,  0.10577678, -0.02662384,
#          0.00844164, -0.01677062,  0.09195543,  0.10904675,  0.03948864,
#          0.08464158,  0.04366448, -0.01171553,  0.02570608,  0.13807023,
#          0.08094353,  0.05242577, -0.09582406,  0.04658754,  0.01554684],
#        dtype=float32),
#  array([-0.15261087,  0.30149233,  0.0376784 , -0.00467594, -0.01348218,
#         -0.3644927 ,  0.09001654,  0.5631454 , -0.2864516 , -0.10557225,
#         -0.166919  , -0.49315888,  0.00338689,  0.14256899,  0.1165095 ,
#         -0.18726568,  0.00465884, -0.3876079 , -0.01968391, -0.4456188 ,
#          0.18178605,  0.15136628,  0.06785155, -0.11132856, -0.15167126,
#          0.03806449, -0.17011848, -0.16172037, -0.27253026, -0.01105691,
#          0.2306046 ,  0.03006594,  0.00682981, -0.18729676, -0.10310972,
#          0.27846766,  0.03470076, -0.2294248 , -0.13268408, -0.5541753 ,
#          0.02619467, -0.23191771, -0.12593552,  0.01485839,  0.24482231,
#         -0.11872109, -0.21223967,  0.01319495,  0.1269032 ,  0.1955222 ,
#          0.12017937, -0.26692817, -0.0739502 , -0.00642462, -0.2187756 ,
#          0.15233228,  0.21192923, -0.04446304, -0.28553674,  0.09371437,
#          0.0520283 ,  0.14400575, -0.11552401,  0.02549176, -0.28055218,
#          0.25085628,  0.1178092 ,  0.1722999 , -0.38014126,  0.3676964 ,
#         -0.13216653,  0.09541066,  0.38178533, -0.06305137,  0.30891675,
#          0.2290016 ,  0.03487701, -0.07885038, -0.2714166 ,  0.10164797,
#         -0.11210001, -0.03686919, -0.3181707 ,  0.4066264 , -0.10288076,
#          0.01055062, -0.05273953,  0.33745554,  0.38102287,  0.14975217,
#          0.30716306,  0.16938165, -0.0252075 ,  0.08852501,  0.5071519 ,
#          0.31850258,  0.19690773, -0.3599121 ,  0.16000952,  0.05890435],
#        dtype=float32),
#  ...]

# %%
len(X)
# Out:
# 5564

# %%
## Independent Feature
X_new = np.array(X)

# %%
X_new.shape
# Out:
# (5564, 100)

# %%
X_new[0].shape
# Out:
# (100,)

# %%
### Output Feature
y = pd.get_dummies(df['label'])
y = y.iloc[:,0].values

# %%
y.shape
# Out:
# (5572,)

# %%
df.shape
# Out:
# (5572, 2)

# %%
print("Feature matrix shape:", X_new.shape)  # Should be (5564, 100)
print("Label shape:", y.shape)
# Out:
# Feature matrix shape: (5564, 100)
# Label shape: (5572,)

# %%
# Ensure the number of labels matches the number of samples in X_new
y = y[:len(X_new)]  # Trim the labels to match the number of samples in X_new

# Check the shapes again
print("Feature matrix shape:", X_new.shape)  # (5564, 100)
print("Label shape:", y.shape)  # (5564,)
# Out:
# Feature matrix shape: (5564, 100)
# Label shape: (5564,)

# %%
# Step 1: Split the data into training and testing sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_new, y, test_size=0.2, random_state=42)

# Step 2: Initialize and train the model
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=100, random_state=42)
clf.fit(X_train, y_train)

# Step 3: Evaluate the model
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
y_pred = clf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy * 100:.2f}%")

print(classification_report(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 84.64%
#               precision    recall  f1-score   support
#
#        False       0.07      0.01      0.01       158
#         True       0.86      0.99      0.92       955
#
#     accuracy                           0.85      1113
#    macro avg       0.46      0.50      0.46      1113
# weighted avg       0.74      0.85      0.79      1113
#
# Confusion Matrix:
#  [[  1 157]
#  [ 14 941]]
